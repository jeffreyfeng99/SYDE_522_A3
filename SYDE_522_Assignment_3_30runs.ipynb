# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffreyfeng99/SYDE_522_A3/blob/master/SYDE_522_Assignment_3_30runs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Submission Notes
# Group members:
#
# Jeffrey Feng, 20704800
#
# Joey Kuang, 20726074

# %% [markdown]
# # Import statements

# %%
import os
import pandas as pd
import numpy as np
import random
from PIL import Image
from tqdm import tqdm
from datetime import datetime

import torch
import torch.nn as nn
import torch.utils.data as data
from torch.autograd import Function
import torch.backends.cudnn as cudnn
from torchvision import transforms
from torchvision import datasets
from torchvision import models
import torch.optim as optim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Config

# %%
cuda = True
cudnn.benchmark = True
LR = 1e-3
BATCH_SIZE = 128
IMAGE_SIZE = 224 #227
FT_OUT_SIZE = 512
N_EPOCH = 100

# %% [markdown]
# # Data loader

# %%
dataset_root = '/content/drive/MyDrive/4B/SYDE-522/data'
output_root = '/content/drive/MyDrive/4B/SYDE-522/submission/03292022_run4'
source_dataset_name = 'train_set'
target_dataset_name = 'test_set'

source_image_root = os.path.join(dataset_root, source_dataset_name)
target_image_root = os.path.join(dataset_root, target_dataset_name)

train_label_list = os.path.join(dataset_root, 'train_labels.csv')

os.makedirs(output_root, exist_ok=True)

# %%
class GetLoader(data.Dataset):
    def __init__(self, data_root, data_list=None, transform=None):
        self.root = data_root
        self.transform = transform

        # we only pass data_list if it's training set
        if data_list is not None:
            df = pd.read_csv(data_list)
            self.img_paths = df['dir'].to_list()

            if 'label2' in df.columns:
                self.img_labels = df['label2'].to_list()
            else: 
                self.img_labels = ['0' for i in range(len(self.img_paths))]

            if 'label1' in df.columns:
                self.domain_labels = df['label1'].to_list()
            else: 
                self.domain_labels = ['0' for i in range(len(self.img_paths))]
        else:
            # Walk through test folder - we don't need labels
            self.img_paths = [f for root,dirs,files in os.walk(data_root) for f in files if f.endswith('.png')]
            self.img_labels = ['0' for i in range(len(self.img_paths))]
            self.domain_labels = ['0' for i in range(len(self.img_paths))]

        self.n_data = len(self.img_paths)

    def __getitem__(self, item):
        img_paths, labels, domain_labels = self.img_paths[item%self.n_data], self.img_labels[item%self.n_data], self.domain_labels[item%self.n_data]
        imgs = Image.open(os.path.join(self.root, img_paths)).convert('RGB')

        if self.transform is not None:
            imgs = self.transform(imgs)
            labels = int(labels)
            domain_labels = int(domain_labels)

        return imgs, labels, domain_labels, img_paths

    def __len__(self):
        return self.n_data

# %%
# Preprocess data
def preprocess_fn(mu=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)):
  img_transform = transforms.Compose([
      transforms.Resize(IMAGE_SIZE),
      transforms.ToTensor(),
      transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)) # why isn't this (0.1307,) and (0.3081,) like in test?
  ])

  return img_transform

def prep_dataloader(image_root, label_list=None, img_transform=None, 
                    drop_last=False, shuffle=True):
    dataset = GetLoader(
        data_root=image_root,
        data_list=label_list,
        transform=img_transform
    )

    dataloader = data.DataLoader(
        dataset=dataset,
        batch_size=BATCH_SIZE,
        shuffle=shuffle,
        num_workers=8,
        drop_last=drop_last)
    
    return dataset, dataloader

# %% [markdown]
# # Model definition

# %%
# if False, then we are feature extracting
def set_parameter_requires_grad(model, finetune):
    for param in model.parameters():
        param.requires_grad = finetune

# %%
class ReverseLayerF(Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None


class CNNModel(nn.Module):

    def __init__(self, model_name="resnet18"):
        super(CNNModel, self).__init__()

        if model_name == "resnet18":
            self.feature = models.resnet18(pretrained=True) 
            self.feature.fc = nn.Identity()
        elif model_name == "vgg11":
            self.feature = models.vgg11_bn(pretrained=True) 
            self.feature.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1)) # original is (7,7)
            self.feature.classifier = nn.Identity()
        else:
            # Need some default model?
            self.feature = nn.Sequential()
            self.feature.add_module('f_conv1', nn.Conv2d(3, 64, kernel_size=5))
            self.feature.add_module('f_bn1', nn.BatchNorm2d(64))
            self.feature.add_module('f_pool1', nn.MaxPool2d(2))
            self.feature.add_module('f_relu1', nn.ReLU(True))
            self.feature.add_module('f_conv2', nn.Conv2d(64, 128, kernel_size=3))
            self.feature.add_module('f_bn2', nn.BatchNorm2d(128))
            self.feature.add_module('f_drop1', nn.Dropout2d())
            self.feature.add_module('f_pool2', nn.MaxPool2d(2))
            self.feature.add_module('f_relu2', nn.ReLU(True))
            self.feature.add_module('f_conv3', nn.Conv2d(128, 256, kernel_size=3))
            self.feature.add_module('f_bn3', nn.BatchNorm2d(256))
            self.feature.add_module('f_drop3', nn.Dropout2d())
            self.feature.add_module('f_pool3', nn.MaxPool2d(2))
            self.feature.add_module('f_relu4', nn.ReLU(True))
            self.feature.add_module('f_conv4', nn.Conv2d(256, 256, kernel_size=3))
            self.feature.add_module('f_bn4', nn.BatchNorm2d(256))
            self.feature.add_module('f_drop4', nn.Dropout2d())
            self.feature.add_module('f_pool4', nn.MaxPool2d(2))
            self.feature.add_module('f_relu4', nn.ReLU(True))
            self.feature.add_module('f_conv5', nn.Conv2d(256, 512, kernel_size=3))
            self.feature.add_module('f_bn5', nn.BatchNorm2d(512))
            self.feature.add_module('f_drop5', nn.Dropout2d())
            self.feature.add_module('f_pool5', nn.MaxPool2d(2))
            self.feature.add_module('f_relu5', nn.ReLU(True))

        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(FT_OUT_SIZE, 100))
        self.class_classifier.add_module('c_bn1', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_drop1', nn.Dropout2d())
        self.class_classifier.add_module('c_fc2', nn.Linear(100, 100))
        self.class_classifier.add_module('c_bn2', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(100, 7))
        self.class_classifier.add_module('c_softmax', nn.LogSoftmax(dim=1))

        self.domain_classifier = nn.Sequential()
        self.domain_classifier.add_module('d_fc1', nn.Linear(FT_OUT_SIZE, 100))
        self.domain_classifier.add_module('d_bn1', nn.BatchNorm1d(100))
        self.domain_classifier.add_module('d_relu1', nn.ReLU(True))
        self.domain_classifier.add_module('d_fc2', nn.Linear(100, 4))
        self.domain_classifier.add_module('d_softmax', nn.LogSoftmax(dim=1))

    def forward(self, input_data, alpha):
        input_data = input_data.expand(input_data.data.shape[0], 3, IMAGE_SIZE, IMAGE_SIZE)
        feature = self.feature(input_data)
        feature = feature.view(-1, FT_OUT_SIZE)
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)

        return class_output, domain_output

# %% [markdown]
# # Test pipeline

# %%
def test(net, epoch):

    # load data
    img_transform_source = preprocess_fn(mu=(0.1307,), std=(0.3081,))
    img_transform_target = preprocess_fn()

    dataset_source, dataloader_source = prep_dataloader(
        image_root=os.path.join(source_image_root, 'train_set'),
        label_list=train_label_list,
        img_transform=img_transform_source,
        shuffle=False
    )

    dataset_target, dataloader_target = prep_dataloader(
        image_root=os.path.join(target_image_root, 'test_set'),
        img_transform=img_transform_target,
        shuffle=False
    )

    net.eval()

    if cuda:
        net = net.cuda()

    train_pths, train_preds = inference(net, dataloader_source, cuda=cuda, alpha=alpha)
    train_results = pd.DataFrame({'id': train_pths, 'label': train_preds})
    train_results_pth = os.path.join(output_root, '%s_train_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
    train_results.to_csv(train_results_pth, index=False)

    test_pths, test_preds = inference(net, dataloader_target, cuda=cuda, alpha=alpha)
    test_results = pd.DataFrame({'id': test_pths, 'label': test_preds})
    test_results_pth = os.path.join(output_root, '%s_test_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
    test_results.to_csv(test_results_pth, index=False)

    print('epoch: %d, accuracy of the train dataset: %f' % (epoch, compare(train_label_list, train_results_pth)))

    # Secret
    test_label_list = os.path.join(dataset_root, 'dummy_test_labels.csv')
    print('epoch: %d, accuracy of the test dataset: %f' % (epoch, compare(test_label_list, test_results_pth)))

def inference(net, dataloader, cuda=True, alpha=0.0):
    preds = []
    pths = []
    for input_img, _,_, img_paths in dataloader: 

        if cuda:
            input_img = input_img.cuda()

        class_output, _ = net(input_data=input_img, alpha=alpha)
        pred = class_output.data.max(1, keepdim=True)[1]
        pths = pths + list(img_paths)
        preds = preds + list(pred.squeeze(1).cpu().numpy())
    return pths, preds

def compare(true_labels, predicted_labels):
    combined_df = pd.read_csv(true_labels)
    predicted_df = pd.read_csv(predicted_labels)

    combined_df['label'] = combined_df['dir'].map(predicted_df.set_index('id')['label'])

    true_labels = np.array(combined_df['label2'].to_list())
    pred_labels = np.array(combined_df['label'].to_list())

    return np.sum(true_labels == pred_labels) / len(true_labels)

# %% [markdown]
# # Training pipeline

# %%
manual_seed = random.randint(1, 10000)
random.seed(manual_seed)
torch.manual_seed(manual_seed)

# load data
img_transform_source = preprocess_fn()
img_transform_target = preprocess_fn()

dataset_source, dataloader_source = prep_dataloader(
    image_root=os.path.join(source_image_root, 'train_set'), # TODO should we unnest
    label_list=train_label_list,
    img_transform=img_transform_source
)

dataset_target, dataloader_target = prep_dataloader(
    image_root=os.path.join(target_image_root, 'test_set'),
    img_transform=img_transform_target
)

# load model
my_net = CNNModel()

# setup optimizer
optimizer = optim.Adam(my_net.parameters(), lr=LR)

loss_class = torch.nn.NLLLoss()
loss_domain = torch.nn.NLLLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()
    loss_domain = loss_domain.cuda()

set_parameter_requires_grad(my_net, True)

# training
for epoch in range(N_EPOCH):

    len_dataloader = max(len(dataloader_source), len(dataloader_target))
    data_source_iter = iter(dataloader_source)
    data_target_iter = iter(dataloader_target)

    i = 0
    while i < len_dataloader:

        p = float(i + epoch * len_dataloader) / N_EPOCH / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # training model using source data
        data_source = data_source_iter.next()
        s_img, s_label, s_domain_label, _ = data_source

        my_net.zero_grad()
        batch_size = len(s_label)

        input_img = torch.FloatTensor(batch_size, 3, IMAGE_SIZE, IMAGE_SIZE)
        class_label = torch.LongTensor(batch_size)
        domain_label = torch.LongTensor(batch_size)

        if cuda:
            s_img = s_img.cuda()
            s_label = s_label.cuda()
            s_domain_label = s_domain_label.cuda()
            input_img = input_img.cuda()
            class_label = class_label.cuda()
            domain_label = domain_label.cuda()

        input_img.resize_as_(s_img).copy_(s_img)
        class_label.resize_as_(s_label).copy_(s_label)
        domain_label.resize_as_(s_domain_label).copy_(s_domain_label)

        class_output, domain_output = my_net(input_data=input_img, alpha=alpha)
        err_s_label = loss_class(class_output, class_label)
        err_s_domain = loss_domain(domain_output, domain_label)

        # training model using target data
        if i == len(dataloader_target):
            data_target_iter = iter(dataloader_target)
        data_target = data_target_iter.next()
        t_img, _, _, _ = data_target

        batch_size = len(t_img) # TODO: why?

        input_img = torch.FloatTensor(batch_size, 3, IMAGE_SIZE, IMAGE_SIZE)
        domain_label = torch.ones(batch_size) * 3.0
        domain_label = domain_label.long()

        if cuda:
            t_img = t_img.cuda()
            input_img = input_img.cuda()
            domain_label = domain_label.cuda()

        input_img.resize_as_(t_img).copy_(t_img)

        _, domain_output = my_net(input_data=input_img, alpha=alpha)
        err_t_domain = loss_domain(domain_output, domain_label)
        err = err_t_domain + err_s_domain + err_s_label
        err.backward()
        optimizer.step()

        i += 1

        print('epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
            % (epoch, i, len_dataloader, err_s_label.cpu().data.numpy(),
                err_s_domain.cpu().data.numpy(), err_t_domain.cpu().data.numpy()))

    # torch.save(my_net, 'output/model_epoch_{}.pth'.format(epoch))
    test(my_net, epoch)
    my_net.train()

print('done')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch: 0, [iter: 1 / all 48], err_s_label: 2.049632, err_s_domain: 1.463411, err_t_domain: 1.369871
# epoch: 0, [iter: 2 / all 48], err_s_label: 1.763609, err_s_domain: 1.286389, err_t_domain: 1.320969
# epoch: 0, [iter: 3 / all 48], err_s_label: 1.640862, err_s_domain: 1.212555, err_t_domain: 1.277465
# epoch: 0, [iter: 4 / all 48], err_s_label: 1.489732, err_s_domain: 1.142430, err_t_domain: 1.228827
# epoch: 0, [iter: 5 / all 48], err_s_label: 1.413516, err_s_domain: 1.113349, err_t_domain: 1.185817
# epoch: 0, [iter: 6 / all 48], err_s_label: 1.281601, err_s_domain: 1.094675, err_t_domain: 1.162535
# epoch: 0, [iter: 7 / all 48], err_s_label: 1.240850, err_s_domain: 1.005652, err_t_domain: 1.111124
# epoch: 0, [iter: 8 / all 48], err_s_label: 1.184774, err_s_domain: 0.977652, err_t_domain: 1.068045
# epoch: 0, [iter: 9 / all 48], err_s_label: 1.091792, err_s_domain: 1.049122, err_t_domain: 1.024271
# epoch: 0, [iter: 10 / all 48], err_s_label: 1.206450, err_s_domain: 1.114057, err_t_domain: 0.977575
# epoch: 0, [iter: 11 / all 48], err_s_label: 1.103390, err_s_domain: 1.070566, err_t_domain: 0.928927
# epoch: 0, [iter: 12 / all 48], err_s_label: 1.002768, err_s_domain: 1.161162, err_t_domain: 0.887096
# epoch: 0, [iter: 13 / all 48], err_s_label: 0.969784, err_s_domain: 1.171744, err_t_domain: 0.849442
# epoch: 0, [iter: 14 / all 48], err_s_label: 1.001713, err_s_domain: 1.224034, err_t_domain: 0.823908
# epoch: 0, [iter: 15 / all 48], err_s_label: 0.943603, err_s_domain: 1.278823, err_t_domain: 0.791890
# epoch: 0, [iter: 16 / all 48], err_s_label: 0.992862, err_s_domain: 1.302257, err_t_domain: 0.747868
# epoch: 0, [iter: 17 / all 48], err_s_label: 0.858343, err_s_domain: 1.453882, err_t_domain: 0.710074
# epoch: 0, [iter: 18 / all 48], err_s_label: 0.731173, err_s_domain: 1.357816, err_t_domain: 0.701742
# epoch: 0, [iter: 19 / all 48], err_s_label: 0.846285, err_s_domain: 1.387461, err_t_domain: 0.678897
# epoch: 0, [iter: 20 / all 48], err_s_label: 0.867261, err_s_domain: 1.494143, err_t_domain: 0.675075
# epoch: 0, [iter: 21 / all 48], err_s_label: 0.803772, err_s_domain: 1.505051, err_t_domain: 0.662608
# epoch: 0, [iter: 22 / all 48], err_s_label: 0.699991, err_s_domain: 1.526300, err_t_domain: 0.653950
# epoch: 0, [iter: 23 / all 48], err_s_label: 0.722804, err_s_domain: 1.546091, err_t_domain: 0.650581
# epoch: 0, [iter: 24 / all 48], err_s_label: 0.658326, err_s_domain: 1.604934, err_t_domain: 0.637577
# epoch: 0, [iter: 25 / all 48], err_s_label: 0.719291, err_s_domain: 1.728915, err_t_domain: 0.636397
# epoch: 0, [iter: 26 / all 48], err_s_label: 0.768505, err_s_domain: 1.646163, err_t_domain: 0.608001
# epoch: 0, [iter: 27 / all 48], err_s_label: 0.674475, err_s_domain: 1.825933, err_t_domain: 0.593159
# epoch: 0, [iter: 28 / all 48], err_s_label: 0.667531, err_s_domain: 1.848754, err_t_domain: 0.595837
# epoch: 0, [iter: 29 / all 48], err_s_label: 0.632050, err_s_domain: 1.908485, err_t_domain: 0.544133
# epoch: 0, [iter: 30 / all 48], err_s_label: 0.653631, err_s_domain: 1.936469, err_t_domain: 0.579924
# epoch: 0, [iter: 31 / all 48], err_s_label: 0.521521, err_s_domain: 2.066224, err_t_domain: 0.583700
# epoch: 0, [iter: 32 / all 48], err_s_label: 0.620150, err_s_domain: 2.109285, err_t_domain: 0.581569
# epoch: 0, [iter: 33 / all 48], err_s_label: 0.553647, err_s_domain: 2.147501, err_t_domain: 0.602195
# epoch: 0, [iter: 34 / all 48], err_s_label: 0.713386, err_s_domain: 2.223949, err_t_domain: 0.608311
# epoch: 0, [iter: 35 / all 48], err_s_label: 0.552909, err_s_domain: 2.306795, err_t_domain: 0.626196
# epoch: 0, [iter: 36 / all 48], err_s_label: 0.715826, err_s_domain: 2.323082, err_t_domain: 0.615692
# epoch: 0, [iter: 37 / all 48], err_s_label: 0.537548, err_s_domain: 2.254376, err_t_domain: 0.631255
# epoch: 0, [iter: 38 / all 48], err_s_label: 0.594747, err_s_domain: 2.244056, err_t_domain: 0.626143
# epoch: 0, [iter: 39 / all 48], err_s_label: 0.716722, err_s_domain: 2.263961, err_t_domain: 0.634675
# epoch: 0, [iter: 40 / all 48], err_s_label: 0.509156, err_s_domain: 2.193825, err_t_domain: 0.655182
# epoch: 0, [iter: 41 / all 48], err_s_label: 0.640429, err_s_domain: 2.223425, err_t_domain: 0.653757
# epoch: 0, [iter: 42 / all 48], err_s_label: 0.531164, err_s_domain: 2.194815, err_t_domain: 0.662647
# epoch: 0, [iter: 43 / all 48], err_s_label: 0.637364, err_s_domain: 2.174071, err_t_domain: 0.672620
# epoch: 0, [iter: 44 / all 48], err_s_label: 0.416717, err_s_domain: 2.103929, err_t_domain: 0.672543
# epoch: 0, [iter: 45 / all 48], err_s_label: 0.492276, err_s_domain: 2.059945, err_t_domain: 0.683423
# epoch: 0, [iter: 46 / all 48], err_s_label: 0.514089, err_s_domain: 2.043984, err_t_domain: 0.684508
# epoch: 0, [iter: 47 / all 48], err_s_label: 0.790091, err_s_domain: 2.020197, err_t_domain: 0.698139
# epoch: 0, [iter: 48 / all 48], err_s_label: 0.707263, err_s_domain: 1.972425, err_t_domain: 0.695356
# epoch: 0, accuracy of the train dataset: 0.562026
# epoch: 0, accuracy of the test dataset: 0.431153
# epoch: 1, [iter: 1 / all 48], err_s_label: 0.338349, err_s_domain: 2.039950, err_t_domain: 0.712104
# epoch: 1, [iter: 2 / all 48], err_s_label: 0.397723, err_s_domain: 2.110920, err_t_domain: 0.710066
# epoch: 1, [iter: 3 / all 48], err_s_label: 0.460118, err_s_domain: 1.997370, err_t_domain: 0.711929
# epoch: 1, [iter: 4 / all 48], err_s_label: 0.574757, err_s_domain: 2.020798, err_t_domain: 0.713062
# epoch: 1, [iter: 5 / all 48], err_s_label: 0.610320, err_s_domain: 2.016960, err_t_domain: 0.712779
# epoch: 1, [iter: 6 / all 48], err_s_label: 0.526438, err_s_domain: 1.954435, err_t_domain: 0.717004
# epoch: 1, [iter: 7 / all 48], err_s_label: 0.367096, err_s_domain: 1.904381, err_t_domain: 0.701292
# epoch: 1, [iter: 8 / all 48], err_s_label: 0.431414, err_s_domain: 1.929413, err_t_domain: 0.706083
# epoch: 1, [iter: 9 / all 48], err_s_label: 0.441707, err_s_domain: 1.826574, err_t_domain: 0.701828
# epoch: 1, [iter: 10 / all 48], err_s_label: 0.363055, err_s_domain: 1.824242, err_t_domain: 0.700768
# epoch: 1, [iter: 11 / all 48], err_s_label: 0.302311, err_s_domain: 1.787396, err_t_domain: 0.708429
# epoch: 1, [iter: 12 / all 48], err_s_label: 0.523520, err_s_domain: 1.816590, err_t_domain: 0.693509
# epoch: 1, [iter: 13 / all 48], err_s_label: 0.461031, err_s_domain: 1.736297, err_t_domain: 0.682068
# epoch: 1, [iter: 14 / all 48], err_s_label: 0.411838, err_s_domain: 1.729591, err_t_domain: 0.682698
# epoch: 1, [iter: 15 / all 48], err_s_label: 0.407197, err_s_domain: 1.753553, err_t_domain: 0.676780
# epoch: 1, [iter: 16 / all 48], err_s_label: 0.412660, err_s_domain: 1.840717, err_t_domain: 0.685603
# epoch: 1, [iter: 17 / all 48], err_s_label: 0.298272, err_s_domain: 1.761366, err_t_domain: 0.687587
# epoch: 1, [iter: 18 / all 48], err_s_label: 0.375250, err_s_domain: 1.747905, err_t_domain: 0.671965
# epoch: 1, [iter: 19 / all 48], err_s_label: 0.450351, err_s_domain: 1.702135, err_t_domain: 0.677029
# epoch: 1, [iter: 20 / all 48], err_s_label: 0.339336, err_s_domain: 1.780002, err_t_domain: 0.675025
# epoch: 1, [iter: 21 / all 48], err_s_label: 0.448804, err_s_domain: 1.758187, err_t_domain: 0.678250
# epoch: 1, [iter: 22 / all 48], err_s_label: 0.375870, err_s_domain: 1.693710, err_t_domain: 0.663336
# epoch: 1, [iter: 23 / all 48], err_s_label: 0.409326, err_s_domain: 1.657554, err_t_domain: 0.674561
# epoch: 1, [iter: 24 / all 48], err_s_label: 0.458196, err_s_domain: 1.684358, err_t_domain: 0.663286
# epoch: 1, [iter: 25 / all 48], err_s_label: 0.379540, err_s_domain: 1.672689, err_t_domain: 0.660705
# epoch: 1, [iter: 26 / all 48], err_s_label: 0.374574, err_s_domain: 1.602515, err_t_domain: 0.684315
# epoch: 1, [iter: 27 / all 48], err_s_label: 0.469685, err_s_domain: 1.641469, err_t_domain: 0.664183
# epoch: 1, [iter: 28 / all 48], err_s_label: 0.326198, err_s_domain: 1.676204, err_t_domain: 0.681431
# epoch: 1, [iter: 29 / all 48], err_s_label: 0.414434, err_s_domain: 1.602472, err_t_domain: 0.692636
# epoch: 1, [iter: 30 / all 48], err_s_label: 0.343187, err_s_domain: 1.667742, err_t_domain: 0.675698
# epoch: 1, [iter: 31 / all 48], err_s_label: 0.440868, err_s_domain: 1.649396, err_t_domain: 0.664326
# epoch: 1, [iter: 32 / all 48], err_s_label: 0.488254, err_s_domain: 1.651308, err_t_domain: 0.670923
# epoch: 1, [iter: 33 / all 48], err_s_label: 0.296383, err_s_domain: 1.667567, err_t_domain: 0.654470
# epoch: 1, [iter: 34 / all 48], err_s_label: 0.341790, err_s_domain: 1.652162, err_t_domain: 0.653156
# epoch: 1, [iter: 35 / all 48], err_s_label: 0.327240, err_s_domain: 1.614463, err_t_domain: 0.675571
# epoch: 1, [iter: 36 / all 48], err_s_label: 0.459768, err_s_domain: 1.601525, err_t_domain: 0.658968
# epoch: 1, [iter: 37 / all 48], err_s_label: 0.425687, err_s_domain: 1.687662, err_t_domain: 0.663334
# epoch: 1, [iter: 38 / all 48], err_s_label: 0.410491, err_s_domain: 1.654779, err_t_domain: 0.679552
# epoch: 1, [iter: 39 / all 48], err_s_label: 0.370073, err_s_domain: 1.734530, err_t_domain: 0.661520
# epoch: 1, [iter: 40 / all 48], err_s_label: 0.275536, err_s_domain: 1.627103, err_t_domain: 0.649767
# epoch: 1, [iter: 41 / all 48], err_s_label: 0.276332, err_s_domain: 1.620910, err_t_domain: 0.669229
# epoch: 1, [iter: 42 / all 48], err_s_label: 0.348069, err_s_domain: 1.644741, err_t_domain: 0.680121
# epoch: 1, [iter: 43 / all 48], err_s_label: 0.329270, err_s_domain: 1.661198, err_t_domain: 0.685378
# epoch: 1, [iter: 44 / all 48], err_s_label: 0.264160, err_s_domain: 1.751319, err_t_domain: 0.705924
# epoch: 1, [iter: 45 / all 48], err_s_label: 0.450485, err_s_domain: 1.749386, err_t_domain: 0.698643
# epoch: 1, [iter: 46 / all 48], err_s_label: 0.446423, err_s_domain: 1.701860, err_t_domain: 0.712669
# epoch: 1, [iter: 47 / all 48], err_s_label: 0.385048, err_s_domain: 1.695438, err_t_domain: 0.674854
# epoch: 1, [iter: 48 / all 48], err_s_label: 0.463550, err_s_domain: 1.824512, err_t_domain: 0.691043
# epoch: 1, accuracy of the train dataset: 0.748928
# epoch: 1, accuracy of the test dataset: 0.625350
# epoch: 2, [iter: 1 / all 48], err_s_label: 0.336214, err_s_domain: 1.759988, err_t_domain: 0.682042
# epoch: 2, [iter: 2 / all 48], err_s_label: 0.289163, err_s_domain: 1.870748, err_t_domain: 0.677576
# epoch: 2, [iter: 3 / all 48], err_s_label: 0.179829, err_s_domain: 1.896121, err_t_domain: 0.685162
# epoch: 2, [iter: 4 / all 48], err_s_label: 0.319345, err_s_domain: 1.913347, err_t_domain: 0.697336
# epoch: 2, [iter: 5 / all 48], err_s_label: 0.216842, err_s_domain: 1.903001, err_t_domain: 0.653576
# epoch: 2, [iter: 6 / all 48], err_s_label: 0.193616, err_s_domain: 1.968699, err_t_domain: 0.661887
# epoch: 2, [iter: 7 / all 48], err_s_label: 0.236184, err_s_domain: 1.999841, err_t_domain: 0.645144
# epoch: 2, [iter: 8 / all 48], err_s_label: 0.259979, err_s_domain: 2.093855, err_t_domain: 0.659481
# epoch: 2, [iter: 9 / all 48], err_s_label: 0.373725, err_s_domain: 2.048224, err_t_domain: 0.691883
# epoch: 2, [iter: 10 / all 48], err_s_label: 0.188641, err_s_domain: 2.023700, err_t_domain: 0.655637
# epoch: 2, [iter: 11 / all 48], err_s_label: 0.203232, err_s_domain: 2.109991, err_t_domain: 0.663304
# epoch: 2, [iter: 12 / all 48], err_s_label: 0.227961, err_s_domain: 2.054977, err_t_domain: 0.660222
# epoch: 2, [iter: 13 / all 48], err_s_label: 0.306416, err_s_domain: 2.029295, err_t_domain: 0.623583
# epoch: 2, [iter: 14 / all 48], err_s_label: 0.326541, err_s_domain: 2.063432, err_t_domain: 0.652943
# epoch: 2, [iter: 15 / all 48], err_s_label: 0.286194, err_s_domain: 2.003180, err_t_domain: 0.665221
# epoch: 2, [iter: 16 / all 48], err_s_label: 0.279292, err_s_domain: 2.017220, err_t_domain: 0.665862
# epoch: 2, [iter: 17 / all 48], err_s_label: 0.439645, err_s_domain: 1.975694, err_t_domain: 0.676871
# epoch: 2, [iter: 18 / all 48], err_s_label: 0.278536, err_s_domain: 1.976650, err_t_domain: 0.684544
# epoch: 2, [iter: 19 / all 48], err_s_label: 0.260017, err_s_domain: 1.935163, err_t_domain: 0.675072
# epoch: 2, [iter: 20 / all 48], err_s_label: 0.269544, err_s_domain: 1.931905, err_t_domain: 0.683540
# epoch: 2, [iter: 21 / all 48], err_s_label: 0.357936, err_s_domain: 1.927642, err_t_domain: 0.683317
# epoch: 2, [iter: 22 / all 48], err_s_label: 0.246399, err_s_domain: 1.845654, err_t_domain: 0.687740
# epoch: 2, [iter: 23 / all 48], err_s_label: 0.153513, err_s_domain: 1.831128, err_t_domain: 0.692026
# epoch: 2, [iter: 24 / all 48], err_s_label: 0.233628, err_s_domain: 1.814480, err_t_domain: 0.693112
# epoch: 2, [iter: 25 / all 48], err_s_label: 0.217518, err_s_domain: 1.807765, err_t_domain: 0.700311
# epoch: 2, [iter: 26 / all 48], err_s_label: 0.405109, err_s_domain: 1.814785, err_t_domain: 0.704189
# epoch: 2, [iter: 27 / all 48], err_s_label: 0.234847, err_s_domain: 1.772534, err_t_domain: 0.707677
# epoch: 2, [iter: 28 / all 48], err_s_label: 0.243505, err_s_domain: 1.711405, err_t_domain: 0.687500
# epoch: 2, [iter: 29 / all 48], err_s_label: 0.249598, err_s_domain: 1.749099, err_t_domain: 0.713780
# epoch: 2, [iter: 30 / all 48], err_s_label: 0.246989, err_s_domain: 1.681233, err_t_domain: 0.715983
# epoch: 2, [iter: 31 / all 48], err_s_label: 0.322890, err_s_domain: 1.697020, err_t_domain: 0.701751
# epoch: 2, [iter: 32 / all 48], err_s_label: 0.215506, err_s_domain: 1.660905, err_t_domain: 0.707901
# epoch: 2, [iter: 33 / all 48], err_s_label: 0.247814, err_s_domain: 1.667622, err_t_domain: 0.726874
# epoch: 2, [iter: 34 / all 48], err_s_label: 0.264014, err_s_domain: 1.631991, err_t_domain: 0.716307
# epoch: 2, [iter: 35 / all 48], err_s_label: 0.298133, err_s_domain: 1.613542, err_t_domain: 0.722893
# epoch: 2, [iter: 36 / all 48], err_s_label: 0.269538, err_s_domain: 1.677993, err_t_domain: 0.694771
# epoch: 2, [iter: 37 / all 48], err_s_label: 0.207471, err_s_domain: 1.667232, err_t_domain: 0.721858
# epoch: 2, [iter: 38 / all 48], err_s_label: 0.329234, err_s_domain: 1.670027, err_t_domain: 0.719909
# epoch: 2, [iter: 39 / all 48], err_s_label: 0.301263, err_s_domain: 1.653945, err_t_domain: 0.717908
# epoch: 2, [iter: 40 / all 48], err_s_label: 0.291778, err_s_domain: 1.680048, err_t_domain: 0.702876
# epoch: 2, [iter: 41 / all 48], err_s_label: 0.263156, err_s_domain: 1.636484, err_t_domain: 0.692954
# epoch: 2, [iter: 42 / all 48], err_s_label: 0.287311, err_s_domain: 1.693048, err_t_domain: 0.698834
# epoch: 2, [iter: 43 / all 48], err_s_label: 0.272816, err_s_domain: 1.663603, err_t_domain: 0.702798
# epoch: 2, [iter: 44 / all 48], err_s_label: 0.171785, err_s_domain: 1.671891, err_t_domain: 0.684077
# epoch: 2, [iter: 45 / all 48], err_s_label: 0.277423, err_s_domain: 1.670868, err_t_domain: 0.696607
# epoch: 2, [iter: 46 / all 48], err_s_label: 0.166718, err_s_domain: 1.696959, err_t_domain: 0.684125
# epoch: 2, [iter: 47 / all 48], err_s_label: 0.154347, err_s_domain: 1.682861, err_t_domain: 0.695625
# epoch: 2, [iter: 48 / all 48], err_s_label: 0.376480, err_s_domain: 1.697757, err_t_domain: 0.697523
# epoch: 2, accuracy of the train dataset: 0.866711
# epoch: 2, accuracy of the test dataset: 0.471367
# epoch: 3, [iter: 1 / all 48], err_s_label: 0.194344, err_s_domain: 1.669751, err_t_domain: 0.688834
# epoch: 3, [iter: 2 / all 48], err_s_label: 0.127459, err_s_domain: 1.702822, err_t_domain: 0.685925
# epoch: 3, [iter: 3 / all 48], err_s_label: 0.097955, err_s_domain: 1.648404, err_t_domain: 0.682270
# epoch: 3, [iter: 4 / all 48], err_s_label: 0.191745, err_s_domain: 1.770146, err_t_domain: 0.675833
# epoch: 3, [iter: 5 / all 48], err_s_label: 0.310603, err_s_domain: 1.793008, err_t_domain: 0.688340
# epoch: 3, [iter: 6 / all 48], err_s_label: 0.243613, err_s_domain: 1.850471, err_t_domain: 0.683925
# epoch: 3, [iter: 7 / all 48], err_s_label: 0.252085, err_s_domain: 1.781819, err_t_domain: 0.680841
# epoch: 3, [iter: 8 / all 48], err_s_label: 0.194416, err_s_domain: 1.781815, err_t_domain: 0.679074
# epoch: 3, [iter: 9 / all 48], err_s_label: 0.187009, err_s_domain: 1.826612, err_t_domain: 0.673415
# epoch: 3, [iter: 10 / all 48], err_s_label: 0.146591, err_s_domain: 1.741392, err_t_domain: 0.671655
# epoch: 3, [iter: 11 / all 48], err_s_label: 0.200056, err_s_domain: 1.807162, err_t_domain: 0.689386
# epoch: 3, [iter: 12 / all 48], err_s_label: 0.190438, err_s_domain: 1.843413, err_t_domain: 0.691602
# epoch: 3, [iter: 13 / all 48], err_s_label: 0.203068, err_s_domain: 1.813452, err_t_domain: 0.680433
# epoch: 3, [iter: 14 / all 48], err_s_label: 0.123791, err_s_domain: 1.818156, err_t_domain: 0.699708
# epoch: 3, [iter: 15 / all 48], err_s_label: 0.161068, err_s_domain: 1.826800, err_t_domain: 0.695606
# epoch: 3, [iter: 16 / all 48], err_s_label: 0.218720, err_s_domain: 1.846713, err_t_domain: 0.698799
# epoch: 3, [iter: 17 / all 48], err_s_label: 0.251128, err_s_domain: 1.792109, err_t_domain: 0.690385
# epoch: 3, [iter: 18 / all 48], err_s_label: 0.182699, err_s_domain: 1.845385, err_t_domain: 0.673126
# epoch: 3, [iter: 19 / all 48], err_s_label: 0.229018, err_s_domain: 1.811522, err_t_domain: 0.696611
# epoch: 3, [iter: 20 / all 48], err_s_label: 0.264356, err_s_domain: 1.811144, err_t_domain: 0.693552
# epoch: 3, [iter: 21 / all 48], err_s_label: 0.330747, err_s_domain: 1.809383, err_t_domain: 0.691452
# epoch: 3, [iter: 22 / all 48], err_s_label: 0.212213, err_s_domain: 1.812331, err_t_domain: 0.699871
# epoch: 3, [iter: 23 / all 48], err_s_label: 0.119900, err_s_domain: 1.783836, err_t_domain: 0.687645
# epoch: 3, [iter: 24 / all 48], err_s_label: 0.215875, err_s_domain: 1.809448, err_t_domain: 0.700531
# epoch: 3, [iter: 25 / all 48], err_s_label: 0.317406, err_s_domain: 1.846297, err_t_domain: 0.701231
# epoch: 3, [iter: 26 / all 48], err_s_label: 0.144925, err_s_domain: 1.787007, err_t_domain: 0.701638
# epoch: 3, [iter: 27 / all 48], err_s_label: 0.181122, err_s_domain: 1.797414, err_t_domain: 0.694020
# epoch: 3, [iter: 28 / all 48], err_s_label: 0.137463, err_s_domain: 1.815165, err_t_domain: 0.672122
# epoch: 3, [iter: 29 / all 48], err_s_label: 0.259887, err_s_domain: 1.871991, err_t_domain: 0.694853
# epoch: 3, [iter: 30 / all 48], err_s_label: 0.145633, err_s_domain: 1.758988, err_t_domain: 0.678798
# epoch: 3, [iter: 31 / all 48], err_s_label: 0.087756, err_s_domain: 1.793483, err_t_domain: 0.698518
# epoch: 3, [iter: 32 / all 48], err_s_label: 0.235923, err_s_domain: 1.756249, err_t_domain: 0.682033
# epoch: 3, [iter: 33 / all 48], err_s_label: 0.130492, err_s_domain: 1.826867, err_t_domain: 0.678174
# epoch: 3, [iter: 34 / all 48], err_s_label: 0.149532, err_s_domain: 1.876604, err_t_domain: 0.687800
# epoch: 3, [iter: 35 / all 48], err_s_label: 0.110667, err_s_domain: 1.774851, err_t_domain: 0.694526
# epoch: 3, [iter: 36 / all 48], err_s_label: 0.156756, err_s_domain: 1.802006, err_t_domain: 0.695397
# epoch: 3, [iter: 37 / all 48], err_s_label: 0.200164, err_s_domain: 1.811888, err_t_domain: 0.670123
# epoch: 3, [iter: 38 / all 48], err_s_label: 0.210564, err_s_domain: 1.829346, err_t_domain: 0.698646
# epoch: 3, [iter: 39 / all 48], err_s_label: 0.141427, err_s_domain: 1.780776, err_t_domain: 0.685968
# epoch: 3, [iter: 40 / all 48], err_s_label: 0.129523, err_s_domain: 1.806388, err_t_domain: 0.686274
# epoch: 3, [iter: 41 / all 48], err_s_label: 0.154480, err_s_domain: 1.828691, err_t_domain: 0.690079
# epoch: 3, [iter: 42 / all 48], err_s_label: 0.220388, err_s_domain: 1.794914, err_t_domain: 0.690169
# epoch: 3, [iter: 43 / all 48], err_s_label: 0.209255, err_s_domain: 1.789017, err_t_domain: 0.671556
# epoch: 3, [iter: 44 / all 48], err_s_label: 0.325291, err_s_domain: 1.781577, err_t_domain: 0.691420
# epoch: 3, [iter: 45 / all 48], err_s_label: 0.243191, err_s_domain: 1.811915, err_t_domain: 0.686623
# epoch: 3, [iter: 46 / all 48], err_s_label: 0.186663, err_s_domain: 1.782341, err_t_domain: 0.709615
# epoch: 3, [iter: 47 / all 48], err_s_label: 0.130803, err_s_domain: 1.752037, err_t_domain: 0.695260
# epoch: 3, [iter: 48 / all 48], err_s_label: 0.183222, err_s_domain: 1.846572, err_t_domain: 0.698475
# epoch: 3, accuracy of the train dataset: 0.723854
# epoch: 3, accuracy of the test dataset: 0.651820
# epoch: 4, [iter: 1 / all 48], err_s_label: 0.169633, err_s_domain: 1.753580, err_t_domain: 0.720212
# epoch: 4, [iter: 2 / all 48], err_s_label: 0.133522, err_s_domain: 1.744543, err_t_domain: 0.718231
# epoch: 4, [iter: 3 / all 48], err_s_label: 0.344653, err_s_domain: 1.792910, err_t_domain: 0.730598
# epoch: 4, [iter: 4 / all 48], err_s_label: 0.213617, err_s_domain: 1.802842, err_t_domain: 0.723950
# epoch: 4, [iter: 5 / all 48], err_s_label: 0.174527, err_s_domain: 1.742899, err_t_domain: 0.698326
# epoch: 4, [iter: 6 / all 48], err_s_label: 0.162078, err_s_domain: 1.800378, err_t_domain: 0.722365
# epoch: 4, [iter: 7 / all 48], err_s_label: 0.152118, err_s_domain: 1.735519, err_t_domain: 0.716115
# epoch: 4, [iter: 8 / all 48], err_s_label: 0.138931, err_s_domain: 1.736691, err_t_domain: 0.709969
# epoch: 4, [iter: 9 / all 48], err_s_label: 0.193958, err_s_domain: 1.725284, err_t_domain: 0.726994
# epoch: 4, [iter: 10 / all 48], err_s_label: 0.183441, err_s_domain: 1.755679, err_t_domain: 0.703684
# epoch: 4, [iter: 11 / all 48], err_s_label: 0.195493, err_s_domain: 1.734546, err_t_domain: 0.707879
# epoch: 4, [iter: 12 / all 48], err_s_label: 0.148227, err_s_domain: 1.757459, err_t_domain: 0.705423
# epoch: 4, [iter: 13 / all 48], err_s_label: 0.115312, err_s_domain: 1.704791, err_t_domain: 0.686471
# epoch: 4, [iter: 14 / all 48], err_s_label: 0.134362, err_s_domain: 1.747196, err_t_domain: 0.696383
# epoch: 4, [iter: 15 / all 48], err_s_label: 0.218301, err_s_domain: 1.760357, err_t_domain: 0.701825
# epoch: 4, [iter: 16 / all 48], err_s_label: 0.194531, err_s_domain: 1.768198, err_t_domain: 0.690988
# epoch: 4, [iter: 17 / all 48], err_s_label: 0.164004, err_s_domain: 1.790740, err_t_domain: 0.689909
# epoch: 4, [iter: 18 / all 48], err_s_label: 0.133626, err_s_domain: 1.772635, err_t_domain: 0.692811
# epoch: 4, [iter: 19 / all 48], err_s_label: 0.150411, err_s_domain: 1.785771, err_t_domain: 0.691178
# epoch: 4, [iter: 20 / all 48], err_s_label: 0.139732, err_s_domain: 1.783910, err_t_domain: 0.689289
# epoch: 4, [iter: 21 / all 48], err_s_label: 0.116706, err_s_domain: 1.749026, err_t_domain: 0.685627
# epoch: 4, [iter: 22 / all 48], err_s_label: 0.210271, err_s_domain: 1.769553, err_t_domain: 0.681598
# epoch: 4, [iter: 23 / all 48], err_s_label: 0.140839, err_s_domain: 1.781403, err_t_domain: 0.692820
# epoch: 4, [iter: 24 / all 48], err_s_label: 0.112287, err_s_domain: 1.791679, err_t_domain: 0.695167
# epoch: 4, [iter: 25 / all 48], err_s_label: 0.145124, err_s_domain: 1.751173, err_t_domain: 0.709045
# epoch: 4, [iter: 26 / all 48], err_s_label: 0.150084, err_s_domain: 1.770286, err_t_domain: 0.680541
# epoch: 4, [iter: 27 / all 48], err_s_label: 0.177890, err_s_domain: 1.802750, err_t_domain: 0.697038
# epoch: 4, [iter: 28 / all 48], err_s_label: 0.156624, err_s_domain: 1.813567, err_t_domain: 0.679975
# epoch: 4, [iter: 29 / all 48], err_s_label: 0.236530, err_s_domain: 1.771082, err_t_domain: 0.686367
# epoch: 4, [iter: 30 / all 48], err_s_label: 0.132130, err_s_domain: 1.737624, err_t_domain: 0.702785
# epoch: 4, [iter: 31 / all 48], err_s_label: 0.225477, err_s_domain: 1.767885, err_t_domain: 0.695178
# epoch: 4, [iter: 32 / all 48], err_s_label: 0.124431, err_s_domain: 1.762951, err_t_domain: 0.701798
# epoch: 4, [iter: 33 / all 48], err_s_label: 0.168127, err_s_domain: 1.724253, err_t_domain: 0.740139
# epoch: 4, [iter: 34 / all 48], err_s_label: 0.162899, err_s_domain: 1.722192, err_t_domain: 0.691693
# epoch: 4, [iter: 35 / all 48], err_s_label: 0.093310, err_s_domain: 1.739008, err_t_domain: 0.730298
# epoch: 4, [iter: 36 / all 48], err_s_label: 0.156154, err_s_domain: 1.736966, err_t_domain: 0.717215
# epoch: 4, [iter: 37 / all 48], err_s_label: 0.208241, err_s_domain: 1.727786, err_t_domain: 0.696804
# epoch: 4, [iter: 38 / all 48], err_s_label: 0.119757, err_s_domain: 1.716691, err_t_domain: 0.714570
# epoch: 4, [iter: 39 / all 48], err_s_label: 0.092489, err_s_domain: 1.691286, err_t_domain: 0.711497
# epoch: 4, [iter: 40 / all 48], err_s_label: 0.204240, err_s_domain: 1.763145, err_t_domain: 0.734267
# epoch: 4, [iter: 41 / all 48], err_s_label: 0.179677, err_s_domain: 1.781179, err_t_domain: 0.700604
# epoch: 4, [iter: 42 / all 48], err_s_label: 0.187772, err_s_domain: 1.745160, err_t_domain: 0.719909
# epoch: 4, [iter: 43 / all 48], err_s_label: 0.144464, err_s_domain: 1.733963, err_t_domain: 0.709281
# epoch: 4, [iter: 44 / all 48], err_s_label: 0.141842, err_s_domain: 1.698716, err_t_domain: 0.705640
# epoch: 4, [iter: 45 / all 48], err_s_label: 0.151324, err_s_domain: 1.740595, err_t_domain: 0.735624
# epoch: 4, [iter: 46 / all 48], err_s_label: 0.152148, err_s_domain: 1.711387, err_t_domain: 0.704381
# epoch: 4, [iter: 47 / all 48], err_s_label: 0.173828, err_s_domain: 1.714408, err_t_domain: 0.724021
# epoch: 4, [iter: 48 / all 48], err_s_label: 0.346338, err_s_domain: 1.714397, err_t_domain: 0.720239
# epoch: 4, accuracy of the train dataset: 0.901023
# epoch: 4, accuracy of the test dataset: 0.651311
# epoch: 5, [iter: 1 / all 48], err_s_label: 0.157649, err_s_domain: 1.690893, err_t_domain: 0.712568
# epoch: 5, [iter: 2 / all 48], err_s_label: 0.159692, err_s_domain: 1.722013, err_t_domain: 0.730823
# epoch: 5, [iter: 3 / all 48], err_s_label: 0.089385, err_s_domain: 1.702846, err_t_domain: 0.734265
# epoch: 5, [iter: 4 / all 48], err_s_label: 0.144052, err_s_domain: 1.750026, err_t_domain: 0.733649
# epoch: 5, [iter: 5 / all 48], err_s_label: 0.125031, err_s_domain: 1.725162, err_t_domain: 0.750586
# epoch: 5, [iter: 6 / all 48], err_s_label: 0.170645, err_s_domain: 1.723703, err_t_domain: 0.729276
# epoch: 5, [iter: 7 / all 48], err_s_label: 0.095487, err_s_domain: 1.717599, err_t_domain: 0.727086
# epoch: 5, [iter: 8 / all 48], err_s_label: 0.121962, err_s_domain: 1.757396, err_t_domain: 0.705615
# epoch: 5, [iter: 9 / all 48], err_s_label: 0.177135, err_s_domain: 1.752737, err_t_domain: 0.733537
# epoch: 5, [iter: 10 / all 48], err_s_label: 0.171280, err_s_domain: 1.752291, err_t_domain: 0.717884
# epoch: 5, [iter: 11 / all 48], err_s_label: 0.123273, err_s_domain: 1.841600, err_t_domain: 0.713236
# epoch: 5, [iter: 12 / all 48], err_s_label: 0.097749, err_s_domain: 1.805893, err_t_domain: 0.709030
# epoch: 5, [iter: 13 / all 48], err_s_label: 0.178633, err_s_domain: 1.795846, err_t_domain: 0.710224
# epoch: 5, [iter: 14 / all 48], err_s_label: 0.090445, err_s_domain: 1.860071, err_t_domain: 0.715426
# epoch: 5, [iter: 15 / all 48], err_s_label: 0.092047, err_s_domain: 1.833904, err_t_domain: 0.715335
# epoch: 5, [iter: 16 / all 48], err_s_label: 0.206100, err_s_domain: 1.826887, err_t_domain: 0.713781
# epoch: 5, [iter: 17 / all 48], err_s_label: 0.101972, err_s_domain: 1.814355, err_t_domain: 0.708216
# epoch: 5, [iter: 18 / all 48], err_s_label: 0.195493, err_s_domain: 1.818510, err_t_domain: 0.715723
# epoch: 5, [iter: 19 / all 48], err_s_label: 0.104263, err_s_domain: 1.849773, err_t_domain: 0.713967
# epoch: 5, [iter: 20 / all 48], err_s_label: 0.135893, err_s_domain: 1.820864, err_t_domain: 0.743277
# epoch: 5, [iter: 21 / all 48], err_s_label: 0.130355, err_s_domain: 1.836854, err_t_domain: 0.709924
# epoch: 5, [iter: 22 / all 48], err_s_label: 0.143833, err_s_domain: 1.772716, err_t_domain: 0.711318
# epoch: 5, [iter: 23 / all 48], err_s_label: 0.045496, err_s_domain: 1.782952, err_t_domain: 0.715050
# epoch: 5, [iter: 24 / all 48], err_s_label: 0.090876, err_s_domain: 1.839524, err_t_domain: 0.724763
# epoch: 5, [iter: 25 / all 48], err_s_label: 0.161647, err_s_domain: 1.832578, err_t_domain: 0.737540
# epoch: 5, [iter: 26 / all 48], err_s_label: 0.109903, err_s_domain: 1.823755, err_t_domain: 0.705026
# epoch: 5, [iter: 27 / all 48], err_s_label: 0.131363, err_s_domain: 1.840129, err_t_domain: 0.714580
# epoch: 5, [iter: 28 / all 48], err_s_label: 0.131709, err_s_domain: 1.810663, err_t_domain: 0.725506
# epoch: 5, [iter: 29 / all 48], err_s_label: 0.246979, err_s_domain: 1.855300, err_t_domain: 0.714393
# epoch: 5, [iter: 30 / all 48], err_s_label: 0.075651, err_s_domain: 1.815448, err_t_domain: 0.737813
# epoch: 5, [iter: 31 / all 48], err_s_label: 0.240008, err_s_domain: 1.882966, err_t_domain: 0.749966
# epoch: 5, [iter: 32 / all 48], err_s_label: 0.227788, err_s_domain: 1.839990, err_t_domain: 0.732665
# epoch: 5, [iter: 33 / all 48], err_s_label: 0.212529, err_s_domain: 1.870667, err_t_domain: 0.737882
# epoch: 5, [iter: 34 / all 48], err_s_label: 0.130853, err_s_domain: 1.930132, err_t_domain: 0.751515
# epoch: 5, [iter: 35 / all 48], err_s_label: 0.194462, err_s_domain: 1.959651, err_t_domain: 0.744298
# epoch: 5, [iter: 36 / all 48], err_s_label: 0.222148, err_s_domain: 1.985992, err_t_domain: 0.732891
# epoch: 5, [iter: 37 / all 48], err_s_label: 0.297675, err_s_domain: 1.972204, err_t_domain: 0.706683
# epoch: 5, [iter: 38 / all 48], err_s_label: 0.107518, err_s_domain: 1.934289, err_t_domain: 0.727496
# epoch: 5, [iter: 39 / all 48], err_s_label: 0.106316, err_s_domain: 1.856570, err_t_domain: 0.732377
# epoch: 5, [iter: 40 / all 48], err_s_label: 0.155630, err_s_domain: 1.839681, err_t_domain: 0.744393
# epoch: 5, [iter: 41 / all 48], err_s_label: 0.180743, err_s_domain: 1.841027, err_t_domain: 0.736708
# epoch: 5, [iter: 42 / all 48], err_s_label: 0.284402, err_s_domain: 1.840366, err_t_domain: 0.717246
# epoch: 5, [iter: 43 / all 48], err_s_label: 0.119928, err_s_domain: 1.829607, err_t_domain: 0.740031
# epoch: 5, [iter: 44 / all 48], err_s_label: 0.203893, err_s_domain: 1.829539, err_t_domain: 0.728782
# epoch: 5, [iter: 45 / all 48], err_s_label: 0.112174, err_s_domain: 1.765877, err_t_domain: 0.721299
# epoch: 5, [iter: 46 / all 48], err_s_label: 0.133963, err_s_domain: 1.825200, err_t_domain: 0.732430
# epoch: 5, [iter: 47 / all 48], err_s_label: 0.166077, err_s_domain: 1.778463, err_t_domain: 0.734952
# epoch: 5, [iter: 48 / all 48], err_s_label: 0.154992, err_s_domain: 1.767221, err_t_domain: 0.742006
# epoch: 5, accuracy of the train dataset: 0.917519
# epoch: 5, accuracy of the test dataset: 0.673963
# epoch: 6, [iter: 1 / all 48], err_s_label: 0.150651, err_s_domain: 1.750866, err_t_domain: 0.764781
# epoch: 6, [iter: 2 / all 48], err_s_label: 0.167134, err_s_domain: 1.755797, err_t_domain: 0.755538
# epoch: 6, [iter: 3 / all 48], err_s_label: 0.229203, err_s_domain: 1.732833, err_t_domain: 0.749967
# epoch: 6, [iter: 4 / all 48], err_s_label: 0.142497, err_s_domain: 1.681528, err_t_domain: 0.770042
# epoch: 6, [iter: 5 / all 48], err_s_label: 0.086320, err_s_domain: 1.696247, err_t_domain: 0.753489
# epoch: 6, [iter: 6 / all 48], err_s_label: 0.144055, err_s_domain: 1.704285, err_t_domain: 0.773739
# epoch: 6, [iter: 7 / all 48], err_s_label: 0.049829, err_s_domain: 1.681921, err_t_domain: 0.774250
# epoch: 6, [iter: 8 / all 48], err_s_label: 0.055136, err_s_domain: 1.669934, err_t_domain: 0.762782
# epoch: 6, [iter: 9 / all 48], err_s_label: 0.201372, err_s_domain: 1.671591, err_t_domain: 0.758764
# epoch: 6, [iter: 10 / all 48], err_s_label: 0.178658, err_s_domain: 1.665245, err_t_domain: 0.770772
# epoch: 6, [iter: 11 / all 48], err_s_label: 0.133174, err_s_domain: 1.646392, err_t_domain: 0.752630
# epoch: 6, [iter: 12 / all 48], err_s_label: 0.124355, err_s_domain: 1.713262, err_t_domain: 0.758764
# epoch: 6, [iter: 13 / all 48], err_s_label: 0.110746, err_s_domain: 1.678361, err_t_domain: 0.767141
# epoch: 6, [iter: 14 / all 48], err_s_label: 0.094652, err_s_domain: 1.711177, err_t_domain: 0.768695
# epoch: 6, [iter: 15 / all 48], err_s_label: 0.069566, err_s_domain: 1.762178, err_t_domain: 0.752789
# epoch: 6, [iter: 16 / all 48], err_s_label: 0.104929, err_s_domain: 1.725055, err_t_domain: 0.738174
# epoch: 6, [iter: 17 / all 48], err_s_label: 0.116160, err_s_domain: 1.730863, err_t_domain: 0.760037
# epoch: 6, [iter: 18 / all 48], err_s_label: 0.154097, err_s_domain: 1.751205, err_t_domain: 0.773193
# epoch: 6, [iter: 19 / all 48], err_s_label: 0.093912, err_s_domain: 1.766611, err_t_domain: 0.750642
# epoch: 6, [iter: 20 / all 48], err_s_label: 0.059518, err_s_domain: 1.759944, err_t_domain: 0.757732
# epoch: 6, [iter: 21 / all 48], err_s_label: 0.090680, err_s_domain: 1.785873, err_t_domain: 0.751112
# epoch: 6, [iter: 22 / all 48], err_s_label: 0.098806, err_s_domain: 1.794701, err_t_domain: 0.735848
# epoch: 6, [iter: 23 / all 48], err_s_label: 0.106197, err_s_domain: 1.795814, err_t_domain: 0.754991
# epoch: 6, [iter: 24 / all 48], err_s_label: 0.121383, err_s_domain: 1.800488, err_t_domain: 0.733279
# epoch: 6, [iter: 25 / all 48], err_s_label: 0.079276, err_s_domain: 1.835622, err_t_domain: 0.739513
# epoch: 6, [iter: 26 / all 48], err_s_label: 0.138922, err_s_domain: 1.837541, err_t_domain: 0.739623
# epoch: 6, [iter: 27 / all 48], err_s_label: 0.084504, err_s_domain: 1.890547, err_t_domain: 0.723333
# epoch: 6, [iter: 28 / all 48], err_s_label: 0.197879, err_s_domain: 1.899318, err_t_domain: 0.750946
# epoch: 6, [iter: 29 / all 48], err_s_label: 0.094781, err_s_domain: 1.908996, err_t_domain: 0.746288
# epoch: 6, [iter: 30 / all 48], err_s_label: 0.099594, err_s_domain: 1.913873, err_t_domain: 0.737612
# epoch: 6, [iter: 31 / all 48], err_s_label: 0.112493, err_s_domain: 1.895947, err_t_domain: 0.729447
# epoch: 6, [iter: 32 / all 48], err_s_label: 0.065408, err_s_domain: 1.942438, err_t_domain: 0.739039
# epoch: 6, [iter: 33 / all 48], err_s_label: 0.150519, err_s_domain: 1.902328, err_t_domain: 0.745206
# epoch: 6, [iter: 34 / all 48], err_s_label: 0.085806, err_s_domain: 1.893915, err_t_domain: 0.741883
# epoch: 6, [iter: 35 / all 48], err_s_label: 0.111626, err_s_domain: 1.946979, err_t_domain: 0.737635
# epoch: 6, [iter: 36 / all 48], err_s_label: 0.188869, err_s_domain: 1.921152, err_t_domain: 0.731415
# epoch: 6, [iter: 37 / all 48], err_s_label: 0.091104, err_s_domain: 1.914215, err_t_domain: 0.756047
# epoch: 6, [iter: 38 / all 48], err_s_label: 0.098741, err_s_domain: 1.883715, err_t_domain: 0.747048
# epoch: 6, [iter: 39 / all 48], err_s_label: 0.129496, err_s_domain: 1.870891, err_t_domain: 0.760382
# epoch: 6, [iter: 40 / all 48], err_s_label: 0.082898, err_s_domain: 1.871274, err_t_domain: 0.746949
# epoch: 6, [iter: 41 / all 48], err_s_label: 0.123790, err_s_domain: 1.872769, err_t_domain: 0.747614
# epoch: 6, [iter: 42 / all 48], err_s_label: 0.064068, err_s_domain: 1.888415, err_t_domain: 0.756458
# epoch: 6, [iter: 43 / all 48], err_s_label: 0.024135, err_s_domain: 1.825527, err_t_domain: 0.782424
# epoch: 6, [iter: 44 / all 48], err_s_label: 0.202775, err_s_domain: 1.834919, err_t_domain: 0.796950
# epoch: 6, [iter: 45 / all 48], err_s_label: 0.107559, err_s_domain: 1.816683, err_t_domain: 0.764629
# epoch: 6, [iter: 46 / all 48], err_s_label: 0.093550, err_s_domain: 1.786518, err_t_domain: 0.796767
# epoch: 6, [iter: 47 / all 48], err_s_label: 0.144537, err_s_domain: 1.840006, err_t_domain: 0.798242
# epoch: 6, [iter: 48 / all 48], err_s_label: 0.185951, err_s_domain: 1.795778, err_t_domain: 0.784824
# epoch: 6, accuracy of the train dataset: 0.856318
# epoch: 6, accuracy of the test dataset: 0.659201
# epoch: 7, [iter: 1 / all 48], err_s_label: 0.043312, err_s_domain: 1.686145, err_t_domain: 0.785300
# epoch: 7, [iter: 2 / all 48], err_s_label: 0.083603, err_s_domain: 1.720776, err_t_domain: 0.786430
# epoch: 7, [iter: 3 / all 48], err_s_label: 0.125163, err_s_domain: 1.723705, err_t_domain: 0.790890
# epoch: 7, [iter: 4 / all 48], err_s_label: 0.135077, err_s_domain: 1.695382, err_t_domain: 0.790609
# epoch: 7, [iter: 5 / all 48], err_s_label: 0.156683, err_s_domain: 1.715727, err_t_domain: 0.789068
# epoch: 7, [iter: 6 / all 48], err_s_label: 0.132677, err_s_domain: 1.657462, err_t_domain: 0.805138
# epoch: 7, [iter: 7 / all 48], err_s_label: 0.036370, err_s_domain: 1.696141, err_t_domain: 0.800493
# epoch: 7, [iter: 8 / all 48], err_s_label: 0.076491, err_s_domain: 1.701644, err_t_domain: 0.784553
# epoch: 7, [iter: 9 / all 48], err_s_label: 0.064815, err_s_domain: 1.714368, err_t_domain: 0.779548
# epoch: 7, [iter: 10 / all 48], err_s_label: 0.119351, err_s_domain: 1.743012, err_t_domain: 0.765019
# epoch: 7, [iter: 11 / all 48], err_s_label: 0.027547, err_s_domain: 1.753109, err_t_domain: 0.784748
# epoch: 7, [iter: 12 / all 48], err_s_label: 0.071083, err_s_domain: 1.808089, err_t_domain: 0.775660
# epoch: 7, [iter: 13 / all 48], err_s_label: 0.050448, err_s_domain: 1.800040, err_t_domain: 0.774085
# epoch: 7, [iter: 14 / all 48], err_s_label: 0.190903, err_s_domain: 1.818990, err_t_domain: 0.780535
# epoch: 7, [iter: 15 / all 48], err_s_label: 0.139567, err_s_domain: 1.840503, err_t_domain: 0.793753
# epoch: 7, [iter: 16 / all 48], err_s_label: 0.213631, err_s_domain: 1.878156, err_t_domain: 0.800778
# epoch: 7, [iter: 17 / all 48], err_s_label: 0.074526, err_s_domain: 1.894524, err_t_domain: 0.797301
# epoch: 7, [iter: 18 / all 48], err_s_label: 0.081995, err_s_domain: 1.861900, err_t_domain: 0.783112
# epoch: 7, [iter: 19 / all 48], err_s_label: 0.177082, err_s_domain: 1.887711, err_t_domain: 0.775288
# epoch: 7, [iter: 20 / all 48], err_s_label: 0.072425, err_s_domain: 1.857659, err_t_domain: 0.819996
# epoch: 7, [iter: 21 / all 48], err_s_label: 0.302472, err_s_domain: 1.914116, err_t_domain: 0.797897
# epoch: 7, [iter: 22 / all 48], err_s_label: 0.069309, err_s_domain: 1.846186, err_t_domain: 0.815087
# epoch: 7, [iter: 23 / all 48], err_s_label: 0.167892, err_s_domain: 1.818886, err_t_domain: 0.828835
# epoch: 7, [iter: 24 / all 48], err_s_label: 0.208570, err_s_domain: 1.826449, err_t_domain: 0.851992
# epoch: 7, [iter: 25 / all 48], err_s_label: 0.102680, err_s_domain: 1.812853, err_t_domain: 0.842892
# epoch: 7, [iter: 26 / all 48], err_s_label: 0.101569, err_s_domain: 1.827521, err_t_domain: 0.821662
# epoch: 7, [iter: 27 / all 48], err_s_label: 0.127432, err_s_domain: 1.820535, err_t_domain: 0.837124
# epoch: 7, [iter: 28 / all 48], err_s_label: 0.079698, err_s_domain: 1.797316, err_t_domain: 0.853624
# epoch: 7, [iter: 29 / all 48], err_s_label: 0.123604, err_s_domain: 1.775314, err_t_domain: 0.850495
# epoch: 7, [iter: 30 / all 48], err_s_label: 0.102228, err_s_domain: 1.770646, err_t_domain: 0.832127
# epoch: 7, [iter: 31 / all 48], err_s_label: 0.096806, err_s_domain: 1.765778, err_t_domain: 0.831425
# epoch: 7, [iter: 32 / all 48], err_s_label: 0.067964, err_s_domain: 1.758088, err_t_domain: 0.863671
# epoch: 7, [iter: 33 / all 48], err_s_label: 0.108478, err_s_domain: 1.762746, err_t_domain: 0.844735
# epoch: 7, [iter: 34 / all 48], err_s_label: 0.083466, err_s_domain: 1.755148, err_t_domain: 0.851648
# epoch: 7, [iter: 35 / all 48], err_s_label: 0.048312, err_s_domain: 1.730499, err_t_domain: 0.840158
# epoch: 7, [iter: 36 / all 48], err_s_label: 0.072838, err_s_domain: 1.739701, err_t_domain: 0.846955
# epoch: 7, [iter: 37 / all 48], err_s_label: 0.115371, err_s_domain: 1.771773, err_t_domain: 0.832238
# epoch: 7, [iter: 38 / all 48], err_s_label: 0.054712, err_s_domain: 1.739796, err_t_domain: 0.820419
# epoch: 7, [iter: 39 / all 48], err_s_label: 0.055347, err_s_domain: 1.766147, err_t_domain: 0.810862
# epoch: 7, [iter: 40 / all 48], err_s_label: 0.068181, err_s_domain: 1.766341, err_t_domain: 0.802615
# epoch: 7, [iter: 41 / all 48], err_s_label: 0.160273, err_s_domain: 1.784609, err_t_domain: 0.824543
# epoch: 7, [iter: 42 / all 48], err_s_label: 0.031557, err_s_domain: 1.738590, err_t_domain: 0.841115
# epoch: 7, [iter: 43 / all 48], err_s_label: 0.057516, err_s_domain: 1.766405, err_t_domain: 0.821341
# epoch: 7, [iter: 44 / all 48], err_s_label: 0.110594, err_s_domain: 1.752184, err_t_domain: 0.834915
# epoch: 7, [iter: 45 / all 48], err_s_label: 0.086240, err_s_domain: 1.766508, err_t_domain: 0.850525
# epoch: 7, [iter: 46 / all 48], err_s_label: 0.087179, err_s_domain: 1.772103, err_t_domain: 0.840106
# epoch: 7, [iter: 47 / all 48], err_s_label: 0.168211, err_s_domain: 1.802378, err_t_domain: 0.868460
# epoch: 7, [iter: 48 / all 48], err_s_label: 0.406811, err_s_domain: 1.806180, err_t_domain: 0.846666
# epoch: 7, accuracy of the train dataset: 0.886836
# epoch: 7, accuracy of the test dataset: 0.573683
# epoch: 8, [iter: 1 / all 48], err_s_label: 0.045538, err_s_domain: 1.722071, err_t_domain: 0.851216
# epoch: 8, [iter: 2 / all 48], err_s_label: 0.082888, err_s_domain: 1.822253, err_t_domain: 0.846823
# epoch: 8, [iter: 3 / all 48], err_s_label: 0.108570, err_s_domain: 1.768598, err_t_domain: 0.816543
# epoch: 8, [iter: 4 / all 48], err_s_label: 0.155158, err_s_domain: 1.784677, err_t_domain: 0.821621
# epoch: 8, [iter: 5 / all 48], err_s_label: 0.471762, err_s_domain: 1.756371, err_t_domain: 0.827563
# epoch: 8, [iter: 6 / all 48], err_s_label: 0.063402, err_s_domain: 1.751237, err_t_domain: 0.834198
# epoch: 8, [iter: 7 / all 48], err_s_label: 0.136602, err_s_domain: 1.704979, err_t_domain: 0.818814
# epoch: 8, [iter: 8 / all 48], err_s_label: 0.082454, err_s_domain: 1.772362, err_t_domain: 0.813514
# epoch: 8, [iter: 9 / all 48], err_s_label: 0.065537, err_s_domain: 1.756548, err_t_domain: 0.817645
# epoch: 8, [iter: 10 / all 48], err_s_label: 0.085026, err_s_domain: 1.775246, err_t_domain: 0.821768
# epoch: 8, [iter: 11 / all 48], err_s_label: 0.170740, err_s_domain: 1.719239, err_t_domain: 0.798142
# epoch: 8, [iter: 12 / all 48], err_s_label: 0.241431, err_s_domain: 1.727436, err_t_domain: 0.804901
# epoch: 8, [iter: 13 / all 48], err_s_label: 0.103420, err_s_domain: 1.753754, err_t_domain: 0.806204
# epoch: 8, [iter: 14 / all 48], err_s_label: 0.212243, err_s_domain: 1.735403, err_t_domain: 0.835204
# epoch: 8, [iter: 15 / all 48], err_s_label: 0.064220, err_s_domain: 1.732783, err_t_domain: 0.852277
# epoch: 8, [iter: 16 / all 48], err_s_label: 0.150563, err_s_domain: 1.742124, err_t_domain: 0.800982
# epoch: 8, [iter: 17 / all 48], err_s_label: 0.104613, err_s_domain: 1.714295, err_t_domain: 0.840446
# epoch: 8, [iter: 18 / all 48], err_s_label: 0.157060, err_s_domain: 1.728740, err_t_domain: 0.803405
# epoch: 8, [iter: 19 / all 48], err_s_label: 0.163998, err_s_domain: 1.738354, err_t_domain: 0.882298
# epoch: 8, [iter: 20 / all 48], err_s_label: 0.265651, err_s_domain: 1.729750, err_t_domain: 0.852920
# epoch: 8, [iter: 21 / all 48], err_s_label: 0.176820, err_s_domain: 1.715796, err_t_domain: 0.854084
# epoch: 8, [iter: 22 / all 48], err_s_label: 0.326140, err_s_domain: 1.756679, err_t_domain: 0.865345
# epoch: 8, [iter: 23 / all 48], err_s_label: 0.161962, err_s_domain: 1.818234, err_t_domain: 0.841006
# epoch: 8, [iter: 24 / all 48], err_s_label: 0.124112, err_s_domain: 1.820041, err_t_domain: 0.845405
# epoch: 8, [iter: 25 / all 48], err_s_label: 0.168840, err_s_domain: 1.805465, err_t_domain: 0.866130
# epoch: 8, [iter: 26 / all 48], err_s_label: 0.073718, err_s_domain: 1.827560, err_t_domain: 0.841460
# epoch: 8, [iter: 27 / all 48], err_s_label: 0.141435, err_s_domain: 1.917516, err_t_domain: 0.865657
# epoch: 8, [iter: 28 / all 48], err_s_label: 0.211048, err_s_domain: 1.884374, err_t_domain: 0.824862
# epoch: 8, [iter: 29 / all 48], err_s_label: 0.116310, err_s_domain: 1.891295, err_t_domain: 0.831931
# epoch: 8, [iter: 30 / all 48], err_s_label: 0.153259, err_s_domain: 1.870041, err_t_domain: 0.835827
# epoch: 8, [iter: 31 / all 48], err_s_label: 0.208675, err_s_domain: 1.868923, err_t_domain: 0.835697
# epoch: 8, [iter: 32 / all 48], err_s_label: 0.133021, err_s_domain: 1.841137, err_t_domain: 0.853303
# epoch: 8, [iter: 33 / all 48], err_s_label: 0.252420, err_s_domain: 1.941607, err_t_domain: 0.869410
# epoch: 8, [iter: 34 / all 48], err_s_label: 0.119885, err_s_domain: 1.842655, err_t_domain: 0.866717
# epoch: 8, [iter: 35 / all 48], err_s_label: 0.096301, err_s_domain: 1.882127, err_t_domain: 0.870260
# epoch: 8, [iter: 36 / all 48], err_s_label: 0.144456, err_s_domain: 1.869908, err_t_domain: 0.877363
# epoch: 8, [iter: 37 / all 48], err_s_label: 0.062042, err_s_domain: 1.863911, err_t_domain: 0.930112
# epoch: 8, [iter: 38 / all 48], err_s_label: 0.084911, err_s_domain: 1.830000, err_t_domain: 0.940233
# epoch: 8, [iter: 39 / all 48], err_s_label: 0.120891, err_s_domain: 1.816179, err_t_domain: 0.938317
# epoch: 8, [iter: 40 / all 48], err_s_label: 0.088352, err_s_domain: 1.812393, err_t_domain: 0.904401
# epoch: 8, [iter: 41 / all 48], err_s_label: 0.241147, err_s_domain: 1.786809, err_t_domain: 0.874266
# epoch: 8, [iter: 42 / all 48], err_s_label: 0.257509, err_s_domain: 1.756754, err_t_domain: 0.896143
# epoch: 8, [iter: 43 / all 48], err_s_label: 0.153438, err_s_domain: 1.780548, err_t_domain: 0.896679
# epoch: 8, [iter: 44 / all 48], err_s_label: 0.185404, err_s_domain: 1.715837, err_t_domain: 0.889964
# epoch: 8, [iter: 45 / all 48], err_s_label: 0.093371, err_s_domain: 1.707966, err_t_domain: 0.904761
# epoch: 8, [iter: 46 / all 48], err_s_label: 0.248677, err_s_domain: 1.657260, err_t_domain: 0.859889
# epoch: 8, [iter: 47 / all 48], err_s_label: 0.075273, err_s_domain: 1.706072, err_t_domain: 0.869367
# epoch: 8, [iter: 48 / all 48], err_s_label: 0.077662, err_s_domain: 1.754535, err_t_domain: 0.854258
# epoch: 8, accuracy of the train dataset: 0.770373
# epoch: 8, accuracy of the test dataset: 0.577501
# epoch: 9, [iter: 1 / all 48], err_s_label: 0.064536, err_s_domain: 1.700915, err_t_domain: 0.839968
# epoch: 9, [iter: 2 / all 48], err_s_label: 0.054786, err_s_domain: 1.705807, err_t_domain: 0.856784
# epoch: 9, [iter: 3 / all 48], err_s_label: 0.085835, err_s_domain: 1.748471, err_t_domain: 0.846677
# epoch: 9, [iter: 4 / all 48], err_s_label: 0.150800, err_s_domain: 1.765193, err_t_domain: 0.819004
# epoch: 9, [iter: 5 / all 48], err_s_label: 0.104275, err_s_domain: 1.752309, err_t_domain: 0.826177
# epoch: 9, [iter: 6 / all 48], err_s_label: 0.129615, err_s_domain: 1.759612, err_t_domain: 0.833262
# epoch: 9, [iter: 7 / all 48], err_s_label: 0.096230, err_s_domain: 1.781866, err_t_domain: 0.828791
# epoch: 9, [iter: 8 / all 48], err_s_label: 0.141444, err_s_domain: 1.770374, err_t_domain: 0.818540
# epoch: 9, [iter: 9 / all 48], err_s_label: 0.169458, err_s_domain: 1.855442, err_t_domain: 0.819493
# epoch: 9, [iter: 10 / all 48], err_s_label: 0.080689, err_s_domain: 1.798724, err_t_domain: 0.846440
# epoch: 9, [iter: 11 / all 48], err_s_label: 0.132110, err_s_domain: 1.815778, err_t_domain: 0.856675
# epoch: 9, [iter: 12 / all 48], err_s_label: 0.114112, err_s_domain: 1.798935, err_t_domain: 0.812985
# epoch: 9, [iter: 13 / all 48], err_s_label: 0.074413, err_s_domain: 1.769879, err_t_domain: 0.847237
# epoch: 9, [iter: 14 / all 48], err_s_label: 0.106659, err_s_domain: 1.796021, err_t_domain: 0.825087
# epoch: 9, [iter: 15 / all 48], err_s_label: 0.051874, err_s_domain: 1.781407, err_t_domain: 0.870987
# epoch: 9, [iter: 16 / all 48], err_s_label: 0.104000, err_s_domain: 1.775162, err_t_domain: 0.877976
# epoch: 9, [iter: 17 / all 48], err_s_label: 0.093216, err_s_domain: 1.785663, err_t_domain: 0.859864
# epoch: 9, [iter: 18 / all 48], err_s_label: 0.141791, err_s_domain: 1.777400, err_t_domain: 0.890966
# epoch: 9, [iter: 19 / all 48], err_s_label: 0.067569, err_s_domain: 1.757816, err_t_domain: 0.866329
# epoch: 9, [iter: 20 / all 48], err_s_label: 0.123875, err_s_domain: 1.741643, err_t_domain: 0.889065
# epoch: 9, [iter: 21 / all 48], err_s_label: 0.123751, err_s_domain: 1.733647, err_t_domain: 0.871387
# epoch: 9, [iter: 22 / all 48], err_s_label: 0.089826, err_s_domain: 1.712372, err_t_domain: 0.903084
# epoch: 9, [iter: 23 / all 48], err_s_label: 0.045174, err_s_domain: 1.695231, err_t_domain: 0.910858
# epoch: 9, [iter: 24 / all 48], err_s_label: 0.060035, err_s_domain: 1.696238, err_t_domain: 0.916713
# epoch: 9, [iter: 25 / all 48], err_s_label: 0.069185, err_s_domain: 1.702001, err_t_domain: 0.925982
# epoch: 9, [iter: 26 / all 48], err_s_label: 0.048938, err_s_domain: 1.733794, err_t_domain: 0.909238
# epoch: 9, [iter: 27 / all 48], err_s_label: 0.127535, err_s_domain: 1.679704, err_t_domain: 0.884329
# epoch: 9, [iter: 28 / all 48], err_s_label: 0.073423, err_s_domain: 1.731404, err_t_domain: 0.897789
# epoch: 9, [iter: 29 / all 48], err_s_label: 0.066630, err_s_domain: 1.735249, err_t_domain: 0.895472
# epoch: 9, [iter: 30 / all 48], err_s_label: 0.083557, err_s_domain: 1.718344, err_t_domain: 0.859471
# ...
# epoch: 25, [iter: 42 / all 48], err_s_label: 0.073658, err_s_domain: 1.815587, err_t_domain: 0.693834
# epoch: 25, [iter: 43 / all 48], err_s_label: 0.016942, err_s_domain: 1.809733, err_t_domain: 0.692525
# epoch: 25, [iter: 44 / all 48], err_s_label: 0.037987, err_s_domain: 1.789671, err_t_domain: 0.691900
# epoch: 25, [iter: 45 / all 48], err_s_label: 0.098175, err_s_domain: 1.784189, err_t_domain: 0.691589
# epoch: 25, [iter: 46 / all 48], err_s_label: 0.019749, err_s_domain: 1.805202, err_t_domain: 0.690253
# epoch: 25, [iter: 47 / all 48], err_s_label: 0.050495, err_s_domain: 1.786538, err_t_domain: 0.694793
# epoch: 25, [iter: 48 / all 48], err_s_label: 0.008259, err_s_domain: 1.836430, err_t_domain: 0.694249
# epoch: 25, accuracy of the train dataset: 0.930716
# epoch: 25, accuracy of the test dataset: 0.644948
# epoch: 26, [iter: 1 / all 48], err_s_label: 0.016966, err_s_domain: 1.759294, err_t_domain: 0.693503
# epoch: 26, [iter: 2 / all 48], err_s_label: 0.015789, err_s_domain: 1.749768, err_t_domain: 0.694018
# epoch: 26, [iter: 3 / all 48], err_s_label: 0.057753, err_s_domain: 1.788903, err_t_domain: 0.697752
# epoch: 26, [iter: 4 / all 48], err_s_label: 0.072870, err_s_domain: 1.770837, err_t_domain: 0.697680
# epoch: 26, [iter: 5 / all 48], err_s_label: 0.012710, err_s_domain: 1.751814, err_t_domain: 0.697255
# epoch: 26, [iter: 6 / all 48], err_s_label: 0.009984, err_s_domain: 1.775965, err_t_domain: 0.699128
# epoch: 26, [iter: 7 / all 48], err_s_label: 0.085356, err_s_domain: 1.746021, err_t_domain: 0.702731
# epoch: 26, [iter: 8 / all 48], err_s_label: 0.020238, err_s_domain: 1.766781, err_t_domain: 0.703651
# epoch: 26, [iter: 9 / all 48], err_s_label: 0.045170, err_s_domain: 1.782209, err_t_domain: 0.705452
# epoch: 26, [iter: 10 / all 48], err_s_label: 0.005718, err_s_domain: 1.759881, err_t_domain: 0.701479
# epoch: 26, [iter: 11 / all 48], err_s_label: 0.015607, err_s_domain: 1.807423, err_t_domain: 0.705042
# epoch: 26, [iter: 12 / all 48], err_s_label: 0.021585, err_s_domain: 1.806505, err_t_domain: 0.706789
# epoch: 26, [iter: 13 / all 48], err_s_label: 0.027858, err_s_domain: 1.797254, err_t_domain: 0.703535
# epoch: 26, [iter: 14 / all 48], err_s_label: 0.016452, err_s_domain: 1.816382, err_t_domain: 0.702676
# epoch: 26, [iter: 15 / all 48], err_s_label: 0.095723, err_s_domain: 1.847037, err_t_domain: 0.704315
# epoch: 26, [iter: 16 / all 48], err_s_label: 0.025230, err_s_domain: 1.822886, err_t_domain: 0.703016
# epoch: 26, [iter: 17 / all 48], err_s_label: 0.017468, err_s_domain: 1.827551, err_t_domain: 0.707616
# epoch: 26, [iter: 18 / all 48], err_s_label: 0.048167, err_s_domain: 1.833381, err_t_domain: 0.701935
# epoch: 26, [iter: 19 / all 48], err_s_label: 0.075371, err_s_domain: 1.857483, err_t_domain: 0.703430
# epoch: 26, [iter: 20 / all 48], err_s_label: 0.078100, err_s_domain: 1.886448, err_t_domain: 0.699600
# epoch: 26, [iter: 21 / all 48], err_s_label: 0.009993, err_s_domain: 1.863736, err_t_domain: 0.699534
# epoch: 26, [iter: 22 / all 48], err_s_label: 0.122788, err_s_domain: 1.898239, err_t_domain: 0.701889
# epoch: 26, [iter: 23 / all 48], err_s_label: 0.073992, err_s_domain: 1.886636, err_t_domain: 0.698850
# epoch: 26, [iter: 24 / all 48], err_s_label: 0.008470, err_s_domain: 1.904962, err_t_domain: 0.700593
# epoch: 26, [iter: 25 / all 48], err_s_label: 0.035955, err_s_domain: 1.900641, err_t_domain: 0.701342
# epoch: 26, [iter: 26 / all 48], err_s_label: 0.058144, err_s_domain: 1.878500, err_t_domain: 0.695879
# epoch: 26, [iter: 27 / all 48], err_s_label: 0.086261, err_s_domain: 1.872941, err_t_domain: 0.699863
# epoch: 26, [iter: 28 / all 48], err_s_label: 0.017282, err_s_domain: 1.864667, err_t_domain: 0.703736
# epoch: 26, [iter: 29 / all 48], err_s_label: 0.057336, err_s_domain: 1.860805, err_t_domain: 0.697965
# epoch: 26, [iter: 30 / all 48], err_s_label: 0.147380, err_s_domain: 1.862630, err_t_domain: 0.700176
# epoch: 26, [iter: 31 / all 48], err_s_label: 0.036303, err_s_domain: 1.858563, err_t_domain: 0.701035
# epoch: 26, [iter: 32 / all 48], err_s_label: 0.058784, err_s_domain: 1.839838, err_t_domain: 0.698755
# epoch: 26, [iter: 33 / all 48], err_s_label: 0.071250, err_s_domain: 1.845963, err_t_domain: 0.702582
# epoch: 26, [iter: 34 / all 48], err_s_label: 0.049284, err_s_domain: 1.842927, err_t_domain: 0.707314
# epoch: 26, [iter: 35 / all 48], err_s_label: 0.039059, err_s_domain: 1.840257, err_t_domain: 0.706608
# epoch: 26, [iter: 36 / all 48], err_s_label: 0.056803, err_s_domain: 1.806090, err_t_domain: 0.709399
# epoch: 26, [iter: 37 / all 48], err_s_label: 0.060218, err_s_domain: 1.816949, err_t_domain: 0.710382
# epoch: 26, [iter: 38 / all 48], err_s_label: 0.013601, err_s_domain: 1.808891, err_t_domain: 0.710325
# epoch: 26, [iter: 39 / all 48], err_s_label: 0.018443, err_s_domain: 1.809754, err_t_domain: 0.713852
# epoch: 26, [iter: 40 / all 48], err_s_label: 0.011745, err_s_domain: 1.770165, err_t_domain: 0.712841
# epoch: 26, [iter: 41 / all 48], err_s_label: 0.021590, err_s_domain: 1.811231, err_t_domain: 0.713016
# epoch: 26, [iter: 42 / all 48], err_s_label: 0.078353, err_s_domain: 1.832093, err_t_domain: 0.716237
# epoch: 26, [iter: 43 / all 48], err_s_label: 0.050141, err_s_domain: 1.781323, err_t_domain: 0.715172
# epoch: 26, [iter: 44 / all 48], err_s_label: 0.067297, err_s_domain: 1.725555, err_t_domain: 0.720528
# epoch: 26, [iter: 45 / all 48], err_s_label: 0.108330, err_s_domain: 1.772929, err_t_domain: 0.715847
# epoch: 26, [iter: 46 / all 48], err_s_label: 0.054766, err_s_domain: 1.785626, err_t_domain: 0.719021
# epoch: 26, [iter: 47 / all 48], err_s_label: 0.010191, err_s_domain: 1.795735, err_t_domain: 0.717356
# epoch: 26, [iter: 48 / all 48], err_s_label: 0.059673, err_s_domain: 1.849606, err_t_domain: 0.716847
# epoch: 26, accuracy of the train dataset: 0.920818
# epoch: 26, accuracy of the test dataset: 0.527361
# epoch: 27, [iter: 1 / all 48], err_s_label: 0.046483, err_s_domain: 1.786443, err_t_domain: 0.719355
# epoch: 27, [iter: 2 / all 48], err_s_label: 0.058477, err_s_domain: 1.765212, err_t_domain: 0.719937
# epoch: 27, [iter: 3 / all 48], err_s_label: 0.034206, err_s_domain: 1.815230, err_t_domain: 0.716624
# epoch: 27, [iter: 4 / all 48], err_s_label: 0.092394, err_s_domain: 1.804305, err_t_domain: 0.706554
# epoch: 27, [iter: 5 / all 48], err_s_label: 0.039084, err_s_domain: 1.800469, err_t_domain: 0.709331
# epoch: 27, [iter: 6 / all 48], err_s_label: 0.071149, err_s_domain: 1.876685, err_t_domain: 0.710298
# epoch: 27, [iter: 7 / all 48], err_s_label: 0.069780, err_s_domain: 1.839085, err_t_domain: 0.706257
# epoch: 27, [iter: 8 / all 48], err_s_label: 0.072697, err_s_domain: 1.841536, err_t_domain: 0.701285
# epoch: 27, [iter: 9 / all 48], err_s_label: 0.012168, err_s_domain: 1.858799, err_t_domain: 0.706288
# epoch: 27, [iter: 10 / all 48], err_s_label: 0.050469, err_s_domain: 1.844562, err_t_domain: 0.702200
# epoch: 27, [iter: 11 / all 48], err_s_label: 0.110207, err_s_domain: 1.845634, err_t_domain: 0.701276
# epoch: 27, [iter: 12 / all 48], err_s_label: 0.035371, err_s_domain: 1.845567, err_t_domain: 0.704670
# epoch: 27, [iter: 13 / all 48], err_s_label: 0.077434, err_s_domain: 1.841029, err_t_domain: 0.698994
# epoch: 27, [iter: 14 / all 48], err_s_label: 0.078785, err_s_domain: 1.835934, err_t_domain: 0.700724
# epoch: 27, [iter: 15 / all 48], err_s_label: 0.014301, err_s_domain: 1.848716, err_t_domain: 0.700112
# epoch: 27, [iter: 16 / all 48], err_s_label: 0.065812, err_s_domain: 1.821145, err_t_domain: 0.695889
# epoch: 27, [iter: 17 / all 48], err_s_label: 0.030164, err_s_domain: 1.822512, err_t_domain: 0.700217
# epoch: 27, [iter: 18 / all 48], err_s_label: 0.053435, err_s_domain: 1.824998, err_t_domain: 0.700243
# epoch: 27, [iter: 19 / all 48], err_s_label: 0.069545, err_s_domain: 1.796029, err_t_domain: 0.702832
# epoch: 27, [iter: 20 / all 48], err_s_label: 0.126910, err_s_domain: 1.807234, err_t_domain: 0.701491
# epoch: 27, [iter: 21 / all 48], err_s_label: 0.052764, err_s_domain: 1.816696, err_t_domain: 0.701334
# epoch: 27, [iter: 22 / all 48], err_s_label: 0.029087, err_s_domain: 1.795225, err_t_domain: 0.702655
# epoch: 27, [iter: 23 / all 48], err_s_label: 0.044792, err_s_domain: 1.794493, err_t_domain: 0.703643
# epoch: 27, [iter: 24 / all 48], err_s_label: 0.084405, err_s_domain: 1.767195, err_t_domain: 0.703304
# epoch: 27, [iter: 25 / all 48], err_s_label: 0.024579, err_s_domain: 1.775053, err_t_domain: 0.707537
# epoch: 27, [iter: 26 / all 48], err_s_label: 0.009073, err_s_domain: 1.756800, err_t_domain: 0.705971
# epoch: 27, [iter: 27 / all 48], err_s_label: 0.045355, err_s_domain: 1.749871, err_t_domain: 0.707724
# epoch: 27, [iter: 28 / all 48], err_s_label: 0.061252, err_s_domain: 1.741746, err_t_domain: 0.706858
# epoch: 27, [iter: 29 / all 48], err_s_label: 0.108576, err_s_domain: 1.740398, err_t_domain: 0.708706
# epoch: 27, [iter: 30 / all 48], err_s_label: 0.057629, err_s_domain: 1.752921, err_t_domain: 0.709409
# epoch: 27, [iter: 31 / all 48], err_s_label: 0.053914, err_s_domain: 1.726019, err_t_domain: 0.704428
# epoch: 27, [iter: 32 / all 48], err_s_label: 0.049712, err_s_domain: 1.742140, err_t_domain: 0.705299
# epoch: 27, [iter: 33 / all 48], err_s_label: 0.041812, err_s_domain: 1.715954, err_t_domain: 0.710207
# epoch: 27, [iter: 34 / all 48], err_s_label: 0.013418, err_s_domain: 1.749301, err_t_domain: 0.709324
# epoch: 27, [iter: 35 / all 48], err_s_label: 0.012744, err_s_domain: 1.760121, err_t_domain: 0.711888
# epoch: 27, [iter: 36 / all 48], err_s_label: 0.039156, err_s_domain: 1.771994, err_t_domain: 0.706613
# epoch: 27, [iter: 37 / all 48], err_s_label: 0.054645, err_s_domain: 1.743224, err_t_domain: 0.708948
# epoch: 27, [iter: 38 / all 48], err_s_label: 0.014431, err_s_domain: 1.790591, err_t_domain: 0.704934
# epoch: 27, [iter: 39 / all 48], err_s_label: 0.058973, err_s_domain: 1.785814, err_t_domain: 0.706064
# epoch: 27, [iter: 40 / all 48], err_s_label: 0.015241, err_s_domain: 1.813635, err_t_domain: 0.702491
# epoch: 27, [iter: 41 / all 48], err_s_label: 0.108970, err_s_domain: 1.852874, err_t_domain: 0.701364
# epoch: 27, [iter: 42 / all 48], err_s_label: 0.016063, err_s_domain: 1.860321, err_t_domain: 0.702065
# epoch: 27, [iter: 43 / all 48], err_s_label: 0.020598, err_s_domain: 1.840052, err_t_domain: 0.701671
# epoch: 27, [iter: 44 / all 48], err_s_label: 0.055325, err_s_domain: 1.840035, err_t_domain: 0.698037
# epoch: 27, [iter: 45 / all 48], err_s_label: 0.044529, err_s_domain: 1.819439, err_t_domain: 0.699229
# epoch: 27, [iter: 46 / all 48], err_s_label: 0.087000, err_s_domain: 1.837004, err_t_domain: 0.698454
# epoch: 27, [iter: 47 / all 48], err_s_label: 0.105656, err_s_domain: 1.848245, err_t_domain: 0.696253
# epoch: 27, [iter: 48 / all 48], err_s_label: 0.065474, err_s_domain: 1.861682, err_t_domain: 0.697136
# epoch: 27, accuracy of the train dataset: 0.777466
# epoch: 27, accuracy of the test dataset: 0.614915
# epoch: 28, [iter: 1 / all 48], err_s_label: 0.020123, err_s_domain: 1.802640, err_t_domain: 0.693349
# epoch: 28, [iter: 2 / all 48], err_s_label: 0.065735, err_s_domain: 1.818047, err_t_domain: 0.694620
# epoch: 28, [iter: 3 / all 48], err_s_label: 0.016326, err_s_domain: 1.812776, err_t_domain: 0.693181
# epoch: 28, [iter: 4 / all 48], err_s_label: 0.105490, err_s_domain: 1.837389, err_t_domain: 0.689962
# epoch: 28, [iter: 5 / all 48], err_s_label: 0.016088, err_s_domain: 1.823160, err_t_domain: 0.688504
# epoch: 28, [iter: 6 / all 48], err_s_label: 0.026437, err_s_domain: 1.805287, err_t_domain: 0.685726
# epoch: 28, [iter: 7 / all 48], err_s_label: 0.119135, err_s_domain: 1.779268, err_t_domain: 0.689763
# epoch: 28, [iter: 8 / all 48], err_s_label: 0.003696, err_s_domain: 1.802480, err_t_domain: 0.692684
# epoch: 28, [iter: 9 / all 48], err_s_label: 0.014986, err_s_domain: 1.768797, err_t_domain: 0.692819
# epoch: 28, [iter: 10 / all 48], err_s_label: 0.102343, err_s_domain: 1.779876, err_t_domain: 0.690771
# epoch: 28, [iter: 11 / all 48], err_s_label: 0.012150, err_s_domain: 1.755300, err_t_domain: 0.691958
# epoch: 28, [iter: 12 / all 48], err_s_label: 0.005942, err_s_domain: 1.770802, err_t_domain: 0.691415
# epoch: 28, [iter: 13 / all 48], err_s_label: 0.009061, err_s_domain: 1.763929, err_t_domain: 0.696192
# epoch: 28, [iter: 14 / all 48], err_s_label: 0.035125, err_s_domain: 1.759705, err_t_domain: 0.693835
# epoch: 28, [iter: 15 / all 48], err_s_label: 0.018099, err_s_domain: 1.742891, err_t_domain: 0.695541
# epoch: 28, [iter: 16 / all 48], err_s_label: 0.012337, err_s_domain: 1.718602, err_t_domain: 0.691502
# epoch: 28, [iter: 17 / all 48], err_s_label: 0.019439, err_s_domain: 1.728917, err_t_domain: 0.694422
# epoch: 28, [iter: 18 / all 48], err_s_label: 0.055908, err_s_domain: 1.745942, err_t_domain: 0.697013
# epoch: 28, [iter: 19 / all 48], err_s_label: 0.017407, err_s_domain: 1.763570, err_t_domain: 0.703891
# epoch: 28, [iter: 20 / all 48], err_s_label: 0.030171, err_s_domain: 1.772307, err_t_domain: 0.697391
# epoch: 28, [iter: 21 / all 48], err_s_label: 0.011776, err_s_domain: 1.778574, err_t_domain: 0.702473
# epoch: 28, [iter: 22 / all 48], err_s_label: 0.030360, err_s_domain: 1.811052, err_t_domain: 0.698714
# epoch: 28, [iter: 23 / all 48], err_s_label: 0.073527, err_s_domain: 1.791278, err_t_domain: 0.702256
# epoch: 28, [iter: 24 / all 48], err_s_label: 0.033304, err_s_domain: 1.850491, err_t_domain: 0.702995
# epoch: 28, [iter: 25 / all 48], err_s_label: 0.030223, err_s_domain: 1.815587, err_t_domain: 0.701618
# epoch: 28, [iter: 26 / all 48], err_s_label: 0.016322, err_s_domain: 1.818539, err_t_domain: 0.701964
# epoch: 28, [iter: 27 / all 48], err_s_label: 0.018054, err_s_domain: 1.847504, err_t_domain: 0.704255
# epoch: 28, [iter: 28 / all 48], err_s_label: 0.078170, err_s_domain: 1.860546, err_t_domain: 0.702421
# epoch: 28, [iter: 29 / all 48], err_s_label: 0.037767, err_s_domain: 1.861001, err_t_domain: 0.699021
# epoch: 28, [iter: 30 / all 48], err_s_label: 0.053529, err_s_domain: 1.842562, err_t_domain: 0.698928
# epoch: 28, [iter: 31 / all 48], err_s_label: 0.010206, err_s_domain: 1.851855, err_t_domain: 0.700304
# epoch: 28, [iter: 32 / all 48], err_s_label: 0.020350, err_s_domain: 1.849559, err_t_domain: 0.699872
# epoch: 28, [iter: 33 / all 48], err_s_label: 0.021465, err_s_domain: 1.854273, err_t_domain: 0.702459
# epoch: 28, [iter: 34 / all 48], err_s_label: 0.011746, err_s_domain: 1.843227, err_t_domain: 0.703565
# epoch: 28, [iter: 35 / all 48], err_s_label: 0.081722, err_s_domain: 1.873304, err_t_domain: 0.702324
# epoch: 28, [iter: 36 / all 48], err_s_label: 0.034228, err_s_domain: 1.890871, err_t_domain: 0.703126
# epoch: 28, [iter: 37 / all 48], err_s_label: 0.033009, err_s_domain: 1.861005, err_t_domain: 0.706496
# epoch: 28, [iter: 38 / all 48], err_s_label: 0.023007, err_s_domain: 1.839382, err_t_domain: 0.704356
# epoch: 28, [iter: 39 / all 48], err_s_label: 0.014599, err_s_domain: 1.881506, err_t_domain: 0.706677
# epoch: 28, [iter: 40 / all 48], err_s_label: 0.050244, err_s_domain: 1.836766, err_t_domain: 0.707591
# epoch: 28, [iter: 41 / all 48], err_s_label: 0.013676, err_s_domain: 1.887320, err_t_domain: 0.706980
# epoch: 28, [iter: 42 / all 48], err_s_label: 0.011967, err_s_domain: 1.866098, err_t_domain: 0.702903
# epoch: 28, [iter: 43 / all 48], err_s_label: 0.014148, err_s_domain: 1.856638, err_t_domain: 0.704668
# epoch: 28, [iter: 44 / all 48], err_s_label: 0.033178, err_s_domain: 1.819857, err_t_domain: 0.705666
# epoch: 28, [iter: 45 / all 48], err_s_label: 0.051873, err_s_domain: 1.827858, err_t_domain: 0.702241
# epoch: 28, [iter: 46 / all 48], err_s_label: 0.003819, err_s_domain: 1.819257, err_t_domain: 0.705393
# epoch: 28, [iter: 47 / all 48], err_s_label: 0.040454, err_s_domain: 1.847778, err_t_domain: 0.704952
# epoch: 28, [iter: 48 / all 48], err_s_label: 0.039124, err_s_domain: 1.802588, err_t_domain: 0.701117
# epoch: 28, accuracy of the train dataset: 0.955955
# epoch: 28, accuracy of the test dataset: 0.650293
# epoch: 29, [iter: 1 / all 48], err_s_label: 0.010690, err_s_domain: 1.818118, err_t_domain: 0.705105
# epoch: 29, [iter: 2 / all 48], err_s_label: 0.055141, err_s_domain: 1.827114, err_t_domain: 0.700693
