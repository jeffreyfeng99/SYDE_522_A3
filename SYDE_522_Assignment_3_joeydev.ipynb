# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffreyfeng99/SYDE_522_A3/blob/master/SYDE_522_Assignment_3_joeydev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Submission Notes
# Group members:
#
# Jeffrey Feng, 20704800
#
# Joey Kuang, 20726074

# %% [markdown]
# # Import statements

# %%
import os
import pandas as pd
import numpy as np
import random
from PIL import Image
from tqdm import tqdm
from datetime import datetime

import torch
import torch.nn as nn
import torch.utils.data as data
from torch.autograd import Function
import torch.backends.cudnn as cudnn
from torchvision import transforms
from torchvision import datasets
from torchvision import models
import torch.optim as optim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Config

# %%
cuda = True
cudnn.benchmark = True

model_name = "vgg16"

LR = 1e-3
BATCH_SIZE = 128
IMAGE_SIZE = 224 #227
# FT_OUT_SIZE = 512
N_EPOCH = 50

# %% [markdown]
# # Data loader

# %%
dataset_root = '/content/drive/MyDrive/4B/SYDE-522/data'
output_root = '/content/drive/MyDrive/4B/SYDE-522/submission/03292022_resnetnorm'
source_dataset_name = 'train_set'
target_dataset_name = 'test_set'

source_image_root = os.path.join(dataset_root, source_dataset_name)
target_image_root = os.path.join(dataset_root, target_dataset_name)

train_label_list = os.path.join(dataset_root, 'train_labels.csv')

os.makedirs(output_root, exist_ok=True)

# %%
class GetLoader(data.Dataset):
    def __init__(self, data_root, data_list=None, transform=None):
        self.root = data_root
        self.transform = transform

        # we only pass data_list if it's training set
        if data_list is not None:
            df = pd.read_csv(data_list)
            self.img_paths = df['dir'].to_list()

            if 'label2' in df.columns:
                self.img_labels = df['label2'].to_list()
            else: 
                self.img_labels = ['0' for i in range(len(self.img_paths))]

            if 'label1' in df.columns:
                self.domain_labels = df['label1'].to_list()
            else: 
                self.domain_labels = ['0' for i in range(len(self.img_paths))]
        else:
            # Walk through test folder - we don't need labels
            self.img_paths = [f for root,dirs,files in os.walk(data_root) for f in files if f.endswith('.png')]
            self.img_labels = ['0' for i in range(len(self.img_paths))]
            self.domain_labels = ['0' for i in range(len(self.img_paths))]

        self.n_data = len(self.img_paths)

    def __getitem__(self, item):
        img_paths, labels, domain_labels = self.img_paths[item%self.n_data], self.img_labels[item%self.n_data], self.domain_labels[item%self.n_data]
        imgs = Image.open(os.path.join(self.root, img_paths)).convert('RGB')

        if self.transform is not None:

            if isinstance(self.transform, list):
                tform = self.transform[int(domain_labels)]
            else:
                tform = self.transform

            imgs = tform(imgs)
            labels = int(labels)
            domain_labels = int(domain_labels)

        return imgs, labels, domain_labels, img_paths

    def __len__(self):
        return self.n_data

# %%
# Preprocess data
def preprocess_multiple_fn(mus, stds):
    tforms = []

    for i in range(len(mus)):
        tforms.append(preprocess_fn(mu=mus[i], std=stds[i]))
    
    return tforms

def preprocess_fn(mu=(0.6399, 0.6076, 0.5603), std=(0.3065, 0.3082, 0.3353)):
  img_transform = transforms.Compose([
      transforms.Resize(IMAGE_SIZE),
      transforms.ToTensor(),
      transforms.Normalize(mean=mu, std=std) 
  ])

  return img_transform

def prep_dataloader(image_root, label_list=None, img_transform=None, 
                    drop_last=False, shuffle=True):
    dataset = GetLoader(
        data_root=image_root,
        data_list=label_list,
        transform=img_transform
    )

    dataloader = data.DataLoader(
        dataset=dataset,
        batch_size=BATCH_SIZE,
        shuffle=shuffle,
        num_workers=8,
        drop_last=drop_last)
    
    return dataset, dataloader

# %% [markdown]
# # Model definition

# %%
# if False, then we are feature extracting
def set_parameter_requires_grad(model, finetune):
    for param in model.parameters():
        param.requires_grad = finetune

# %%
class ReverseLayerF(Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None


class CNNModel(nn.Module):

    def __init__(self, model_name="resnet18"):
        super(CNNModel, self).__init__()
        self.ft_out_size = 0

        if model_name == "resnet18":
            self.feature = models.resnet18(pretrained=True) 
            self.feature.fc = nn.Identity()
            self.ft_out_size = 512
        if model_name == "resnet50":
            self.feature = models.resnet50(pretrained=True) 
            self.feature.fc = nn.Identity()
            self.ft_out_size = 2048
        elif model_name == "vgg16":
            self.feature = models.vgg16_bn(pretrained=True) 
            self.feature.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1)) # original is (7,7)
            self.feature.classifier = nn.Identity()
            self.ft_out_size = 512
        else:
            # Need some default model?
            self.feature = nn.Sequential()
            self.feature.add_module('f_conv1', nn.Conv2d(3, 64, kernel_size=5))
            self.feature.add_module('f_bn1', nn.BatchNorm2d(64))
            self.feature.add_module('f_pool1', nn.MaxPool2d(2))
            self.feature.add_module('f_relu1', nn.ReLU(True))
            self.feature.add_module('f_conv2', nn.Conv2d(64, 128, kernel_size=3))
            self.feature.add_module('f_bn2', nn.BatchNorm2d(128))
            self.feature.add_module('f_drop1', nn.Dropout2d())
            self.feature.add_module('f_pool2', nn.MaxPool2d(2))
            self.feature.add_module('f_relu2', nn.ReLU(True))
            self.feature.add_module('f_conv3', nn.Conv2d(128, 256, kernel_size=3))
            self.feature.add_module('f_bn3', nn.BatchNorm2d(256))
            self.feature.add_module('f_drop3', nn.Dropout2d())
            self.feature.add_module('f_pool3', nn.MaxPool2d(2))
            self.feature.add_module('f_relu4', nn.ReLU(True))
            self.feature.add_module('f_conv4', nn.Conv2d(256, 256, kernel_size=3))
            self.feature.add_module('f_bn4', nn.BatchNorm2d(256))
            self.feature.add_module('f_drop4', nn.Dropout2d())
            self.feature.add_module('f_pool4', nn.MaxPool2d(2))
            self.feature.add_module('f_relu4', nn.ReLU(True))
            self.feature.add_module('f_conv5', nn.Conv2d(256, 512, kernel_size=3))
            self.feature.add_module('f_bn5', nn.BatchNorm2d(512))
            self.feature.add_module('f_drop5', nn.Dropout2d())
            self.feature.add_module('f_pool5', nn.MaxPool2d(2))
            self.feature.add_module('f_relu5', nn.ReLU(True))

        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(self.ft_out_size, 100))
        self.class_classifier.add_module('c_bn1', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_drop1', nn.Dropout2d())
        self.class_classifier.add_module('c_fc2', nn.Linear(100, 100))
        self.class_classifier.add_module('c_bn2', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(100, 7))
        self.class_classifier.add_module('c_softmax', nn.LogSoftmax(dim=1))

        self.domain_classifier = nn.Sequential()
        self.domain_classifier.add_module('d_fc1', nn.Linear(self.ft_out_size, 100))
        self.domain_classifier.add_module('d_bn1', nn.BatchNorm1d(100))
        self.domain_classifier.add_module('d_relu1', nn.ReLU(True))
        self.domain_classifier.add_module('d_fc2', nn.Linear(100, 4))
        self.domain_classifier.add_module('d_softmax', nn.LogSoftmax(dim=1))

    def forward(self, input_data, alpha):
        input_data = input_data.expand(input_data.data.shape[0], 3, IMAGE_SIZE, IMAGE_SIZE)
        feature = self.feature(input_data)
        feature = feature.view(-1, self.ft_out_size)
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)

        return class_output, domain_output

# %% [markdown]
# # Test pipeline

# %%
def test(net, epoch):

    # load data
    # img_transform_source = preprocess_multiple_fn(mus=[(0.5085, 0.4832, 0.4396),
    #                                                     (0.5550, 0.5085, 0.4579),
    #                                                    (0.8077, 0.7829, 0.7358)], 
    #                                               stds=[(0.1780, 0.1779, 0.1907),
    #                                                     (0.1880, 0.1917, 0.2060),
    #                                                     (0.2239, 0.2283, 0.2437)])
    
    # img_transform_target = preprocess_fn(mu=(0.9566, 0.9566, 0.9566), std=(0.1752, 0.1752, 0.1752))

    img_transform_source = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
    img_transform_target = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))


    dataset_source, dataloader_source = prep_dataloader(
        image_root=os.path.join(source_image_root, 'train_set'),
        label_list=train_label_list,
        img_transform=img_transform_source,
        shuffle=False
    )

    dataset_target, dataloader_target = prep_dataloader(
        image_root=os.path.join(target_image_root, 'test_set'),
        img_transform=img_transform_target,
        shuffle=False
    )

    net.eval()

    if cuda:
        net = net.cuda()

    train_pths, train_preds = inference(net, dataloader_source, cuda=cuda, alpha=alpha)
    train_results = pd.DataFrame({'id': train_pths, 'label': train_preds})
    train_results_pth = os.path.join(output_root, '%s_train_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
    train_results.to_csv(train_results_pth, index=False)

    test_pths, test_preds = inference(net, dataloader_target, cuda=cuda, alpha=alpha)
    test_results = pd.DataFrame({'id': test_pths, 'label': test_preds})
    test_results_pth = os.path.join(output_root, '%s_test_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
    test_results.to_csv(test_results_pth, index=False)

    print('epoch: %d, accuracy of the train dataset: %f' % (epoch, compare(train_label_list, train_results_pth)))

    # Secret
    test_label_list = os.path.join(dataset_root, 'dummy_test_labels.csv')
    print('epoch: %d, accuracy of the test dataset: %f' % (epoch, compare(test_label_list, test_results_pth)))

def inference(net, dataloader, cuda=True, alpha=0.0):
    preds = []
    pths = []
    for input_img, _,_, img_paths in dataloader: 

        if cuda:
            input_img = input_img.cuda()

        class_output, _ = net(input_data=input_img, alpha=alpha)
        pred = class_output.data.max(1, keepdim=True)[1]
        pths = pths + list(img_paths)
        preds = preds + list(pred.squeeze(1).cpu().numpy())
    return pths, preds

def compare(true_labels, predicted_labels):
    combined_df = pd.read_csv(true_labels)
    predicted_df = pd.read_csv(predicted_labels)

    combined_df['label'] = combined_df['dir'].map(predicted_df.set_index('id')['label'])

    true_labels = np.array(combined_df['label2'].to_list())
    pred_labels = np.array(combined_df['label'].to_list())

    return np.sum(true_labels == pred_labels) / len(true_labels)

# %% [markdown]
# # Training pipeline

# %%
manual_seed = random.randint(1, 10000)
random.seed(manual_seed)
torch.manual_seed(manual_seed)

# load data
# img_transform_source = preprocess_multiple_fn(mus=[(0.5085, 0.4832, 0.4396),
#                                                     (0.5550, 0.5085, 0.4579),
#                                                     (0.8077, 0.7829, 0.7358)], 
#                                                 stds=[(0.1780, 0.1779, 0.1907),
#                                                     (0.1880, 0.1917, 0.2060),
#                                                     (0.2239, 0.2283, 0.2437)])
# img_transform_target = preprocess_fn(mu=(0.9566, 0.9566, 0.9566), std=(0.1752, 0.1752, 0.1752))

img_transform_source = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
img_transform_target = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))


dataset_source, dataloader_source = prep_dataloader(
    image_root=os.path.join(source_image_root, 'train_set'), # TODO should we unnest
    label_list=train_label_list,
    img_transform=img_transform_source
)

dataset_target, dataloader_target = prep_dataloader(
    image_root=os.path.join(target_image_root, 'test_set'),
    img_transform=img_transform_target
)

# load model
my_net = CNNModel()

# setup optimizer
optimizer = optim.Adam(my_net.parameters(), lr=LR)

loss_class = torch.nn.NLLLoss()
loss_domain = torch.nn.NLLLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()
    loss_domain = loss_domain.cuda()

set_parameter_requires_grad(my_net, True)

# training
for epoch in range(N_EPOCH):

    len_dataloader = max(len(dataloader_source), len(dataloader_target))
    data_source_iter = iter(dataloader_source)
    data_target_iter = iter(dataloader_target)

    i = 0
    while i < len_dataloader:

        p = float(i + epoch * len_dataloader) / N_EPOCH / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # training model using source data
        data_source = data_source_iter.next()
        s_img, s_label, s_domain_label, _ = data_source

        my_net.zero_grad()
        batch_size = len(s_label)

        input_img = torch.FloatTensor(batch_size, 3, IMAGE_SIZE, IMAGE_SIZE)
        class_label = torch.LongTensor(batch_size)
        domain_label = torch.LongTensor(batch_size)

        if cuda:
            s_img = s_img.cuda()
            s_label = s_label.cuda()
            s_domain_label = s_domain_label.cuda()
            input_img = input_img.cuda()
            class_label = class_label.cuda()
            domain_label = domain_label.cuda()

        input_img.resize_as_(s_img).copy_(s_img)
        class_label.resize_as_(s_label).copy_(s_label)
        domain_label.resize_as_(s_domain_label).copy_(s_domain_label)

        class_output, domain_output = my_net(input_data=input_img, alpha=alpha)
        err_s_label = loss_class(class_output, class_label)
        err_s_domain = loss_domain(domain_output, domain_label)

        # training model using target data
        if i == len(dataloader_target):
            data_target_iter = iter(dataloader_target)
        data_target = data_target_iter.next()
        t_img, _, _, _ = data_target

        batch_size = len(t_img) # TODO: why?

        input_img = torch.FloatTensor(batch_size, 3, IMAGE_SIZE, IMAGE_SIZE)
        domain_label = torch.ones(batch_size) * 3.0
        domain_label = domain_label.long()

        if cuda:
            t_img = t_img.cuda()
            input_img = input_img.cuda()
            domain_label = domain_label.cuda()

        input_img.resize_as_(t_img).copy_(t_img)

        _, domain_output = my_net(input_data=input_img, alpha=alpha)
        err_t_domain = loss_domain(domain_output, domain_label)
        err = err_t_domain + err_s_domain + err_s_label
        err.backward()
        optimizer.step()

        i += 1

        print('epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
            % (epoch, i, len_dataloader, err_s_label.cpu().data.numpy(),
                err_s_domain.cpu().data.numpy(), err_t_domain.cpu().data.numpy()))

    # torch.save(my_net, 'output/model_epoch_{}.pth'.format(epoch))
    test(my_net, epoch)
    my_net.train()

print('done')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# epoch: 0, [iter: 1 / all 48], err_s_label: 2.047918, err_s_domain: 1.428590, err_t_domain: 1.545665
# epoch: 0, [iter: 2 / all 48], err_s_label: 1.730577, err_s_domain: 1.257380, err_t_domain: 1.476156
# epoch: 0, [iter: 3 / all 48], err_s_label: 1.602221, err_s_domain: 1.145457, err_t_domain: 1.425458
# epoch: 0, [iter: 4 / all 48], err_s_label: 1.463524, err_s_domain: 1.130109, err_t_domain: 1.369828
# epoch: 0, [iter: 5 / all 48], err_s_label: 1.401775, err_s_domain: 1.054514, err_t_domain: 1.323410
# epoch: 0, [iter: 6 / all 48], err_s_label: 1.307246, err_s_domain: 1.062621, err_t_domain: 1.281052
# epoch: 0, [iter: 7 / all 48], err_s_label: 1.240423, err_s_domain: 1.100715, err_t_domain: 1.229912
# epoch: 0, [iter: 8 / all 48], err_s_label: 1.171448, err_s_domain: 1.097990, err_t_domain: 1.189844
# epoch: 0, [iter: 9 / all 48], err_s_label: 1.137595, err_s_domain: 1.077359, err_t_domain: 1.142428
# epoch: 0, [iter: 10 / all 48], err_s_label: 1.027208, err_s_domain: 1.118067, err_t_domain: 1.103657
# epoch: 0, [iter: 11 / all 48], err_s_label: 1.084840, err_s_domain: 1.117173, err_t_domain: 1.049606
# epoch: 0, [iter: 12 / all 48], err_s_label: 0.972038, err_s_domain: 1.104305, err_t_domain: 1.015397
# epoch: 0, [iter: 13 / all 48], err_s_label: 1.006895, err_s_domain: 1.307545, err_t_domain: 0.995729
# epoch: 0, [iter: 14 / all 48], err_s_label: 0.910630, err_s_domain: 1.352013, err_t_domain: 0.936767
# epoch: 0, [iter: 15 / all 48], err_s_label: 0.954097, err_s_domain: 1.395841, err_t_domain: 0.899465
# epoch: 0, [iter: 16 / all 48], err_s_label: 0.890575, err_s_domain: 1.442862, err_t_domain: 0.853671
# epoch: 0, [iter: 17 / all 48], err_s_label: 0.856816, err_s_domain: 1.499432, err_t_domain: 0.845938
# epoch: 0, [iter: 18 / all 48], err_s_label: 0.814292, err_s_domain: 1.533834, err_t_domain: 0.793791
# epoch: 0, [iter: 19 / all 48], err_s_label: 0.763607, err_s_domain: 1.610390, err_t_domain: 0.779407
# epoch: 0, [iter: 20 / all 48], err_s_label: 0.780303, err_s_domain: 1.693430, err_t_domain: 0.759965
# epoch: 0, [iter: 21 / all 48], err_s_label: 0.686640, err_s_domain: 1.729855, err_t_domain: 0.742471
# epoch: 0, [iter: 22 / all 48], err_s_label: 0.809605, err_s_domain: 1.895543, err_t_domain: 0.728735
# epoch: 0, [iter: 23 / all 48], err_s_label: 0.811016, err_s_domain: 2.038557, err_t_domain: 0.705692
# epoch: 0, [iter: 24 / all 48], err_s_label: 0.633629, err_s_domain: 2.021777, err_t_domain: 0.701139
# epoch: 0, [iter: 25 / all 48], err_s_label: 0.668260, err_s_domain: 2.054606, err_t_domain: 0.682118
# epoch: 0, [iter: 26 / all 48], err_s_label: 0.770248, err_s_domain: 2.044030, err_t_domain: 0.664838
# epoch: 0, [iter: 27 / all 48], err_s_label: 0.627336, err_s_domain: 2.095628, err_t_domain: 0.656737
# epoch: 0, [iter: 28 / all 48], err_s_label: 0.717533, err_s_domain: 2.235479, err_t_domain: 0.649978
# epoch: 0, [iter: 29 / all 48], err_s_label: 0.659804, err_s_domain: 2.231880, err_t_domain: 0.627011
# epoch: 0, [iter: 30 / all 48], err_s_label: 0.598673, err_s_domain: 2.306297, err_t_domain: 0.624066
# epoch: 0, [iter: 31 / all 48], err_s_label: 0.603284, err_s_domain: 2.248039, err_t_domain: 0.602594
# epoch: 0, [iter: 32 / all 48], err_s_label: 0.651730, err_s_domain: 2.310753, err_t_domain: 0.598551
# epoch: 0, [iter: 33 / all 48], err_s_label: 0.599612, err_s_domain: 2.272589, err_t_domain: 0.595173
# epoch: 0, [iter: 34 / all 48], err_s_label: 0.734453, err_s_domain: 2.301750, err_t_domain: 0.613647
# epoch: 0, [iter: 35 / all 48], err_s_label: 0.511629, err_s_domain: 2.221086, err_t_domain: 0.620660
# epoch: 0, [iter: 36 / all 48], err_s_label: 0.481916, err_s_domain: 2.219290, err_t_domain: 0.625025
# epoch: 0, [iter: 37 / all 48], err_s_label: 0.532328, err_s_domain: 2.327955, err_t_domain: 0.619124
# epoch: 0, [iter: 38 / all 48], err_s_label: 0.572152, err_s_domain: 2.328932, err_t_domain: 0.631673
# epoch: 0, [iter: 39 / all 48], err_s_label: 0.546174, err_s_domain: 2.245971, err_t_domain: 0.636399
# epoch: 0, [iter: 40 / all 48], err_s_label: 0.655510, err_s_domain: 2.354540, err_t_domain: 0.647024
# epoch: 0, [iter: 41 / all 48], err_s_label: 0.483009, err_s_domain: 2.224644, err_t_domain: 0.637993
# epoch: 0, [iter: 42 / all 48], err_s_label: 0.457233, err_s_domain: 2.193440, err_t_domain: 0.641433
# epoch: 0, [iter: 43 / all 48], err_s_label: 0.579969, err_s_domain: 2.076269, err_t_domain: 0.642454
# epoch: 0, [iter: 44 / all 48], err_s_label: 0.465083, err_s_domain: 2.099808, err_t_domain: 0.633657
# epoch: 0, [iter: 45 / all 48], err_s_label: 0.436697, err_s_domain: 2.086995, err_t_domain: 0.634121
# epoch: 0, [iter: 46 / all 48], err_s_label: 0.420613, err_s_domain: 2.082140, err_t_domain: 0.644893
# epoch: 0, [iter: 47 / all 48], err_s_label: 0.583166, err_s_domain: 2.063867, err_t_domain: 0.651890
# epoch: 0, [iter: 48 / all 48], err_s_label: 0.570757, err_s_domain: 2.024999, err_t_domain: 0.642527
# epoch: 0, accuracy of the train dataset: 0.618113
# epoch: 0, accuracy of the test dataset: 0.288114
# epoch: 1, [iter: 1 / all 48], err_s_label: 0.447036, err_s_domain: 1.979674, err_t_domain: 0.653265
# epoch: 1, [iter: 2 / all 48], err_s_label: 0.406728, err_s_domain: 1.946987, err_t_domain: 0.664197
# epoch: 1, [iter: 3 / all 48], err_s_label: 0.325856, err_s_domain: 1.859297, err_t_domain: 0.660336
# epoch: 1, [iter: 4 / all 48], err_s_label: 0.424091, err_s_domain: 1.789315, err_t_domain: 0.669645
# epoch: 1, [iter: 5 / all 48], err_s_label: 0.331496, err_s_domain: 1.812466, err_t_domain: 0.684177
# epoch: 1, [iter: 6 / all 48], err_s_label: 0.389169, err_s_domain: 1.787778, err_t_domain: 0.684890
# epoch: 1, [iter: 7 / all 48], err_s_label: 0.371533, err_s_domain: 1.765245, err_t_domain: 0.697786
# epoch: 1, [iter: 8 / all 48], err_s_label: 0.418020, err_s_domain: 1.755426, err_t_domain: 0.692552
# epoch: 1, [iter: 9 / all 48], err_s_label: 0.432299, err_s_domain: 1.772724, err_t_domain: 0.701534
# epoch: 1, [iter: 10 / all 48], err_s_label: 0.364949, err_s_domain: 1.721192, err_t_domain: 0.718381
# epoch: 1, [iter: 11 / all 48], err_s_label: 0.305933, err_s_domain: 1.727718, err_t_domain: 0.711247
# epoch: 1, [iter: 12 / all 48], err_s_label: 0.435605, err_s_domain: 1.747347, err_t_domain: 0.701060
# epoch: 1, [iter: 13 / all 48], err_s_label: 0.428579, err_s_domain: 1.699547, err_t_domain: 0.721885
# epoch: 1, [iter: 14 / all 48], err_s_label: 0.433524, err_s_domain: 1.728980, err_t_domain: 0.732827
# epoch: 1, [iter: 15 / all 48], err_s_label: 0.392221, err_s_domain: 1.717326, err_t_domain: 0.722673
# epoch: 1, [iter: 16 / all 48], err_s_label: 0.438899, err_s_domain: 1.726890, err_t_domain: 0.719860
# epoch: 1, [iter: 17 / all 48], err_s_label: 0.360648, err_s_domain: 1.703267, err_t_domain: 0.723958
# epoch: 1, [iter: 18 / all 48], err_s_label: 0.378541, err_s_domain: 1.743639, err_t_domain: 0.727551
# epoch: 1, [iter: 19 / all 48], err_s_label: 0.349633, err_s_domain: 1.698905, err_t_domain: 0.728599
# epoch: 1, [iter: 20 / all 48], err_s_label: 0.375147, err_s_domain: 1.700492, err_t_domain: 0.717833
# epoch: 1, [iter: 21 / all 48], err_s_label: 0.291012, err_s_domain: 1.855797, err_t_domain: 0.735915
# epoch: 1, [iter: 22 / all 48], err_s_label: 0.319545, err_s_domain: 1.687562, err_t_domain: 0.729281
# epoch: 1, [iter: 23 / all 48], err_s_label: 0.380577, err_s_domain: 1.837814, err_t_domain: 0.717114
# epoch: 1, [iter: 24 / all 48], err_s_label: 0.384486, err_s_domain: 1.781772, err_t_domain: 0.732089
# epoch: 1, [iter: 25 / all 48], err_s_label: 0.358942, err_s_domain: 1.869445, err_t_domain: 0.731169
# epoch: 1, [iter: 26 / all 48], err_s_label: 0.318717, err_s_domain: 1.921504, err_t_domain: 0.717083
# epoch: 1, [iter: 27 / all 48], err_s_label: 0.338884, err_s_domain: 1.920450, err_t_domain: 0.717280
# epoch: 1, [iter: 28 / all 48], err_s_label: 0.394141, err_s_domain: 1.852608, err_t_domain: 0.715873
# epoch: 1, [iter: 29 / all 48], err_s_label: 0.308919, err_s_domain: 1.912550, err_t_domain: 0.709858
# epoch: 1, [iter: 30 / all 48], err_s_label: 0.376253, err_s_domain: 1.899941, err_t_domain: 0.711449
# epoch: 1, [iter: 31 / all 48], err_s_label: 0.276238, err_s_domain: 1.910524, err_t_domain: 0.717858
# epoch: 1, [iter: 32 / all 48], err_s_label: 0.370153, err_s_domain: 1.968662, err_t_domain: 0.712701
# epoch: 1, [iter: 33 / all 48], err_s_label: 0.314442, err_s_domain: 1.991348, err_t_domain: 0.684869
# epoch: 1, [iter: 34 / all 48], err_s_label: 0.320024, err_s_domain: 1.931612, err_t_domain: 0.708142
# epoch: 1, [iter: 35 / all 48], err_s_label: 0.346841, err_s_domain: 1.908672, err_t_domain: 0.701590
# epoch: 1, [iter: 36 / all 48], err_s_label: 0.531568, err_s_domain: 1.974680, err_t_domain: 0.699660
# epoch: 1, [iter: 37 / all 48], err_s_label: 0.441149, err_s_domain: 1.946657, err_t_domain: 0.703080
# epoch: 1, [iter: 38 / all 48], err_s_label: 0.297552, err_s_domain: 2.008723, err_t_domain: 0.689543
# epoch: 1, [iter: 39 / all 48], err_s_label: 0.404762, err_s_domain: 1.962949, err_t_domain: 0.697576
# epoch: 1, [iter: 40 / all 48], err_s_label: 0.463801, err_s_domain: 1.990841, err_t_domain: 0.700711
# epoch: 1, [iter: 41 / all 48], err_s_label: 0.373204, err_s_domain: 1.993704, err_t_domain: 0.704071
# epoch: 1, [iter: 42 / all 48], err_s_label: 0.352119, err_s_domain: 1.888609, err_t_domain: 0.697215
# epoch: 1, [iter: 43 / all 48], err_s_label: 0.360253, err_s_domain: 1.844673, err_t_domain: 0.716340
# epoch: 1, [iter: 44 / all 48], err_s_label: 0.403264, err_s_domain: 1.886979, err_t_domain: 0.711473
# epoch: 1, [iter: 45 / all 48], err_s_label: 0.351577, err_s_domain: 1.879704, err_t_domain: 0.710537
# epoch: 1, [iter: 46 / all 48], err_s_label: 0.448480, err_s_domain: 1.860801, err_t_domain: 0.719042
# epoch: 1, [iter: 47 / all 48], err_s_label: 0.308507, err_s_domain: 1.885178, err_t_domain: 0.717220
# epoch: 1, [iter: 48 / all 48], err_s_label: 0.310210, err_s_domain: 1.860909, err_t_domain: 0.707355
# epoch: 1, accuracy of the train dataset: 0.901848
# epoch: 1, accuracy of the test dataset: 0.564011
# epoch: 2, [iter: 1 / all 48], err_s_label: 0.262945, err_s_domain: 1.835321, err_t_domain: 0.705904
# epoch: 2, [iter: 2 / all 48], err_s_label: 0.243561, err_s_domain: 1.838024, err_t_domain: 0.694138
# epoch: 2, [iter: 3 / all 48], err_s_label: 0.169519, err_s_domain: 1.837423, err_t_domain: 0.708426
# epoch: 2, [iter: 4 / all 48], err_s_label: 0.323876, err_s_domain: 1.765074, err_t_domain: 0.710968
# epoch: 2, [iter: 5 / all 48], err_s_label: 0.209074, err_s_domain: 1.756181, err_t_domain: 0.725309
# epoch: 2, [iter: 6 / all 48], err_s_label: 0.226681, err_s_domain: 1.819284, err_t_domain: 0.727330
# epoch: 2, [iter: 7 / all 48], err_s_label: 0.277918, err_s_domain: 1.764627, err_t_domain: 0.705758
# epoch: 2, [iter: 8 / all 48], err_s_label: 0.260360, err_s_domain: 1.765680, err_t_domain: 0.729830
# epoch: 2, [iter: 9 / all 48], err_s_label: 0.359265, err_s_domain: 1.761924, err_t_domain: 0.714438
# epoch: 2, [iter: 10 / all 48], err_s_label: 0.245726, err_s_domain: 1.796111, err_t_domain: 0.720882
# epoch: 2, [iter: 11 / all 48], err_s_label: 0.307837, err_s_domain: 1.749893, err_t_domain: 0.718565
# epoch: 2, [iter: 12 / all 48], err_s_label: 0.179678, err_s_domain: 1.715654, err_t_domain: 0.719716
# epoch: 2, [iter: 13 / all 48], err_s_label: 0.182831, err_s_domain: 1.746334, err_t_domain: 0.719853
# epoch: 2, [iter: 14 / all 48], err_s_label: 0.281900, err_s_domain: 1.735201, err_t_domain: 0.712582
# epoch: 2, [iter: 15 / all 48], err_s_label: 0.252133, err_s_domain: 1.711195, err_t_domain: 0.722813
# epoch: 2, [iter: 16 / all 48], err_s_label: 0.249008, err_s_domain: 1.718537, err_t_domain: 0.721966
# epoch: 2, [iter: 17 / all 48], err_s_label: 0.286005, err_s_domain: 1.746247, err_t_domain: 0.709172
# epoch: 2, [iter: 18 / all 48], err_s_label: 0.306871, err_s_domain: 1.658158, err_t_domain: 0.703638
# epoch: 2, [iter: 19 / all 48], err_s_label: 0.284965, err_s_domain: 1.726516, err_t_domain: 0.732322
# epoch: 2, [iter: 20 / all 48], err_s_label: 0.379750, err_s_domain: 1.748049, err_t_domain: 0.733955
# epoch: 2, [iter: 21 / all 48], err_s_label: 0.210220, err_s_domain: 1.716957, err_t_domain: 0.728308
# epoch: 2, [iter: 22 / all 48], err_s_label: 0.220277, err_s_domain: 1.785216, err_t_domain: 0.719674
# epoch: 2, [iter: 23 / all 48], err_s_label: 0.194411, err_s_domain: 1.735833, err_t_domain: 0.726214
# epoch: 2, [iter: 24 / all 48], err_s_label: 0.206302, err_s_domain: 1.850274, err_t_domain: 0.739237
# epoch: 2, [iter: 25 / all 48], err_s_label: 0.241985, err_s_domain: 1.804466, err_t_domain: 0.746102
# epoch: 2, [iter: 26 / all 48], err_s_label: 0.271134, err_s_domain: 1.825461, err_t_domain: 0.756007
# epoch: 2, [iter: 27 / all 48], err_s_label: 0.363352, err_s_domain: 1.903161, err_t_domain: 0.739533
# epoch: 2, [iter: 28 / all 48], err_s_label: 0.264469, err_s_domain: 1.847226, err_t_domain: 0.740885
# epoch: 2, [iter: 29 / all 48], err_s_label: 0.209365, err_s_domain: 1.879134, err_t_domain: 0.724059
# epoch: 2, [iter: 30 / all 48], err_s_label: 0.390381, err_s_domain: 1.877461, err_t_domain: 0.742917
# epoch: 2, [iter: 31 / all 48], err_s_label: 0.269116, err_s_domain: 1.877676, err_t_domain: 0.698771
# epoch: 2, [iter: 32 / all 48], err_s_label: 0.198733, err_s_domain: 1.902598, err_t_domain: 0.745303
# epoch: 2, [iter: 33 / all 48], err_s_label: 0.284898, err_s_domain: 1.898282, err_t_domain: 0.714887
# epoch: 2, [iter: 34 / all 48], err_s_label: 0.220327, err_s_domain: 1.898888, err_t_domain: 0.744584
# epoch: 2, [iter: 35 / all 48], err_s_label: 0.285730, err_s_domain: 1.896385, err_t_domain: 0.721017
# epoch: 2, [iter: 36 / all 48], err_s_label: 0.204035, err_s_domain: 1.903601, err_t_domain: 0.720829
# epoch: 2, [iter: 37 / all 48], err_s_label: 0.243624, err_s_domain: 1.884859, err_t_domain: 0.726186
# epoch: 2, [iter: 38 / all 48], err_s_label: 0.321478, err_s_domain: 1.918871, err_t_domain: 0.752147
# epoch: 2, [iter: 39 / all 48], err_s_label: 0.244291, err_s_domain: 1.827391, err_t_domain: 0.740470
# epoch: 2, [iter: 40 / all 48], err_s_label: 0.279481, err_s_domain: 1.827984, err_t_domain: 0.734165
# epoch: 2, [iter: 41 / all 48], err_s_label: 0.302122, err_s_domain: 1.857093, err_t_domain: 0.739371
# epoch: 2, [iter: 42 / all 48], err_s_label: 0.308729, err_s_domain: 1.841213, err_t_domain: 0.719875
# epoch: 2, [iter: 43 / all 48], err_s_label: 0.207573, err_s_domain: 1.851021, err_t_domain: 0.738203
# epoch: 2, [iter: 44 / all 48], err_s_label: 0.203120, err_s_domain: 1.833946, err_t_domain: 0.756147
# epoch: 2, [iter: 45 / all 48], err_s_label: 0.303481, err_s_domain: 1.860822, err_t_domain: 0.794740
# epoch: 2, [iter: 46 / all 48], err_s_label: 0.256903, err_s_domain: 1.786879, err_t_domain: 0.781105
# epoch: 2, [iter: 47 / all 48], err_s_label: 0.411761, err_s_domain: 1.749639, err_t_domain: 0.780490
# epoch: 2, [iter: 48 / all 48], err_s_label: 0.602423, err_s_domain: 1.762392, err_t_domain: 0.776051
# epoch: 2, accuracy of the train dataset: 0.759155
# epoch: 2, accuracy of the test dataset: 0.522270
# epoch: 3, [iter: 1 / all 48], err_s_label: 0.231436, err_s_domain: 1.766739, err_t_domain: 0.810733
# epoch: 3, [iter: 2 / all 48], err_s_label: 0.227163, err_s_domain: 1.821113, err_t_domain: 0.839971
# epoch: 3, [iter: 3 / all 48], err_s_label: 0.157749, err_s_domain: 1.753301, err_t_domain: 0.824821
# epoch: 3, [iter: 4 / all 48], err_s_label: 0.307610, err_s_domain: 1.704407, err_t_domain: 0.850295
# epoch: 3, [iter: 5 / all 48], err_s_label: 0.290634, err_s_domain: 1.755950, err_t_domain: 0.855683
# epoch: 3, [iter: 6 / all 48], err_s_label: 0.242750, err_s_domain: 1.757800, err_t_domain: 0.875867
# epoch: 3, [iter: 7 / all 48], err_s_label: 0.201046, err_s_domain: 1.701519, err_t_domain: 0.871422
# epoch: 3, [iter: 8 / all 48], err_s_label: 0.334410, err_s_domain: 1.684010, err_t_domain: 0.904656
# epoch: 3, [iter: 9 / all 48], err_s_label: 0.250555, err_s_domain: 1.705686, err_t_domain: 0.925555
# epoch: 3, [iter: 10 / all 48], err_s_label: 0.206459, err_s_domain: 1.671625, err_t_domain: 0.915882
# epoch: 3, [iter: 11 / all 48], err_s_label: 0.196105, err_s_domain: 1.708422, err_t_domain: 0.925078
# epoch: 3, [iter: 12 / all 48], err_s_label: 0.229407, err_s_domain: 1.680823, err_t_domain: 0.927456
# epoch: 3, [iter: 13 / all 48], err_s_label: 0.182296, err_s_domain: 1.694024, err_t_domain: 0.923198
# epoch: 3, [iter: 14 / all 48], err_s_label: 0.192564, err_s_domain: 1.675744, err_t_domain: 0.905928
# epoch: 3, [iter: 15 / all 48], err_s_label: 0.175866, err_s_domain: 1.726709, err_t_domain: 1.012422
# epoch: 3, [iter: 16 / all 48], err_s_label: 0.159559, err_s_domain: 1.707630, err_t_domain: 1.007117
# epoch: 3, [iter: 17 / all 48], err_s_label: 0.228207, err_s_domain: 1.736220, err_t_domain: 0.997944
# epoch: 3, [iter: 18 / all 48], err_s_label: 0.162796, err_s_domain: 1.715567, err_t_domain: 0.963502
# epoch: 3, [iter: 19 / all 48], err_s_label: 0.241231, err_s_domain: 1.676551, err_t_domain: 0.978533
# epoch: 3, [iter: 20 / all 48], err_s_label: 0.217294, err_s_domain: 1.668587, err_t_domain: 0.980977
# epoch: 3, [iter: 21 / all 48], err_s_label: 0.157640, err_s_domain: 1.695615, err_t_domain: 1.016005
# epoch: 3, [iter: 22 / all 48], err_s_label: 0.243012, err_s_domain: 1.650083, err_t_domain: 1.045521
# epoch: 3, [iter: 23 / all 48], err_s_label: 0.231999, err_s_domain: 1.624132, err_t_domain: 1.030414
# epoch: 3, [iter: 24 / all 48], err_s_label: 0.210399, err_s_domain: 1.645572, err_t_domain: 0.963626
# epoch: 3, [iter: 25 / all 48], err_s_label: 0.202076, err_s_domain: 1.617028, err_t_domain: 1.024281
# epoch: 3, [iter: 26 / all 48], err_s_label: 0.216629, err_s_domain: 1.666436, err_t_domain: 1.078811
# epoch: 3, [iter: 27 / all 48], err_s_label: 0.234660, err_s_domain: 1.626969, err_t_domain: 1.063860
# epoch: 3, [iter: 28 / all 48], err_s_label: 0.285308, err_s_domain: 1.637463, err_t_domain: 1.064384
# epoch: 3, [iter: 29 / all 48], err_s_label: 0.217475, err_s_domain: 1.612329, err_t_domain: 1.045815
# epoch: 3, [iter: 30 / all 48], err_s_label: 0.262445, err_s_domain: 1.631900, err_t_domain: 1.067535
# epoch: 3, [iter: 31 / all 48], err_s_label: 0.375929, err_s_domain: 1.571196, err_t_domain: 1.098348
# epoch: 3, [iter: 32 / all 48], err_s_label: 0.195795, err_s_domain: 1.609001, err_t_domain: 1.059322
# epoch: 3, [iter: 33 / all 48], err_s_label: 0.122127, err_s_domain: 1.548914, err_t_domain: 1.084826
# epoch: 3, [iter: 34 / all 48], err_s_label: 0.214504, err_s_domain: 1.483468, err_t_domain: 1.111256
# epoch: 3, [iter: 35 / all 48], err_s_label: 0.276241, err_s_domain: 1.533920, err_t_domain: 1.080464
# epoch: 3, [iter: 36 / all 48], err_s_label: 0.165093, err_s_domain: 1.513120, err_t_domain: 1.114719
# epoch: 3, [iter: 37 / all 48], err_s_label: 0.170791, err_s_domain: 1.502658, err_t_domain: 1.093253
# epoch: 3, [iter: 38 / all 48], err_s_label: 0.276682, err_s_domain: 1.496366, err_t_domain: 1.089804
# epoch: 3, [iter: 39 / all 48], err_s_label: 0.202286, err_s_domain: 1.476027, err_t_domain: 1.094346
# epoch: 3, [iter: 40 / all 48], err_s_label: 0.256888, err_s_domain: 1.463554, err_t_domain: 1.108150
# epoch: 3, [iter: 41 / all 48], err_s_label: 0.184623, err_s_domain: 1.522628, err_t_domain: 1.089646
# epoch: 3, [iter: 42 / all 48], err_s_label: 0.170212, err_s_domain: 1.511457, err_t_domain: 1.106068
# epoch: 3, [iter: 43 / all 48], err_s_label: 0.374182, err_s_domain: 1.489169, err_t_domain: 1.108789
# epoch: 3, [iter: 44 / all 48], err_s_label: 0.144050, err_s_domain: 1.519567, err_t_domain: 1.183516
# epoch: 3, [iter: 45 / all 48], err_s_label: 0.165483, err_s_domain: 1.461808, err_t_domain: 1.130838
# epoch: 3, [iter: 46 / all 48], err_s_label: 0.220506, err_s_domain: 1.479708, err_t_domain: 1.109390
# epoch: 3, [iter: 47 / all 48], err_s_label: 0.191575, err_s_domain: 1.505835, err_t_domain: 1.175156
# epoch: 3, [iter: 48 / all 48], err_s_label: 0.362453, err_s_domain: 1.519649, err_t_domain: 1.189419
# epoch: 3, accuracy of the train dataset: 0.887166
# epoch: 3, accuracy of the test dataset: 0.456350
# epoch: 4, [iter: 1 / all 48], err_s_label: 0.096993, err_s_domain: 1.503329, err_t_domain: 1.157667
# epoch: 4, [iter: 2 / all 48], err_s_label: 0.125607, err_s_domain: 1.535519, err_t_domain: 1.128694
# epoch: 4, [iter: 3 / all 48], err_s_label: 0.155079, err_s_domain: 1.509706, err_t_domain: 1.099215
# epoch: 4, [iter: 4 / all 48], err_s_label: 0.214825, err_s_domain: 1.566765, err_t_domain: 1.076089
# epoch: 4, [iter: 5 / all 48], err_s_label: 0.173635, err_s_domain: 1.603816, err_t_domain: 1.030573
# epoch: 4, [iter: 6 / all 48], err_s_label: 0.212216, err_s_domain: 1.599058, err_t_domain: 0.966947
# epoch: 4, [iter: 7 / all 48], err_s_label: 0.225160, err_s_domain: 1.621320, err_t_domain: 0.920862
# epoch: 4, [iter: 8 / all 48], err_s_label: 0.182524, err_s_domain: 1.644509, err_t_domain: 0.901941
# epoch: 4, [iter: 9 / all 48], err_s_label: 0.184984, err_s_domain: 1.627367, err_t_domain: 0.856591
# epoch: 4, [iter: 10 / all 48], err_s_label: 0.263887, err_s_domain: 1.692773, err_t_domain: 0.812383
# epoch: 4, [iter: 11 / all 48], err_s_label: 0.202261, err_s_domain: 1.697257, err_t_domain: 0.798970
# epoch: 4, [iter: 12 / all 48], err_s_label: 0.138001, err_s_domain: 1.748525, err_t_domain: 0.745645
# epoch: 4, [iter: 13 / all 48], err_s_label: 0.102725, err_s_domain: 1.764367, err_t_domain: 0.743554
# epoch: 4, [iter: 14 / all 48], err_s_label: 0.129897, err_s_domain: 1.800330, err_t_domain: 0.698699
# epoch: 4, [iter: 15 / all 48], err_s_label: 0.211334, err_s_domain: 1.862427, err_t_domain: 0.686778
# epoch: 4, [iter: 16 / all 48], err_s_label: 0.207827, err_s_domain: 1.832640, err_t_domain: 0.670890
# epoch: 4, [iter: 17 / all 48], err_s_label: 0.139513, err_s_domain: 1.880938, err_t_domain: 0.665676
# epoch: 4, [iter: 18 / all 48], err_s_label: 0.213987, err_s_domain: 1.845187, err_t_domain: 0.622811
# epoch: 4, [iter: 19 / all 48], err_s_label: 0.131543, err_s_domain: 1.880618, err_t_domain: 0.645270
# epoch: 4, [iter: 20 / all 48], err_s_label: 0.069750, err_s_domain: 1.869401, err_t_domain: 0.649907
# epoch: 4, [iter: 21 / all 48], err_s_label: 0.139669, err_s_domain: 1.918097, err_t_domain: 0.648933
# epoch: 4, [iter: 22 / all 48], err_s_label: 0.193369, err_s_domain: 1.925913, err_t_domain: 0.633869
# epoch: 4, [iter: 23 / all 48], err_s_label: 0.176098, err_s_domain: 1.947818, err_t_domain: 0.650347
# epoch: 4, [iter: 24 / all 48], err_s_label: 0.155756, err_s_domain: 1.888341, err_t_domain: 0.647330
# epoch: 4, [iter: 25 / all 48], err_s_label: 0.127725, err_s_domain: 1.924098, err_t_domain: 0.647021
# epoch: 4, [iter: 26 / all 48], err_s_label: 0.219135, err_s_domain: 1.947065, err_t_domain: 0.665698
# epoch: 4, [iter: 27 / all 48], err_s_label: 0.420511, err_s_domain: 1.945153, err_t_domain: 0.652092
# epoch: 4, [iter: 28 / all 48], err_s_label: 0.110257, err_s_domain: 1.918656, err_t_domain: 0.640805
# epoch: 4, [iter: 29 / all 48], err_s_label: 0.293001, err_s_domain: 1.906882, err_t_domain: 0.668631
# epoch: 4, [iter: 30 / all 48], err_s_label: 0.197016, err_s_domain: 1.874213, err_t_domain: 0.680749
# epoch: 4, [iter: 31 / all 48], err_s_label: 0.122080, err_s_domain: 1.890693, err_t_domain: 0.689286
# epoch: 4, [iter: 32 / all 48], err_s_label: 0.165186, err_s_domain: 1.848184, err_t_domain: 0.687040
# epoch: 4, [iter: 33 / all 48], err_s_label: 0.127945, err_s_domain: 1.831820, err_t_domain: 0.690921
# epoch: 4, [iter: 34 / all 48], err_s_label: 0.160540, err_s_domain: 1.784590, err_t_domain: 0.697271
# epoch: 4, [iter: 35 / all 48], err_s_label: 0.136083, err_s_domain: 1.819963, err_t_domain: 0.725248
# epoch: 4, [iter: 36 / all 48], err_s_label: 0.189103, err_s_domain: 1.792556, err_t_domain: 0.696912
# epoch: 4, [iter: 37 / all 48], err_s_label: 0.159251, err_s_domain: 1.793042, err_t_domain: 0.739549
# epoch: 4, [iter: 38 / all 48], err_s_label: 0.201870, err_s_domain: 1.781254, err_t_domain: 0.720969
# epoch: 4, [iter: 39 / all 48], err_s_label: 0.228423, err_s_domain: 1.774149, err_t_domain: 0.754628
# epoch: 4, [iter: 40 / all 48], err_s_label: 0.130529, err_s_domain: 1.735000, err_t_domain: 0.750569
# epoch: 4, [iter: 41 / all 48], err_s_label: 0.119443, err_s_domain: 1.765215, err_t_domain: 0.767140
# epoch: 4, [iter: 42 / all 48], err_s_label: 0.152323, err_s_domain: 1.750231, err_t_domain: 0.776839
# epoch: 4, [iter: 43 / all 48], err_s_label: 0.246833, err_s_domain: 1.734382, err_t_domain: 0.801449
# epoch: 4, [iter: 44 / all 48], err_s_label: 0.138157, err_s_domain: 1.725657, err_t_domain: 0.820813
# epoch: 4, [iter: 45 / all 48], err_s_label: 0.077080, err_s_domain: 1.742160, err_t_domain: 0.828113
# epoch: 4, [iter: 46 / all 48], err_s_label: 0.227369, err_s_domain: 1.729043, err_t_domain: 0.825452
# epoch: 4, [iter: 47 / all 48], err_s_label: 0.196823, err_s_domain: 1.714587, err_t_domain: 0.833557
# epoch: 4, [iter: 48 / all 48], err_s_label: 0.140901, err_s_domain: 1.721583, err_t_domain: 0.837952
# epoch: 4, accuracy of the train dataset: 0.886341
# epoch: 4, accuracy of the test dataset: 0.552049
# epoch: 5, [iter: 1 / all 48], err_s_label: 0.083766, err_s_domain: 1.773255, err_t_domain: 0.849814
# epoch: 5, [iter: 2 / all 48], err_s_label: 0.145026, err_s_domain: 1.646427, err_t_domain: 0.853460
# epoch: 5, [iter: 3 / all 48], err_s_label: 0.101425, err_s_domain: 1.750203, err_t_domain: 0.844749
# epoch: 5, [iter: 4 / all 48], err_s_label: 0.104077, err_s_domain: 1.744147, err_t_domain: 0.846323
# epoch: 5, [iter: 5 / all 48], err_s_label: 0.164353, err_s_domain: 1.733211, err_t_domain: 0.839943
# epoch: 5, [iter: 6 / all 48], err_s_label: 0.188358, err_s_domain: 1.728236, err_t_domain: 0.844812
# epoch: 5, [iter: 7 / all 48], err_s_label: 0.134492, err_s_domain: 1.771647, err_t_domain: 0.889912
# epoch: 5, [iter: 8 / all 48], err_s_label: 0.209948, err_s_domain: 1.767256, err_t_domain: 0.888882
# epoch: 5, [iter: 9 / all 48], err_s_label: 0.132571, err_s_domain: 1.758937, err_t_domain: 0.912596
# epoch: 5, [iter: 10 / all 48], err_s_label: 0.157538, err_s_domain: 1.772445, err_t_domain: 0.891606
# epoch: 5, [iter: 11 / all 48], err_s_label: 0.185199, err_s_domain: 1.842628, err_t_domain: 0.916222
# epoch: 5, [iter: 12 / all 48], err_s_label: 0.269626, err_s_domain: 1.720847, err_t_domain: 0.904638
# epoch: 5, [iter: 13 / all 48], err_s_label: 0.208065, err_s_domain: 1.823217, err_t_domain: 0.890915
# epoch: 5, [iter: 14 / all 48], err_s_label: 0.202165, err_s_domain: 1.800511, err_t_domain: 0.903397
# epoch: 5, [iter: 15 / all 48], err_s_label: 0.098955, err_s_domain: 1.771572, err_t_domain: 0.907187
# epoch: 5, [iter: 16 / all 48], err_s_label: 0.160396, err_s_domain: 1.769314, err_t_domain: 0.919105
# epoch: 5, [iter: 17 / all 48], err_s_label: 0.185276, err_s_domain: 1.823861, err_t_domain: 0.916297
# epoch: 5, [iter: 18 / all 48], err_s_label: 0.115989, err_s_domain: 1.753550, err_t_domain: 0.929425
# epoch: 5, [iter: 19 / all 48], err_s_label: 0.170392, err_s_domain: 1.778912, err_t_domain: 0.953968
# epoch: 5, [iter: 20 / all 48], err_s_label: 0.148543, err_s_domain: 1.758950, err_t_domain: 0.960869
# epoch: 5, [iter: 21 / all 48], err_s_label: 0.187185, err_s_domain: 1.817257, err_t_domain: 0.937649
# epoch: 5, [iter: 22 / all 48], err_s_label: 0.113856, err_s_domain: 1.766865, err_t_domain: 0.944449
# epoch: 5, [iter: 23 / all 48], err_s_label: 0.219859, err_s_domain: 1.769826, err_t_domain: 0.951611
# epoch: 5, [iter: 24 / all 48], err_s_label: 0.068520, err_s_domain: 1.721250, err_t_domain: 0.959944
# epoch: 5, [iter: 25 / all 48], err_s_label: 0.159130, err_s_domain: 1.729757, err_t_domain: 0.962652
# epoch: 5, [iter: 26 / all 48], err_s_label: 0.087207, err_s_domain: 1.764127, err_t_domain: 0.956757
# epoch: 5, [iter: 27 / all 48], err_s_label: 0.127031, err_s_domain: 1.777196, err_t_domain: 0.951047
# epoch: 5, [iter: 28 / all 48], err_s_label: 0.080810, err_s_domain: 1.748233, err_t_domain: 0.930607
# epoch: 5, [iter: 29 / all 48], err_s_label: 0.063563, err_s_domain: 1.723314, err_t_domain: 0.912394
# epoch: 5, [iter: 30 / all 48], err_s_label: 0.147006, err_s_domain: 1.774933, err_t_domain: 0.904897
# epoch: 5, [iter: 31 / all 48], err_s_label: 0.124132, err_s_domain: 1.738822, err_t_domain: 0.885248
# epoch: 5, [iter: 32 / all 48], err_s_label: 0.159030, err_s_domain: 1.757260, err_t_domain: 0.872635
# epoch: 5, [iter: 33 / all 48], err_s_label: 0.089783, err_s_domain: 1.714283, err_t_domain: 0.856029
# epoch: 5, [iter: 34 / all 48], err_s_label: 0.147966, err_s_domain: 1.732716, err_t_domain: 0.870479
# epoch: 5, [iter: 35 / all 48], err_s_label: 0.140583, err_s_domain: 1.745867, err_t_domain: 0.857840
# epoch: 5, [iter: 36 / all 48], err_s_label: 0.076674, err_s_domain: 1.777442, err_t_domain: 0.850145
# epoch: 5, [iter: 37 / all 48], err_s_label: 0.135134, err_s_domain: 1.744056, err_t_domain: 0.872878
# epoch: 5, [iter: 38 / all 48], err_s_label: 0.112375, err_s_domain: 1.751001, err_t_domain: 0.882277
# epoch: 5, [iter: 39 / all 48], err_s_label: 0.101057, err_s_domain: 1.763941, err_t_domain: 0.868223
# epoch: 5, [iter: 40 / all 48], err_s_label: 0.135710, err_s_domain: 1.786667, err_t_domain: 0.875266
# epoch: 5, [iter: 41 / all 48], err_s_label: 0.114387, err_s_domain: 1.738629, err_t_domain: 0.888124
# epoch: 5, [iter: 42 / all 48], err_s_label: 0.166659, err_s_domain: 1.729426, err_t_domain: 0.901115
# epoch: 5, [iter: 43 / all 48], err_s_label: 0.044783, err_s_domain: 1.722296, err_t_domain: 0.904470
# epoch: 5, [iter: 44 / all 48], err_s_label: 0.043865, err_s_domain: 1.760555, err_t_domain: 0.908187
# epoch: 5, [iter: 45 / all 48], err_s_label: 0.161483, err_s_domain: 1.710272, err_t_domain: 0.912546
# epoch: 5, [iter: 46 / all 48], err_s_label: 0.095334, err_s_domain: 1.742947, err_t_domain: 0.892238
# epoch: 5, [iter: 47 / all 48], err_s_label: 0.063167, err_s_domain: 1.718091, err_t_domain: 0.880664
# epoch: 5, [iter: 48 / all 48], err_s_label: 0.101910, err_s_domain: 1.701799, err_t_domain: 0.893626
# epoch: 5, accuracy of the train dataset: 0.760970
# epoch: 5, accuracy of the test dataset: 0.300585
# epoch: 6, [iter: 1 / all 48], err_s_label: 0.055046, err_s_domain: 1.694898, err_t_domain: 0.897363
# epoch: 6, [iter: 2 / all 48], err_s_label: 0.199688, err_s_domain: 1.725867, err_t_domain: 0.908177
# epoch: 6, [iter: 3 / all 48], err_s_label: 0.076570, err_s_domain: 1.734434, err_t_domain: 0.928119
# epoch: 6, [iter: 4 / all 48], err_s_label: 0.080138, err_s_domain: 1.710823, err_t_domain: 0.940214
# epoch: 6, [iter: 5 / all 48], err_s_label: 0.033847, err_s_domain: 1.694751, err_t_domain: 0.937137
# epoch: 6, [iter: 6 / all 48], err_s_label: 0.110360, err_s_domain: 1.685827, err_t_domain: 0.945413
# epoch: 6, [iter: 7 / all 48], err_s_label: 0.119395, err_s_domain: 1.692750, err_t_domain: 0.945498
# epoch: 6, [iter: 8 / all 48], err_s_label: 0.143857, err_s_domain: 1.657426, err_t_domain: 0.936909
# epoch: 6, [iter: 9 / all 48], err_s_label: 0.063364, err_s_domain: 1.695292, err_t_domain: 0.950034
# epoch: 6, [iter: 10 / all 48], err_s_label: 0.053824, err_s_domain: 1.681981, err_t_domain: 0.961261
# epoch: 6, [iter: 11 / all 48], err_s_label: 0.138965, err_s_domain: 1.754307, err_t_domain: 0.974634
# epoch: 6, [iter: 12 / all 48], err_s_label: 0.087402, err_s_domain: 1.761180, err_t_domain: 0.971671
# epoch: 6, [iter: 13 / all 48], err_s_label: 0.082213, err_s_domain: 1.775017, err_t_domain: 0.976940
# epoch: 6, [iter: 14 / all 48], err_s_label: 0.128418, err_s_domain: 1.793164, err_t_domain: 0.968973
# epoch: 6, [iter: 15 / all 48], err_s_label: 0.049926, err_s_domain: 1.792879, err_t_domain: 0.980866
# epoch: 6, [iter: 16 / all 48], err_s_label: 0.106078, err_s_domain: 1.774107, err_t_domain: 0.963350
# epoch: 6, [iter: 17 / all 48], err_s_label: 0.138915, err_s_domain: 1.833693, err_t_domain: 0.958441
# epoch: 6, [iter: 18 / all 48], err_s_label: 0.104413, err_s_domain: 1.781531, err_t_domain: 0.973118
# epoch: 6, [iter: 19 / all 48], err_s_label: 0.110926, err_s_domain: 1.822537, err_t_domain: 0.961498
# epoch: 6, [iter: 20 / all 48], err_s_label: 0.063440, err_s_domain: 1.789638, err_t_domain: 0.923546
# epoch: 6, [iter: 21 / all 48], err_s_label: 0.127687, err_s_domain: 1.800223, err_t_domain: 0.933191
# epoch: 6, [iter: 22 / all 48], err_s_label: 0.067111, err_s_domain: 1.820646, err_t_domain: 0.906007
# epoch: 6, [iter: 23 / all 48], err_s_label: 0.043916, err_s_domain: 1.805554, err_t_domain: 0.898001
# epoch: 6, [iter: 24 / all 48], err_s_label: 0.063205, err_s_domain: 1.811176, err_t_domain: 0.872039
# epoch: 6, [iter: 25 / all 48], err_s_label: 0.149990, err_s_domain: 1.801664, err_t_domain: 0.872507
# epoch: 6, [iter: 26 / all 48], err_s_label: 0.116113, err_s_domain: 1.817201, err_t_domain: 0.857251
# epoch: 6, [iter: 27 / all 48], err_s_label: 0.101438, err_s_domain: 1.790897, err_t_domain: 0.846196
# epoch: 6, [iter: 28 / all 48], err_s_label: 0.062496, err_s_domain: 1.814399, err_t_domain: 0.842526
# epoch: 6, [iter: 29 / all 48], err_s_label: 0.156893, err_s_domain: 1.826023, err_t_domain: 0.840553
# epoch: 6, [iter: 30 / all 48], err_s_label: 0.151334, err_s_domain: 1.855811, err_t_domain: 0.841322
# epoch: 6, [iter: 31 / all 48], err_s_label: 0.054499, err_s_domain: 1.808622, err_t_domain: 0.824875
# epoch: 6, [iter: 32 / all 48], err_s_label: 0.143290, err_s_domain: 1.877580, err_t_domain: 0.834832
# epoch: 6, [iter: 33 / all 48], err_s_label: 0.175132, err_s_domain: 1.860983, err_t_domain: 0.827751
# epoch: 6, [iter: 34 / all 48], err_s_label: 0.108602, err_s_domain: 1.848902, err_t_domain: 0.822264
# epoch: 6, [iter: 35 / all 48], err_s_label: 0.107154, err_s_domain: 1.843406, err_t_domain: 0.830155
# epoch: 6, [iter: 36 / all 48], err_s_label: 0.148763, err_s_domain: 1.837366, err_t_domain: 0.833198
# epoch: 6, [iter: 37 / all 48], err_s_label: 0.214473, err_s_domain: 1.814860, err_t_domain: 0.825229
# epoch: 6, [iter: 38 / all 48], err_s_label: 0.131460, err_s_domain: 1.829716, err_t_domain: 0.814601
# epoch: 6, [iter: 39 / all 48], err_s_label: 0.094696, err_s_domain: 1.794369, err_t_domain: 0.808518
# epoch: 6, [iter: 40 / all 48], err_s_label: 0.076127, err_s_domain: 1.845564, err_t_domain: 0.803167
# epoch: 6, [iter: 41 / all 48], err_s_label: 0.161895, err_s_domain: 1.852890, err_t_domain: 0.810484
# epoch: 6, [iter: 42 / all 48], err_s_label: 0.141384, err_s_domain: 1.772492, err_t_domain: 0.796975
# epoch: 6, [iter: 43 / all 48], err_s_label: 0.059715, err_s_domain: 1.796848, err_t_domain: 0.798721
# epoch: 6, [iter: 44 / all 48], err_s_label: 0.099582, err_s_domain: 1.744650, err_t_domain: 0.823221
# epoch: 6, [iter: 45 / all 48], err_s_label: 0.115144, err_s_domain: 1.751049, err_t_domain: 0.832682
# epoch: 6, [iter: 46 / all 48], err_s_label: 0.147920, err_s_domain: 1.738858, err_t_domain: 0.839224
# epoch: 6, [iter: 47 / all 48], err_s_label: 0.046948, err_s_domain: 1.738540, err_t_domain: 0.847025
# epoch: 6, [iter: 48 / all 48], err_s_label: 0.188534, err_s_domain: 1.776770, err_t_domain: 0.868929
# epoch: 6, accuracy of the train dataset: 0.855988
# epoch: 6, accuracy of the test dataset: 0.412319
# epoch: 7, [iter: 1 / all 48], err_s_label: 0.037334, err_s_domain: 1.718351, err_t_domain: 0.875158
# epoch: 7, [iter: 2 / all 48], err_s_label: 0.190858, err_s_domain: 1.777762, err_t_domain: 0.876158
# epoch: 7, [iter: 3 / all 48], err_s_label: 0.109053, err_s_domain: 1.725492, err_t_domain: 0.892334
# epoch: 7, [iter: 4 / all 48], err_s_label: 0.290768, err_s_domain: 1.752205, err_t_domain: 0.903995
# epoch: 7, [iter: 5 / all 48], err_s_label: 0.131653, err_s_domain: 1.739584, err_t_domain: 0.909203
# epoch: 7, [iter: 6 / all 48], err_s_label: 0.088112, err_s_domain: 1.746628, err_t_domain: 0.908217
# epoch: 7, [iter: 7 / all 48], err_s_label: 0.120085, err_s_domain: 1.704828, err_t_domain: 0.931684
# epoch: 7, [iter: 8 / all 48], err_s_label: 0.088345, err_s_domain: 1.746687, err_t_domain: 0.926933
# epoch: 7, [iter: 9 / all 48], err_s_label: 0.082388, err_s_domain: 1.755720, err_t_domain: 0.924021
# epoch: 7, [iter: 10 / all 48], err_s_label: 0.103908, err_s_domain: 1.793612, err_t_domain: 0.924891
# epoch: 7, [iter: 11 / all 48], err_s_label: 0.105379, err_s_domain: 1.825115, err_t_domain: 0.936161
# epoch: 7, [iter: 12 / all 48], err_s_label: 0.084544, err_s_domain: 1.857198, err_t_domain: 0.933059
# epoch: 7, [iter: 13 / all 48], err_s_label: 0.143969, err_s_domain: 1.882634, err_t_domain: 0.930728
# epoch: 7, [iter: 14 / all 48], err_s_label: 0.186980, err_s_domain: 1.902977, err_t_domain: 0.958586
# epoch: 7, [iter: 15 / all 48], err_s_label: 0.217649, err_s_domain: 1.927570, err_t_domain: 0.957520
# epoch: 7, [iter: 16 / all 48], err_s_label: 0.238962, err_s_domain: 1.919031, err_t_domain: 0.948338
# epoch: 7, [iter: 17 / all 48], err_s_label: 0.077509, err_s_domain: 1.925084, err_t_domain: 0.956913
# epoch: 7, [iter: 18 / all 48], err_s_label: 0.084072, err_s_domain: 1.925601, err_t_domain: 0.948718
# epoch: 7, [iter: 19 / all 48], err_s_label: 0.213619, err_s_domain: 1.897424, err_t_domain: 0.932875
# epoch: 7, [iter: 20 / all 48], err_s_label: 0.077983, err_s_domain: 1.933741, err_t_domain: 0.926116
# epoch: 7, [iter: 21 / all 48], err_s_label: 0.175553, err_s_domain: 1.916854, err_t_domain: 0.917871
# epoch: 7, [iter: 22 / all 48], err_s_label: 0.102817, err_s_domain: 1.898815, err_t_domain: 0.920120
# epoch: 7, [iter: 23 / all 48], err_s_label: 0.112739, err_s_domain: 1.885173, err_t_domain: 0.911586
# epoch: 7, [iter: 24 / all 48], err_s_label: 0.144823, err_s_domain: 1.856481, err_t_domain: 0.897669
# epoch: 7, [iter: 25 / all 48], err_s_label: 0.151861, err_s_domain: 1.873439, err_t_domain: 0.909762
# epoch: 7, [iter: 26 / all 48], err_s_label: 0.168087, err_s_domain: 1.837751, err_t_domain: 0.910134
# epoch: 7, [iter: 27 / all 48], err_s_label: 0.192943, err_s_domain: 1.849352, err_t_domain: 0.890345
# epoch: 7, [iter: 28 / all 48], err_s_label: 0.170545, err_s_domain: 1.820791, err_t_domain: 0.909319
# epoch: 7, [iter: 29 / all 48], err_s_label: 0.128662, err_s_domain: 1.801861, err_t_domain: 0.899582
# epoch: 7, [iter: 30 / all 48], err_s_label: 0.178744, err_s_domain: 1.840682, err_t_domain: 0.901869
# epoch: 7, [iter: 31 / all 48], err_s_label: 0.161301, err_s_domain: 1.774874, err_t_domain: 0.916808
# epoch: 7, [iter: 32 / all 48], err_s_label: 0.152363, err_s_domain: 1.788373, err_t_domain: 0.906809
# epoch: 7, [iter: 33 / all 48], err_s_label: 0.204116, err_s_domain: 1.759510, err_t_domain: 0.928202
# epoch: 7, [iter: 34 / all 48], err_s_label: 0.153798, err_s_domain: 1.781386, err_t_domain: 0.931825
# epoch: 7, [iter: 35 / all 48], err_s_label: 0.042446, err_s_domain: 1.796086, err_t_domain: 0.921217
# epoch: 7, [iter: 36 / all 48], err_s_label: 0.047789, err_s_domain: 1.740919, err_t_domain: 0.937021
# epoch: 7, [iter: 37 / all 48], err_s_label: 0.148230, err_s_domain: 1.740760, err_t_domain: 0.936142
# epoch: 7, [iter: 38 / all 48], err_s_label: 0.120884, err_s_domain: 1.768396, err_t_domain: 0.931889
# epoch: 7, [iter: 39 / all 48], err_s_label: 0.281215, err_s_domain: 1.753680, err_t_domain: 0.939275
# epoch: 7, [iter: 40 / all 48], err_s_label: 0.140976, err_s_domain: 1.731254, err_t_domain: 0.953968
# epoch: 7, [iter: 41 / all 48], err_s_label: 0.152394, err_s_domain: 1.726542, err_t_domain: 0.956802
# epoch: 7, [iter: 42 / all 48], err_s_label: 0.218290, err_s_domain: 1.737225, err_t_domain: 0.963091
# epoch: 7, [iter: 43 / all 48], err_s_label: 0.141275, err_s_domain: 1.748422, err_t_domain: 0.963506
# epoch: 7, [iter: 44 / all 48], err_s_label: 0.206113, err_s_domain: 1.780313, err_t_domain: 0.978541
# epoch: 7, [iter: 45 / all 48], err_s_label: 0.194683, err_s_domain: 1.771210, err_t_domain: 0.979338
# epoch: 7, [iter: 46 / all 48], err_s_label: 0.217793, err_s_domain: 1.758769, err_t_domain: 0.974556
# epoch: 7, [iter: 47 / all 48], err_s_label: 0.190518, err_s_domain: 1.739575, err_t_domain: 0.953739
# epoch: 7, [iter: 48 / all 48], err_s_label: 0.168946, err_s_domain: 1.704522, err_t_domain: 0.966571
# epoch: 7, accuracy of the train dataset: 0.933190
# epoch: 7, accuracy of the test dataset: 0.536014
# epoch: 8, [iter: 1 / all 48], err_s_label: 0.031707, err_s_domain: 1.731106, err_t_domain: 0.952115
# epoch: 8, [iter: 2 / all 48], err_s_label: 0.058619, err_s_domain: 1.739703, err_t_domain: 0.959583
# epoch: 8, [iter: 3 / all 48], err_s_label: 0.163714, err_s_domain: 1.750849, err_t_domain: 0.945852
# epoch: 8, [iter: 4 / all 48], err_s_label: 0.134600, err_s_domain: 1.727888, err_t_domain: 0.968877
# epoch: 8, [iter: 5 / all 48], err_s_label: 0.149283, err_s_domain: 1.718145, err_t_domain: 0.936931
# epoch: 8, [iter: 6 / all 48], err_s_label: 0.128175, err_s_domain: 1.761576, err_t_domain: 0.917208
# epoch: 8, [iter: 7 / all 48], err_s_label: 0.144812, err_s_domain: 1.752025, err_t_domain: 0.910458
# epoch: 8, [iter: 8 / all 48], err_s_label: 0.095211, err_s_domain: 1.718264, err_t_domain: 0.939267
# epoch: 8, [iter: 9 / all 48], err_s_label: 0.102610, err_s_domain: 1.742915, err_t_domain: 0.929923
# epoch: 8, [iter: 10 / all 48], err_s_label: 0.161467, err_s_domain: 1.698182, err_t_domain: 0.903062
# epoch: 8, [iter: 11 / all 48], err_s_label: 0.159108, err_s_domain: 1.725252, err_t_domain: 0.907605
# epoch: 8, [iter: 12 / all 48], err_s_label: 0.274456, err_s_domain: 1.723837, err_t_domain: 0.922835
# epoch: 8, [iter: 13 / all 48], err_s_label: 0.142281, err_s_domain: 1.711976, err_t_domain: 0.897541
# epoch: 8, [iter: 14 / all 48], err_s_label: 0.056379, err_s_domain: 1.705600, err_t_domain: 0.894596
# epoch: 8, [iter: 15 / all 48], err_s_label: 0.145227, err_s_domain: 1.726090, err_t_domain: 0.899987
# epoch: 8, [iter: 16 / all 48], err_s_label: 0.133796, err_s_domain: 1.706375, err_t_domain: 0.910546
# epoch: 8, [iter: 17 / all 48], err_s_label: 0.056689, err_s_domain: 1.695939, err_t_domain: 0.905904
# epoch: 8, [iter: 18 / all 48], err_s_label: 0.079553, err_s_domain: 1.751466, err_t_domain: 0.901639
# epoch: 8, [iter: 19 / all 48], err_s_label: 0.072209, err_s_domain: 1.714317, err_t_domain: 0.897169
# epoch: 8, [iter: 20 / all 48], err_s_label: 0.080935, err_s_domain: 1.764526, err_t_domain: 0.897974
# epoch: 8, [iter: 21 / all 48], err_s_label: 0.158803, err_s_domain: 1.765238, err_t_domain: 0.895964
# epoch: 8, [iter: 22 / all 48], err_s_label: 0.056927, err_s_domain: 1.789092, err_t_domain: 0.899901
# epoch: 8, [iter: 23 / all 48], err_s_label: 0.063015, err_s_domain: 1.797348, err_t_domain: 0.901503
# epoch: 8, [iter: 24 / all 48], err_s_label: 0.119028, err_s_domain: 1.762271, err_t_domain: 0.912340
# epoch: 8, [iter: 25 / all 48], err_s_label: 0.177810, err_s_domain: 1.847973, err_t_domain: 0.919339
# epoch: 8, [iter: 26 / all 48], err_s_label: 0.097095, err_s_domain: 1.807790, err_t_domain: 0.910859
# epoch: 8, [iter: 27 / all 48], err_s_label: 0.196546, err_s_domain: 1.818797, err_t_domain: 0.919688
# epoch: 8, [iter: 28 / all 48], err_s_label: 0.110865, err_s_domain: 1.789418, err_t_domain: 0.927366
# epoch: 8, [iter: 29 / all 48], err_s_label: 0.057561, err_s_domain: 1.758876, err_t_domain: 0.926052
# epoch: 8, [iter: 30 / all 48], err_s_label: 0.068247, err_s_domain: 1.759683, err_t_domain: 0.928686
# epoch: 8, [iter: 31 / all 48], err_s_label: 0.140561, err_s_domain: 1.749372, err_t_domain: 0.925069
# epoch: 8, [iter: 32 / all 48], err_s_label: 0.074505, err_s_domain: 1.744815, err_t_domain: 0.911475
# epoch: 8, [iter: 33 / all 48], err_s_label: 0.085150, err_s_domain: 1.684881, err_t_domain: 0.907744
# epoch: 8, [iter: 34 / all 48], err_s_label: 0.073789, err_s_domain: 1.698288, err_t_domain: 0.915645
# epoch: 8, [iter: 35 / all 48], err_s_label: 0.106933, err_s_domain: 1.676569, err_t_domain: 0.913289
# epoch: 8, [iter: 36 / all 48], err_s_label: 0.062095, err_s_domain: 1.675739, err_t_domain: 0.912388
# epoch: 8, [iter: 37 / all 48], err_s_label: 0.166990, err_s_domain: 1.649269, err_t_domain: 0.896715
# epoch: 8, [iter: 38 / all 48], err_s_label: 0.051809, err_s_domain: 1.628838, err_t_domain: 0.894312
# epoch: 8, [iter: 39 / all 48], err_s_label: 0.140017, err_s_domain: 1.633288, err_t_domain: 0.884458
# epoch: 8, [iter: 40 / all 48], err_s_label: 0.086651, err_s_domain: 1.603445, err_t_domain: 0.881735
# epoch: 8, [iter: 41 / all 48], err_s_label: 0.084597, err_s_domain: 1.582163, err_t_domain: 0.895979
# epoch: 8, [iter: 42 / all 48], err_s_label: 0.252510, err_s_domain: 1.613786, err_t_domain: 0.873687
# epoch: 8, [iter: 43 / all 48], err_s_label: 0.130318, err_s_domain: 1.579927, err_t_domain: 0.887222
# epoch: 8, [iter: 44 / all 48], err_s_label: 0.207643, err_s_domain: 1.548742, err_t_domain: 0.874756
# epoch: 8, [iter: 45 / all 48], err_s_label: 0.030363, err_s_domain: 1.582373, err_t_domain: 0.871370
# epoch: 8, [iter: 46 / all 48], err_s_label: 0.075482, err_s_domain: 1.555319, err_t_domain: 0.862549
# epoch: 8, [iter: 47 / all 48], err_s_label: 0.064635, err_s_domain: 1.627625, err_t_domain: 0.849594
# epoch: 8, [iter: 48 / all 48], err_s_label: 0.089365, err_s_domain: 1.615710, err_t_domain: 0.856812
# epoch: 8, accuracy of the train dataset: 0.943418
# epoch: 8, accuracy of the test dataset: 0.620769
# epoch: 9, [iter: 1 / all 48], err_s_label: 0.053340, err_s_domain: 1.697358, err_t_domain: 0.859502
# epoch: 9, [iter: 2 / all 48], err_s_label: 0.052409, err_s_domain: 1.736770, err_t_domain: 0.853053
# epoch: 9, [iter: 3 / all 48], err_s_label: 0.029390, err_s_domain: 1.805448, err_t_domain: 0.851647
# epoch: 9, [iter: 4 / all 48], err_s_label: 0.138918, err_s_domain: 1.806908, err_t_domain: 0.847597
# epoch: 9, [iter: 5 / all 48], err_s_label: 0.079049, err_s_domain: 1.805007, err_t_domain: 0.858938
# epoch: 9, [iter: 6 / all 48], err_s_label: 0.047335, err_s_domain: 1.900847, err_t_domain: 0.850534
# epoch: 9, [iter: 7 / all 48], err_s_label: 0.145448, err_s_domain: 1.923651, err_t_domain: 0.853268
# epoch: 9, [iter: 8 / all 48], err_s_label: 0.163850, err_s_domain: 1.917120, err_t_domain: 0.844743
# epoch: 9, [iter: 9 / all 48], err_s_label: 0.166830, err_s_domain: 1.965637, err_t_domain: 0.848126
# epoch: 9, [iter: 10 / all 48], err_s_label: 0.236740, err_s_domain: 1.954000, err_t_domain: 0.842507
# epoch: 9, [iter: 11 / all 48], err_s_label: 0.067242, err_s_domain: 1.951405, err_t_domain: 0.837219
# epoch: 9, [iter: 12 / all 48], err_s_label: 0.048024, err_s_domain: 1.950039, err_t_domain: 0.843684
# epoch: 9, [iter: 13 / all 48], err_s_label: 0.058959, err_s_domain: 1.945832, err_t_domain: 0.823171
# epoch: 9, [iter: 14 / all 48], err_s_label: 0.107422, err_s_domain: 1.958182, err_t_domain: 0.831003
# epoch: 9, [iter: 15 / all 48], err_s_label: 0.190366, err_s_domain: 1.955627, err_t_domain: 0.828278
# epoch: 9, [iter: 16 / all 48], err_s_label: 0.084719, err_s_domain: 1.923231, err_t_domain: 0.827791
# epoch: 9, [iter: 17 / all 48], err_s_label: 0.086222, err_s_domain: 1.893570, err_t_domain: 0.846352
# epoch: 9, [iter: 18 / all 48], err_s_label: 0.031016, err_s_domain: 1.871532, err_t_domain: 0.837006
# epoch: 9, [iter: 19 / all 48], err_s_label: 0.092380, err_s_domain: 1.846054, err_t_domain: 0.851751
# epoch: 9, [iter: 20 / all 48], err_s_label: 0.066157, err_s_domain: 1.826269, err_t_domain: 0.856575
# epoch: 9, [iter: 21 / all 48], err_s_label: 0.049567, err_s_domain: 1.801253, err_t_domain: 0.847419
# epoch: 9, [iter: 22 / all 48], err_s_label: 0.060546, err_s_domain: 1.808614, err_t_domain: 0.885483
# epoch: 9, [iter: 23 / all 48], err_s_label: 0.106991, err_s_domain: 1.769266, err_t_domain: 0.882280
# epoch: 9, [iter: 24 / all 48], err_s_label: 0.111814, err_s_domain: 1.725005, err_t_domain: 0.902528
# epoch: 9, [iter: 25 / all 48], err_s_label: 0.070669, err_s_domain: 1.747268, err_t_domain: 0.921090
# epoch: 9, [iter: 26 / all 48], err_s_label: 0.150681, err_s_domain: 1.742896, err_t_domain: 0.920450
# epoch: 9, [iter: 27 / all 48], err_s_label: 0.039950, err_s_domain: 1.728388, err_t_domain: 0.934390
# epoch: 9, [iter: 28 / all 48], err_s_label: 0.198314, err_s_domain: 1.732177, err_t_domain: 0.936275
# epoch: 9, [iter: 29 / all 48], err_s_label: 0.039058, err_s_domain: 1.775618, err_t_domain: 0.941187
# ...
# epoch: 34, [iter: 28 / all 48], err_s_label: 0.006251, err_s_domain: 1.811998, err_t_domain: 0.710764
# epoch: 34, [iter: 29 / all 48], err_s_label: 0.073946, err_s_domain: 1.808891, err_t_domain: 0.709917
# epoch: 34, [iter: 30 / all 48], err_s_label: 0.021758, err_s_domain: 1.806030, err_t_domain: 0.709859
# epoch: 34, [iter: 31 / all 48], err_s_label: 0.130003, err_s_domain: 1.836673, err_t_domain: 0.706515
# epoch: 34, [iter: 32 / all 48], err_s_label: 0.006349, err_s_domain: 1.830998, err_t_domain: 0.704999
# epoch: 34, [iter: 33 / all 48], err_s_label: 0.034588, err_s_domain: 1.819516, err_t_domain: 0.708000
# epoch: 34, [iter: 34 / all 48], err_s_label: 0.102483, err_s_domain: 1.842464, err_t_domain: 0.706694
# epoch: 34, [iter: 35 / all 48], err_s_label: 0.033098, err_s_domain: 1.826744, err_t_domain: 0.704884
# epoch: 34, [iter: 36 / all 48], err_s_label: 0.017331, err_s_domain: 1.826824, err_t_domain: 0.705477
# epoch: 34, [iter: 37 / all 48], err_s_label: 0.101620, err_s_domain: 1.802289, err_t_domain: 0.704811
# epoch: 34, [iter: 38 / all 48], err_s_label: 0.090665, err_s_domain: 1.801467, err_t_domain: 0.702921
# epoch: 34, [iter: 39 / all 48], err_s_label: 0.054390, err_s_domain: 1.824347, err_t_domain: 0.701033
# epoch: 34, [iter: 40 / all 48], err_s_label: 0.011797, err_s_domain: 1.813108, err_t_domain: 0.702867
# epoch: 34, [iter: 41 / all 48], err_s_label: 0.009700, err_s_domain: 1.820764, err_t_domain: 0.705521
# epoch: 34, [iter: 42 / all 48], err_s_label: 0.076421, err_s_domain: 1.818891, err_t_domain: 0.702043
# epoch: 34, [iter: 43 / all 48], err_s_label: 0.017455, err_s_domain: 1.802762, err_t_domain: 0.703284
# epoch: 34, [iter: 44 / all 48], err_s_label: 0.016628, err_s_domain: 1.789091, err_t_domain: 0.703858
# epoch: 34, [iter: 45 / all 48], err_s_label: 0.051662, err_s_domain: 1.789873, err_t_domain: 0.700975
# epoch: 34, [iter: 46 / all 48], err_s_label: 0.010574, err_s_domain: 1.757708, err_t_domain: 0.704939
# epoch: 34, [iter: 47 / all 48], err_s_label: 0.016825, err_s_domain: 1.784161, err_t_domain: 0.705650
# epoch: 34, [iter: 48 / all 48], err_s_label: 0.003776, err_s_domain: 1.748479, err_t_domain: 0.705892
# epoch: 34, accuracy of the train dataset: 0.973441
# epoch: 34, accuracy of the test dataset: 0.580809
# epoch: 35, [iter: 1 / all 48], err_s_label: 0.016187, err_s_domain: 1.768837, err_t_domain: 0.708272
# epoch: 35, [iter: 2 / all 48], err_s_label: 0.012353, err_s_domain: 1.784876, err_t_domain: 0.708048
# epoch: 35, [iter: 3 / all 48], err_s_label: 0.014505, err_s_domain: 1.767828, err_t_domain: 0.708955
# epoch: 35, [iter: 4 / all 48], err_s_label: 0.010816, err_s_domain: 1.811831, err_t_domain: 0.709551
# epoch: 35, [iter: 5 / all 48], err_s_label: 0.006203, err_s_domain: 1.798130, err_t_domain: 0.708986
# epoch: 35, [iter: 6 / all 48], err_s_label: 0.020049, err_s_domain: 1.801534, err_t_domain: 0.711537
# epoch: 35, [iter: 7 / all 48], err_s_label: 0.042051, err_s_domain: 1.770736, err_t_domain: 0.709127
# epoch: 35, [iter: 8 / all 48], err_s_label: 0.007002, err_s_domain: 1.781662, err_t_domain: 0.711930
# epoch: 35, [iter: 9 / all 48], err_s_label: 0.025224, err_s_domain: 1.826035, err_t_domain: 0.712161
# epoch: 35, [iter: 10 / all 48], err_s_label: 0.056163, err_s_domain: 1.831106, err_t_domain: 0.709766
# epoch: 35, [iter: 11 / all 48], err_s_label: 0.058389, err_s_domain: 1.832160, err_t_domain: 0.710591
# epoch: 35, [iter: 12 / all 48], err_s_label: 0.019134, err_s_domain: 1.830571, err_t_domain: 0.710216
# epoch: 35, [iter: 13 / all 48], err_s_label: 0.006208, err_s_domain: 1.825594, err_t_domain: 0.710423
# epoch: 35, [iter: 14 / all 48], err_s_label: 0.020288, err_s_domain: 1.837904, err_t_domain: 0.708773
# epoch: 35, [iter: 15 / all 48], err_s_label: 0.050572, err_s_domain: 1.820091, err_t_domain: 0.707736
# epoch: 35, [iter: 16 / all 48], err_s_label: 0.014520, err_s_domain: 1.842580, err_t_domain: 0.707411
# epoch: 35, [iter: 17 / all 48], err_s_label: 0.027038, err_s_domain: 1.821644, err_t_domain: 0.705748
# epoch: 35, [iter: 18 / all 48], err_s_label: 0.013449, err_s_domain: 1.811528, err_t_domain: 0.707371
# epoch: 35, [iter: 19 / all 48], err_s_label: 0.007334, err_s_domain: 1.808218, err_t_domain: 0.703614
# epoch: 35, [iter: 20 / all 48], err_s_label: 0.044139, err_s_domain: 1.781566, err_t_domain: 0.704848
# epoch: 35, [iter: 21 / all 48], err_s_label: 0.009667, err_s_domain: 1.787768, err_t_domain: 0.704127
# epoch: 35, [iter: 22 / all 48], err_s_label: 0.008771, err_s_domain: 1.793625, err_t_domain: 0.703207
# epoch: 35, [iter: 23 / all 48], err_s_label: 0.021355, err_s_domain: 1.782875, err_t_domain: 0.701017
# epoch: 35, [iter: 24 / all 48], err_s_label: 0.009656, err_s_domain: 1.795900, err_t_domain: 0.701066
# epoch: 35, [iter: 25 / all 48], err_s_label: 0.063058, err_s_domain: 1.771546, err_t_domain: 0.703220
# epoch: 35, [iter: 26 / all 48], err_s_label: 0.005332, err_s_domain: 1.751860, err_t_domain: 0.700923
# epoch: 35, [iter: 27 / all 48], err_s_label: 0.006253, err_s_domain: 1.764096, err_t_domain: 0.700170
# epoch: 35, [iter: 28 / all 48], err_s_label: 0.013892, err_s_domain: 1.752513, err_t_domain: 0.701220
# epoch: 35, [iter: 29 / all 48], err_s_label: 0.003062, err_s_domain: 1.753570, err_t_domain: 0.702236
# epoch: 35, [iter: 30 / all 48], err_s_label: 0.024634, err_s_domain: 1.724075, err_t_domain: 0.701582
# epoch: 35, [iter: 31 / all 48], err_s_label: 0.031832, err_s_domain: 1.742434, err_t_domain: 0.701940
# epoch: 35, [iter: 32 / all 48], err_s_label: 0.011237, err_s_domain: 1.751565, err_t_domain: 0.702687
# epoch: 35, [iter: 33 / all 48], err_s_label: 0.004118, err_s_domain: 1.739118, err_t_domain: 0.705263
# epoch: 35, [iter: 34 / all 48], err_s_label: 0.004171, err_s_domain: 1.770296, err_t_domain: 0.705583
# epoch: 35, [iter: 35 / all 48], err_s_label: 0.003126, err_s_domain: 1.759480, err_t_domain: 0.707530
# epoch: 35, [iter: 36 / all 48], err_s_label: 0.003099, err_s_domain: 1.768648, err_t_domain: 0.708498
# epoch: 35, [iter: 37 / all 48], err_s_label: 0.014738, err_s_domain: 1.771958, err_t_domain: 0.708702
# epoch: 35, [iter: 38 / all 48], err_s_label: 0.013924, err_s_domain: 1.794501, err_t_domain: 0.712575
# epoch: 35, [iter: 39 / all 48], err_s_label: 0.006052, err_s_domain: 1.771059, err_t_domain: 0.707344
# epoch: 35, [iter: 40 / all 48], err_s_label: 0.006449, err_s_domain: 1.800163, err_t_domain: 0.710037
# epoch: 35, [iter: 41 / all 48], err_s_label: 0.037196, err_s_domain: 1.808167, err_t_domain: 0.711348
# epoch: 35, [iter: 42 / all 48], err_s_label: 0.015572, err_s_domain: 1.774167, err_t_domain: 0.712557
# epoch: 35, [iter: 43 / all 48], err_s_label: 0.015840, err_s_domain: 1.820053, err_t_domain: 0.711935
# epoch: 35, [iter: 44 / all 48], err_s_label: 0.013724, err_s_domain: 1.809822, err_t_domain: 0.710558
# epoch: 35, [iter: 45 / all 48], err_s_label: 0.005928, err_s_domain: 1.826960, err_t_domain: 0.709790
# epoch: 35, [iter: 46 / all 48], err_s_label: 0.028701, err_s_domain: 1.822757, err_t_domain: 0.707392
# epoch: 35, [iter: 47 / all 48], err_s_label: 0.012125, err_s_domain: 1.826467, err_t_domain: 0.709163
# epoch: 35, [iter: 48 / all 48], err_s_label: 0.052034, err_s_domain: 1.828984, err_t_domain: 0.709345
# epoch: 35, accuracy of the train dataset: 0.969977
# epoch: 35, accuracy of the test dataset: 0.672690
# epoch: 36, [iter: 1 / all 48], err_s_label: 0.003849, err_s_domain: 1.828558, err_t_domain: 0.709787
# epoch: 36, [iter: 2 / all 48], err_s_label: 0.004907, err_s_domain: 1.813674, err_t_domain: 0.708270
# epoch: 36, [iter: 3 / all 48], err_s_label: 0.033905, err_s_domain: 1.799874, err_t_domain: 0.706847
# epoch: 36, [iter: 4 / all 48], err_s_label: 0.006591, err_s_domain: 1.814519, err_t_domain: 0.705088
# epoch: 36, [iter: 5 / all 48], err_s_label: 0.003834, err_s_domain: 1.813548, err_t_domain: 0.704462
# epoch: 36, [iter: 6 / all 48], err_s_label: 0.010840, err_s_domain: 1.807242, err_t_domain: 0.705629
# epoch: 36, [iter: 7 / all 48], err_s_label: 0.006589, err_s_domain: 1.811601, err_t_domain: 0.703255
# epoch: 36, [iter: 8 / all 48], err_s_label: 0.049651, err_s_domain: 1.803209, err_t_domain: 0.702069
# epoch: 36, [iter: 9 / all 48], err_s_label: 0.027238, err_s_domain: 1.811636, err_t_domain: 0.702343
# epoch: 36, [iter: 10 / all 48], err_s_label: 0.005857, err_s_domain: 1.800547, err_t_domain: 0.702792
# epoch: 36, [iter: 11 / all 48], err_s_label: 0.017162, err_s_domain: 1.801236, err_t_domain: 0.701517
# epoch: 36, [iter: 12 / all 48], err_s_label: 0.007733, err_s_domain: 1.804561, err_t_domain: 0.700946
# epoch: 36, [iter: 13 / all 48], err_s_label: 0.066572, err_s_domain: 1.782122, err_t_domain: 0.699625
# epoch: 36, [iter: 14 / all 48], err_s_label: 0.010367, err_s_domain: 1.786169, err_t_domain: 0.699693
# epoch: 36, [iter: 15 / all 48], err_s_label: 0.011610, err_s_domain: 1.798532, err_t_domain: 0.700601
# epoch: 36, [iter: 16 / all 48], err_s_label: 0.016461, err_s_domain: 1.791096, err_t_domain: 0.699165
# epoch: 36, [iter: 17 / all 48], err_s_label: 0.047879, err_s_domain: 1.754311, err_t_domain: 0.699788
# epoch: 36, [iter: 18 / all 48], err_s_label: 0.013070, err_s_domain: 1.759723, err_t_domain: 0.699153
# epoch: 36, [iter: 19 / all 48], err_s_label: 0.003338, err_s_domain: 1.767522, err_t_domain: 0.696961
# epoch: 36, [iter: 20 / all 48], err_s_label: 0.011734, err_s_domain: 1.767143, err_t_domain: 0.698472
# epoch: 36, [iter: 21 / all 48], err_s_label: 0.001541, err_s_domain: 1.753601, err_t_domain: 0.699200
# epoch: 36, [iter: 22 / all 48], err_s_label: 0.004224, err_s_domain: 1.741914, err_t_domain: 0.698007
# epoch: 36, [iter: 23 / all 48], err_s_label: 0.027251, err_s_domain: 1.754486, err_t_domain: 0.699665
# epoch: 36, [iter: 24 / all 48], err_s_label: 0.003602, err_s_domain: 1.739537, err_t_domain: 0.699351
# epoch: 36, [iter: 25 / all 48], err_s_label: 0.008490, err_s_domain: 1.754452, err_t_domain: 0.697931
# epoch: 36, [iter: 26 / all 48], err_s_label: 0.010744, err_s_domain: 1.746634, err_t_domain: 0.699796
# epoch: 36, [iter: 27 / all 48], err_s_label: 0.007306, err_s_domain: 1.768633, err_t_domain: 0.700253
# epoch: 36, [iter: 28 / all 48], err_s_label: 0.020559, err_s_domain: 1.735353, err_t_domain: 0.699066
# epoch: 36, [iter: 29 / all 48], err_s_label: 0.009237, err_s_domain: 1.780978, err_t_domain: 0.699554
# epoch: 36, [iter: 30 / all 48], err_s_label: 0.020544, err_s_domain: 1.785197, err_t_domain: 0.699027
# epoch: 36, [iter: 31 / all 48], err_s_label: 0.003778, err_s_domain: 1.802034, err_t_domain: 0.699518
# epoch: 36, [iter: 32 / all 48], err_s_label: 0.064924, err_s_domain: 1.825367, err_t_domain: 0.699115
# epoch: 36, [iter: 33 / all 48], err_s_label: 0.060088, err_s_domain: 1.831423, err_t_domain: 0.700438
# epoch: 36, [iter: 34 / all 48], err_s_label: 0.013771, err_s_domain: 1.835159, err_t_domain: 0.698379
# epoch: 36, [iter: 35 / all 48], err_s_label: 0.004655, err_s_domain: 1.836747, err_t_domain: 0.699551
# epoch: 36, [iter: 36 / all 48], err_s_label: 0.001563, err_s_domain: 1.820204, err_t_domain: 0.700386
# epoch: 36, [iter: 37 / all 48], err_s_label: 0.044868, err_s_domain: 1.826138, err_t_domain: 0.698046
# epoch: 36, [iter: 38 / all 48], err_s_label: 0.016106, err_s_domain: 1.847888, err_t_domain: 0.698516
# epoch: 36, [iter: 39 / all 48], err_s_label: 0.026354, err_s_domain: 1.851759, err_t_domain: 0.698618
# epoch: 36, [iter: 40 / all 48], err_s_label: 0.008382, err_s_domain: 1.856331, err_t_domain: 0.698528
# epoch: 36, [iter: 41 / all 48], err_s_label: 0.074346, err_s_domain: 1.829944, err_t_domain: 0.699094
# epoch: 36, [iter: 42 / all 48], err_s_label: 0.109029, err_s_domain: 1.842458, err_t_domain: 0.698514
# epoch: 36, [iter: 43 / all 48], err_s_label: 0.004048, err_s_domain: 1.848046, err_t_domain: 0.698608
# epoch: 36, [iter: 44 / all 48], err_s_label: 0.008451, err_s_domain: 1.834612, err_t_domain: 0.699255
# epoch: 36, [iter: 45 / all 48], err_s_label: 0.003959, err_s_domain: 1.846945, err_t_domain: 0.697946
# epoch: 36, [iter: 46 / all 48], err_s_label: 0.064801, err_s_domain: 1.820818, err_t_domain: 0.697965
# epoch: 36, [iter: 47 / all 48], err_s_label: 0.011624, err_s_domain: 1.821300, err_t_domain: 0.699416
# epoch: 36, [iter: 48 / all 48], err_s_label: 0.017815, err_s_domain: 1.816646, err_t_domain: 0.699415
# epoch: 36, accuracy of the train dataset: 0.938469
# epoch: 36, accuracy of the test dataset: 0.642403
# epoch: 37, [iter: 1 / all 48], err_s_label: 0.003860, err_s_domain: 1.821576, err_t_domain: 0.699189
# epoch: 37, [iter: 2 / all 48], err_s_label: 0.013558, err_s_domain: 1.803177, err_t_domain: 0.698472
# epoch: 37, [iter: 3 / all 48], err_s_label: 0.035881, err_s_domain: 1.846523, err_t_domain: 0.698887
# epoch: 37, [iter: 4 / all 48], err_s_label: 0.001449, err_s_domain: 1.791998, err_t_domain: 0.697949
# epoch: 37, [iter: 5 / all 48], err_s_label: 0.013833, err_s_domain: 1.818514, err_t_domain: 0.698611
# epoch: 37, [iter: 6 / all 48], err_s_label: 0.019710, err_s_domain: 1.797502, err_t_domain: 0.698421
# epoch: 37, [iter: 7 / all 48], err_s_label: 0.002080, err_s_domain: 1.785596, err_t_domain: 0.698994
# epoch: 37, [iter: 8 / all 48], err_s_label: 0.009399, err_s_domain: 1.782513, err_t_domain: 0.700896
# epoch: 37, [iter: 9 / all 48], err_s_label: 0.016196, err_s_domain: 1.790804, err_t_domain: 0.698485
# epoch: 37, [iter: 10 / all 48], err_s_label: 0.018081, err_s_domain: 1.758014, err_t_domain: 0.698599
# epoch: 37, [iter: 11 / all 48], err_s_label: 0.012040, err_s_domain: 1.782692, err_t_domain: 0.697304
# epoch: 37, [iter: 12 / all 48], err_s_label: 0.012135, err_s_domain: 1.778018, err_t_domain: 0.699130
# epoch: 37, [iter: 13 / all 48], err_s_label: 0.022535, err_s_domain: 1.790191, err_t_domain: 0.698141
# epoch: 37, [iter: 14 / all 48], err_s_label: 0.015587, err_s_domain: 1.767210, err_t_domain: 0.697782
# epoch: 37, [iter: 15 / all 48], err_s_label: 0.011177, err_s_domain: 1.767348, err_t_domain: 0.697017
# epoch: 37, [iter: 16 / all 48], err_s_label: 0.006077, err_s_domain: 1.769354, err_t_domain: 0.697759
# epoch: 37, [iter: 17 / all 48], err_s_label: 0.002799, err_s_domain: 1.764412, err_t_domain: 0.697227
# epoch: 37, [iter: 18 / all 48], err_s_label: 0.010348, err_s_domain: 1.786838, err_t_domain: 0.696798
# epoch: 37, [iter: 19 / all 48], err_s_label: 0.012385, err_s_domain: 1.787034, err_t_domain: 0.696346
# epoch: 37, [iter: 20 / all 48], err_s_label: 0.013613, err_s_domain: 1.791914, err_t_domain: 0.694677
# epoch: 37, [iter: 21 / all 48], err_s_label: 0.008688, err_s_domain: 1.784045, err_t_domain: 0.694949
# epoch: 37, [iter: 22 / all 48], err_s_label: 0.004804, err_s_domain: 1.799612, err_t_domain: 0.694458
# epoch: 37, [iter: 23 / all 48], err_s_label: 0.025500, err_s_domain: 1.826211, err_t_domain: 0.693705
# epoch: 37, [iter: 24 / all 48], err_s_label: 0.005408, err_s_domain: 1.812510, err_t_domain: 0.693869
# epoch: 37, [iter: 25 / all 48], err_s_label: 0.005195, err_s_domain: 1.816590, err_t_domain: 0.693363
# epoch: 37, [iter: 26 / all 48], err_s_label: 0.003854, err_s_domain: 1.841748, err_t_domain: 0.693963
# epoch: 37, [iter: 27 / all 48], err_s_label: 0.013439, err_s_domain: 1.845386, err_t_domain: 0.693065
# epoch: 37, [iter: 28 / all 48], err_s_label: 0.032173, err_s_domain: 1.827335, err_t_domain: 0.691812
# epoch: 37, [iter: 29 / all 48], err_s_label: 0.056141, err_s_domain: 1.819284, err_t_domain: 0.691658
# epoch: 37, [iter: 30 / all 48], err_s_label: 0.030366, err_s_domain: 1.808224, err_t_domain: 0.692530
# epoch: 37, [iter: 31 / all 48], err_s_label: 0.002294, err_s_domain: 1.839295, err_t_domain: 0.691113
# epoch: 37, [iter: 32 / all 48], err_s_label: 0.001874, err_s_domain: 1.822306, err_t_domain: 0.691960
# epoch: 37, [iter: 33 / all 48], err_s_label: 0.009089, err_s_domain: 1.835165, err_t_domain: 0.691682
# epoch: 37, [iter: 34 / all 48], err_s_label: 0.040968, err_s_domain: 1.801324, err_t_domain: 0.691748
# epoch: 37, [iter: 35 / all 48], err_s_label: 0.080517, err_s_domain: 1.861720, err_t_domain: 0.691163
# epoch: 37, [iter: 36 / all 48], err_s_label: 0.055907, err_s_domain: 1.835672, err_t_domain: 0.692148
# epoch: 37, [iter: 37 / all 48], err_s_label: 0.106876, err_s_domain: 1.820623, err_t_domain: 0.690986
