# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffreyfeng99/SYDE_522_A3/blob/master/SYDE_522_Assignment_3_joeydev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Submission Notes
# Group members:
#
# Jeffrey Feng, 20704800
#
# Joey Kuang, 20726074

# %% [markdown]
# # Import statements

# %%
import os
import pandas as pd
import numpy as np
import random
from PIL import Image
from tqdm import tqdm
from datetime import datetime

import torch
import torch.nn as nn
import torch.utils.data as data
from torch.autograd import Function
import torch.backends.cudnn as cudnn
from torchvision import transforms
from torchvision import datasets
from torchvision import models
import torch.optim as optim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Config

# %%
cuda = True
cudnn.benchmark = True

model_name = "resnet50"

LR = 1e-3
BATCH_SIZE = 32
IMAGE_SIZE = 224 #227
# FT_OUT_SIZE = 512
N_EPOCH = 50

# %% [markdown]
# # Data loader

# %%
dataset_root = '/content/drive/MyDrive/4B/SYDE-522/data'
output_root = '/content/drive/MyDrive/4B/SYDE-522/submission/04032022_resnet50_aug'
source_dataset_name = 'train_set'
target_dataset_name = 'test_set'

source_image_root = os.path.join(dataset_root, source_dataset_name)
target_image_root = os.path.join(dataset_root, target_dataset_name)

train_label_list = os.path.join(dataset_root, 'train_labels.csv')

os.makedirs(output_root, exist_ok=True)

# %%
class GetLoader(data.Dataset):
    def __init__(self, data_root, data_list=None, transform=None):
        self.root = data_root
        self.transform = transform

        # we only pass data_list if it's training set
        if data_list is not None:
            df = pd.read_csv(data_list)
            self.img_paths = df['dir'].to_list()

            if 'label2' in df.columns:
                self.img_labels = df['label2'].to_list()
            else: 
                self.img_labels = ['0' for i in range(len(self.img_paths))]

            if 'label1' in df.columns:
                self.domain_labels = df['label1'].to_list()
            else: 
                self.domain_labels = ['0' for i in range(len(self.img_paths))]
        else:
            # Walk through test folder - we don't need labels
            self.img_paths = [f for root,dirs,files in os.walk(data_root) for f in files if f.endswith('.png')]
            self.img_labels = ['0' for i in range(len(self.img_paths))]
            self.domain_labels = ['0' for i in range(len(self.img_paths))]

        self.n_data = len(self.img_paths)

    def __getitem__(self, item):
        img_paths, labels, domain_labels = self.img_paths[item%self.n_data], self.img_labels[item%self.n_data], self.domain_labels[item%self.n_data]
        imgs = Image.open(os.path.join(self.root, img_paths)).convert('RGB')

        if self.transform is not None:

            if isinstance(self.transform, list):
                tform = self.transform[int(domain_labels)]
            else:
                tform = self.transform

            imgs = tform(imgs)
            labels = int(labels)
            domain_labels = int(domain_labels)

        return imgs, labels, domain_labels, img_paths

    def __len__(self):
        return self.n_data

# %%
# Preprocess data
def preprocess_multiple_fn(mus, stds):
    tforms = []

    for i in range(len(mus)):
        tforms.append(preprocess_fn(mu=mus[i], std=stds[i]))
    
    return tforms

def preprocess_fn(mu=(0.6399, 0.6076, 0.5603), std=(0.3065, 0.3082, 0.3353), aug=False):
  if aug:
    img_transform = transforms.Compose([
        transforms.RandomCrop(IMAGE_SIZE),
        transforms.RandomHorizontalFlip(0.5),
        transforms.RandomRotation(15),
        transforms.ColorJitter(brightness=0.5, saturation=0.5),
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize(mean=mu, std=std) 
    ])
  else:
    img_transform = transforms.Compose([
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize(mean=mu, std=std) 
    ])

  return img_transform

def prep_dataloader(image_root, label_list=None, img_transform=None, 
                    drop_last=False, shuffle=True):
    dataset = GetLoader(
        data_root=image_root,
        data_list=label_list,
        transform=img_transform
    )

    dataloader = data.DataLoader(
        dataset=dataset,
        batch_size=BATCH_SIZE,
        shuffle=shuffle,
        num_workers=4,
        drop_last=drop_last)
    
    return dataset, dataloader

# %% [markdown]
# # Model definition

# %%
# if False, then we are feature extracting
def set_parameter_requires_grad(model, finetune):
    for param in model.parameters():
        param.requires_grad = finetune

# %%
class ReverseLayerF(Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None


class CNNModel(nn.Module):

    def __init__(self, model_name="resnet18"):
        super(CNNModel, self).__init__()
        self.ft_out_size = 0

        if model_name == "resnet18":
            self.feature = models.resnet18(pretrained=True) 
            self.feature.fc = nn.Identity()
            self.ft_out_size = 512
        if model_name == "resnet50":
            self.feature = models.resnet50(pretrained=True) 
            self.feature.fc = nn.Identity()
            self.ft_out_size = 2048
        elif model_name == "vgg16":
            self.feature = models.vgg16_bn(pretrained=True) 
            self.feature.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1)) # original is (7,7)
            self.feature.classifier = nn.Identity()
            self.ft_out_size = 512
        else:
            # Need some default model?
            self.feature = nn.Sequential()
            self.feature.add_module('f_conv1', nn.Conv2d(3, 64, kernel_size=5))
            self.feature.add_module('f_bn1', nn.BatchNorm2d(64))
            self.feature.add_module('f_pool1', nn.MaxPool2d(2))
            self.feature.add_module('f_relu1', nn.ReLU(True))
            self.feature.add_module('f_conv2', nn.Conv2d(64, 128, kernel_size=3))
            self.feature.add_module('f_bn2', nn.BatchNorm2d(128))
            self.feature.add_module('f_drop1', nn.Dropout2d())
            self.feature.add_module('f_pool2', nn.MaxPool2d(2))
            self.feature.add_module('f_relu2', nn.ReLU(True))
            self.feature.add_module('f_conv3', nn.Conv2d(128, 256, kernel_size=3))
            self.feature.add_module('f_bn3', nn.BatchNorm2d(256))
            self.feature.add_module('f_drop3', nn.Dropout2d())
            self.feature.add_module('f_pool3', nn.MaxPool2d(2))
            self.feature.add_module('f_relu4', nn.ReLU(True))
            self.feature.add_module('f_conv4', nn.Conv2d(256, 256, kernel_size=3))
            self.feature.add_module('f_bn4', nn.BatchNorm2d(256))
            self.feature.add_module('f_drop4', nn.Dropout2d())
            self.feature.add_module('f_pool4', nn.MaxPool2d(2))
            self.feature.add_module('f_relu4', nn.ReLU(True))
            self.feature.add_module('f_conv5', nn.Conv2d(256, 512, kernel_size=3))
            self.feature.add_module('f_bn5', nn.BatchNorm2d(512))
            self.feature.add_module('f_drop5', nn.Dropout2d())
            self.feature.add_module('f_pool5', nn.MaxPool2d(2))
            self.feature.add_module('f_relu5', nn.ReLU(True))

        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(self.ft_out_size, 100))
        self.class_classifier.add_module('c_bn1', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_drop1', nn.Dropout2d())
        self.class_classifier.add_module('c_fc2', nn.Linear(100, 100))
        self.class_classifier.add_module('c_bn2', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(100, 7))
        self.class_classifier.add_module('c_softmax', nn.LogSoftmax(dim=1))

        self.domain_classifier = nn.Sequential()
        self.domain_classifier.add_module('d_fc1', nn.Linear(self.ft_out_size, 100))
        self.domain_classifier.add_module('d_bn1', nn.BatchNorm1d(100))
        self.domain_classifier.add_module('d_relu1', nn.ReLU(True))
        self.domain_classifier.add_module('d_fc2', nn.Linear(100, 4))
        self.domain_classifier.add_module('d_softmax', nn.LogSoftmax(dim=1))
        


    def forward(self, input_data, alpha):
        input_data = input_data.expand(input_data.data.shape[0], 3, IMAGE_SIZE, IMAGE_SIZE)
        feature = self.feature(input_data)
        feature = feature.view(-1, self.ft_out_size)
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)

        return class_output, domain_output

# %% [markdown]
# # Test pipeline

# %%
def test(net, epoch):

    # load data
    # img_transform_source = preprocess_multiple_fn(mus=[(0.5085, 0.4832, 0.4396),
    #                                                     (0.5550, 0.5085, 0.4579),
    #                                                    (0.8077, 0.7829, 0.7358)], 
    #                                               stds=[(0.1780, 0.1779, 0.1907),
    #                                                     (0.1880, 0.1917, 0.2060),
    #                                                     (0.2239, 0.2283, 0.2437)])
    
    # img_transform_target = preprocess_fn(mu=(0.9566, 0.9566, 0.9566), std=(0.1752, 0.1752, 0.1752))

    img_transform_source = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), aug=True)
    img_transform_target = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), aug=True)


    dataset_source, dataloader_source = prep_dataloader(
        image_root=os.path.join(source_image_root, 'train_set'),
        label_list=train_label_list,
        img_transform=img_transform_source,
        shuffle=False
    )

    dataset_target, dataloader_target = prep_dataloader(
        image_root=os.path.join(target_image_root, 'test_set'),
        img_transform=img_transform_target,
        shuffle=False
    )

    net.eval()

    if cuda:
        net = net.cuda()

    train_pths, train_preds = inference(net, dataloader_source, cuda=cuda, alpha=alpha)
    train_results = pd.DataFrame({'id': train_pths, 'label': train_preds})
    train_results_pth = os.path.join(output_root, '%s_train_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
    train_results.to_csv(train_results_pth, index=False)

    test_pths, test_preds = inference(net, dataloader_target, cuda=cuda, alpha=alpha)
    test_results = pd.DataFrame({'id': test_pths, 'label': test_preds})
    test_results_pth = os.path.join(output_root, '%s_test_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
    test_results.to_csv(test_results_pth, index=False)

    print('epoch: %d, accuracy of the train dataset: %f' % (epoch, compare(train_label_list, train_results_pth)))

    # Secret
    test_label_list = os.path.join(dataset_root, 'dummy_test_labels.csv')
    print('epoch: %d, accuracy of the test dataset: %f' % (epoch, compare(test_label_list, test_results_pth)))

def inference(net, dataloader, cuda=True, alpha=0.0):
    preds = []
    pths = []
    for input_img, _,_, img_paths in dataloader: 

        if cuda:
            input_img = input_img.cuda()

        class_output, _ = net(input_data=input_img, alpha=alpha)
        pred = class_output.data.max(1, keepdim=True)[1]
        pths = pths + list(img_paths)
        preds = preds + list(pred.squeeze(1).cpu().numpy())
    return pths, preds

def compare(true_labels, predicted_labels):
    combined_df = pd.read_csv(true_labels)
    predicted_df = pd.read_csv(predicted_labels)

    combined_df['label'] = combined_df['dir'].map(predicted_df.set_index('id')['label'])

    true_labels = np.array(combined_df['label2'].to_list())
    pred_labels = np.array(combined_df['label'].to_list())

    return np.sum(true_labels == pred_labels) / len(true_labels)

# %% [markdown]
# # Training pipeline

# %%
manual_seed = random.randint(1, 10000)
random.seed(manual_seed)
torch.manual_seed(manual_seed)

# load data
# img_transform_source = preprocess_multiple_fn(mus=[(0.5085, 0.4832, 0.4396),
#                                                     (0.5550, 0.5085, 0.4579),
#                                                     (0.8077, 0.7829, 0.7358)], 
#                                                 stds=[(0.1780, 0.1779, 0.1907),
#                                                     (0.1880, 0.1917, 0.2060),
#                                                     (0.2239, 0.2283, 0.2437)])
# img_transform_target = preprocess_fn(mu=(0.9566, 0.9566, 0.9566), std=(0.1752, 0.1752, 0.1752))

img_transform_source = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
img_transform_target = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))


dataset_source, dataloader_source = prep_dataloader(
    image_root=os.path.join(source_image_root, 'train_set'), # TODO should we unnest
    label_list=train_label_list,
    img_transform=img_transform_source
)

dataset_target, dataloader_target = prep_dataloader(
    image_root=os.path.join(target_image_root, 'test_set'),
    img_transform=img_transform_target
)

# load model
my_net = CNNModel(model_name=model_name)

# setup optimizer
optimizer = optim.Adam(my_net.parameters(), lr=LR)

loss_class = torch.nn.NLLLoss()
loss_domain = torch.nn.NLLLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()
    loss_domain = loss_domain.cuda()

set_parameter_requires_grad(my_net, True)

# training
for epoch in range(N_EPOCH):

    len_dataloader = max(len(dataloader_source), len(dataloader_target))
    data_source_iter = iter(dataloader_source)
    data_target_iter = iter(dataloader_target)

    i = 0
    while i < len_dataloader:

        p = float(i + epoch * len_dataloader) / N_EPOCH / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # training model using source data
        data_source = data_source_iter.next()
        s_img, s_label, s_domain_label, _ = data_source

        my_net.zero_grad()
        batch_size = len(s_label)

        input_img = torch.FloatTensor(batch_size, 3, IMAGE_SIZE, IMAGE_SIZE)
        class_label = torch.LongTensor(batch_size)
        domain_label = torch.LongTensor(batch_size)

        if cuda:
            s_img = s_img.cuda()
            s_label = s_label.cuda()
            s_domain_label = s_domain_label.cuda()
            input_img = input_img.cuda()
            class_label = class_label.cuda()
            domain_label = domain_label.cuda()

        input_img.resize_as_(s_img).copy_(s_img)
        class_label.resize_as_(s_label).copy_(s_label)
        domain_label.resize_as_(s_domain_label).copy_(s_domain_label)

        class_output, domain_output = my_net(input_data=input_img, alpha=alpha)
        err_s_label = loss_class(class_output, class_label)
        err_s_domain = loss_domain(domain_output, domain_label)

        # training model using target data
        if i == len(dataloader_target):
            data_target_iter = iter(dataloader_target)
        data_target = data_target_iter.next()
        t_img, _, _, _ = data_target

        batch_size = len(t_img) # TODO: why?

        input_img = torch.FloatTensor(batch_size, 3, IMAGE_SIZE, IMAGE_SIZE)
        domain_label = torch.ones(batch_size) * 3.0
        domain_label = domain_label.long()

        if cuda:
            t_img = t_img.cuda()
            input_img = input_img.cuda()
            domain_label = domain_label.cuda()

        input_img.resize_as_(t_img).copy_(t_img)

        _, domain_output = my_net(input_data=input_img, alpha=alpha)
        err_t_domain = loss_domain(domain_output, domain_label)
        err = err_t_domain + err_s_domain + err_s_label
        err.backward()
        optimizer.step()

        i += 1

        print('epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
            % (epoch, i, len_dataloader, err_s_label.cpu().data.numpy(),
                err_s_domain.cpu().data.numpy(), err_t_domain.cpu().data.numpy()))

    # torch.save(my_net, 'output/model_epoch_{}.pth'.format(epoch))
    test(my_net, epoch)
    my_net.train()

print('done')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# epoch: 5, [iter: 183 / all 190], err_s_label: 0.498631, err_s_domain: 1.744200, err_t_domain: 0.713488
# epoch: 5, [iter: 184 / all 190], err_s_label: 0.861019, err_s_domain: 1.689172, err_t_domain: 0.694397
# epoch: 5, [iter: 185 / all 190], err_s_label: 0.310723, err_s_domain: 1.745028, err_t_domain: 0.678659
# epoch: 5, [iter: 186 / all 190], err_s_label: 0.682389, err_s_domain: 1.733543, err_t_domain: 0.675418
# epoch: 5, [iter: 187 / all 190], err_s_label: 0.647688, err_s_domain: 1.818009, err_t_domain: 0.683722
# epoch: 5, [iter: 188 / all 190], err_s_label: 0.466108, err_s_domain: 1.663195, err_t_domain: 0.731872
# epoch: 5, [iter: 189 / all 190], err_s_label: 0.609090, err_s_domain: 1.717528, err_t_domain: 0.709068
# epoch: 5, [iter: 190 / all 190], err_s_label: 1.228064, err_s_domain: 1.727985, err_t_domain: 0.658334
# epoch: 5, accuracy of the train dataset: 0.487793
# epoch: 5, accuracy of the test dataset: 0.440061
# epoch: 6, [iter: 1 / all 190], err_s_label: 0.444356, err_s_domain: 1.760321, err_t_domain: 0.678191
# epoch: 6, [iter: 2 / all 190], err_s_label: 0.492179, err_s_domain: 1.709466, err_t_domain: 0.706357
# epoch: 6, [iter: 3 / all 190], err_s_label: 0.675756, err_s_domain: 1.715041, err_t_domain: 0.713421
# epoch: 6, [iter: 4 / all 190], err_s_label: 0.649207, err_s_domain: 1.714725, err_t_domain: 0.722147
# epoch: 6, [iter: 5 / all 190], err_s_label: 0.550424, err_s_domain: 1.731555, err_t_domain: 0.693494
# epoch: 6, [iter: 6 / all 190], err_s_label: 0.322819, err_s_domain: 1.713026, err_t_domain: 0.688494
# epoch: 6, [iter: 7 / all 190], err_s_label: 0.635450, err_s_domain: 1.795622, err_t_domain: 0.707967
# epoch: 6, [iter: 8 / all 190], err_s_label: 0.739744, err_s_domain: 1.771971, err_t_domain: 0.677284
# epoch: 6, [iter: 9 / all 190], err_s_label: 0.687719, err_s_domain: 1.806586, err_t_domain: 0.700280
# epoch: 6, [iter: 10 / all 190], err_s_label: 0.449728, err_s_domain: 1.742583, err_t_domain: 0.723836
# epoch: 6, [iter: 11 / all 190], err_s_label: 0.642358, err_s_domain: 1.720101, err_t_domain: 0.667272
# epoch: 6, [iter: 12 / all 190], err_s_label: 0.748549, err_s_domain: 1.812226, err_t_domain: 0.653895
# epoch: 6, [iter: 13 / all 190], err_s_label: 0.567819, err_s_domain: 1.793822, err_t_domain: 0.651881
# epoch: 6, [iter: 14 / all 190], err_s_label: 0.289599, err_s_domain: 1.715931, err_t_domain: 0.681986
# epoch: 6, [iter: 15 / all 190], err_s_label: 0.417645, err_s_domain: 1.734708, err_t_domain: 0.695830
# epoch: 6, [iter: 16 / all 190], err_s_label: 0.513534, err_s_domain: 1.726180, err_t_domain: 0.686270
# epoch: 6, [iter: 17 / all 190], err_s_label: 0.425510, err_s_domain: 1.712045, err_t_domain: 0.695151
# epoch: 6, [iter: 18 / all 190], err_s_label: 0.629058, err_s_domain: 1.690722, err_t_domain: 0.689668
# epoch: 6, [iter: 19 / all 190], err_s_label: 0.359722, err_s_domain: 1.629614, err_t_domain: 0.700948
# epoch: 6, [iter: 20 / all 190], err_s_label: 0.712569, err_s_domain: 1.739220, err_t_domain: 0.692138
# epoch: 6, [iter: 21 / all 190], err_s_label: 0.503661, err_s_domain: 1.739167, err_t_domain: 0.678321
# epoch: 6, [iter: 22 / all 190], err_s_label: 0.809157, err_s_domain: 1.737639, err_t_domain: 0.684711
# epoch: 6, [iter: 23 / all 190], err_s_label: 0.376417, err_s_domain: 1.713655, err_t_domain: 0.696180
# epoch: 6, [iter: 24 / all 190], err_s_label: 0.309825, err_s_domain: 1.756354, err_t_domain: 0.693515
# epoch: 6, [iter: 25 / all 190], err_s_label: 0.616583, err_s_domain: 1.802963, err_t_domain: 0.744432
# epoch: 6, [iter: 26 / all 190], err_s_label: 0.562968, err_s_domain: 1.776131, err_t_domain: 0.689259
# epoch: 6, [iter: 27 / all 190], err_s_label: 0.340136, err_s_domain: 1.760227, err_t_domain: 0.675402
# epoch: 6, [iter: 28 / all 190], err_s_label: 0.476612, err_s_domain: 1.773554, err_t_domain: 0.673480
# epoch: 6, [iter: 29 / all 190], err_s_label: 0.450759, err_s_domain: 1.697710, err_t_domain: 0.692705
# epoch: 6, [iter: 30 / all 190], err_s_label: 0.345278, err_s_domain: 1.682269, err_t_domain: 0.663242
# epoch: 6, [iter: 31 / all 190], err_s_label: 0.323612, err_s_domain: 1.735659, err_t_domain: 0.659907
# epoch: 6, [iter: 32 / all 190], err_s_label: 0.476446, err_s_domain: 1.714665, err_t_domain: 0.676399
# epoch: 6, [iter: 33 / all 190], err_s_label: 0.535852, err_s_domain: 1.720556, err_t_domain: 0.686538
# epoch: 6, [iter: 34 / all 190], err_s_label: 0.515926, err_s_domain: 1.771761, err_t_domain: 0.662087
# epoch: 6, [iter: 35 / all 190], err_s_label: 0.677354, err_s_domain: 1.662065, err_t_domain: 0.684256
# epoch: 6, [iter: 36 / all 190], err_s_label: 0.438883, err_s_domain: 1.757404, err_t_domain: 0.677533
# epoch: 6, [iter: 37 / all 190], err_s_label: 0.361620, err_s_domain: 1.774111, err_t_domain: 0.698713
# epoch: 6, [iter: 38 / all 190], err_s_label: 0.719621, err_s_domain: 1.671311, err_t_domain: 0.673424
# epoch: 6, [iter: 39 / all 190], err_s_label: 0.292721, err_s_domain: 1.704810, err_t_domain: 0.696854
# epoch: 6, [iter: 40 / all 190], err_s_label: 0.169866, err_s_domain: 1.758067, err_t_domain: 0.675235
# epoch: 6, [iter: 41 / all 190], err_s_label: 0.345527, err_s_domain: 1.718365, err_t_domain: 0.686037
# epoch: 6, [iter: 42 / all 190], err_s_label: 0.710546, err_s_domain: 1.712606, err_t_domain: 0.696141
# epoch: 6, [iter: 43 / all 190], err_s_label: 0.542036, err_s_domain: 1.774150, err_t_domain: 0.674373
# epoch: 6, [iter: 44 / all 190], err_s_label: 0.486470, err_s_domain: 1.813667, err_t_domain: 0.682363
# epoch: 6, [iter: 45 / all 190], err_s_label: 0.451211, err_s_domain: 1.833493, err_t_domain: 0.705419
# epoch: 6, [iter: 46 / all 190], err_s_label: 0.343662, err_s_domain: 1.768855, err_t_domain: 0.671610
# epoch: 6, [iter: 47 / all 190], err_s_label: 0.494643, err_s_domain: 1.781410, err_t_domain: 0.656731
# epoch: 6, [iter: 48 / all 190], err_s_label: 0.620939, err_s_domain: 1.861281, err_t_domain: 0.670081
# epoch: 6, [iter: 49 / all 190], err_s_label: 0.798695, err_s_domain: 1.778104, err_t_domain: 0.684423
# epoch: 6, [iter: 50 / all 190], err_s_label: 0.243636, err_s_domain: 1.728656, err_t_domain: 0.651315
# epoch: 6, [iter: 51 / all 190], err_s_label: 0.456186, err_s_domain: 1.754575, err_t_domain: 0.686842
# epoch: 6, [iter: 52 / all 190], err_s_label: 0.252473, err_s_domain: 1.713953, err_t_domain: 0.656762
# epoch: 6, [iter: 53 / all 190], err_s_label: 0.443982, err_s_domain: 1.748754, err_t_domain: 0.683695
# epoch: 6, [iter: 54 / all 190], err_s_label: 0.767371, err_s_domain: 1.727347, err_t_domain: 0.685621
# epoch: 6, [iter: 55 / all 190], err_s_label: 0.284843, err_s_domain: 1.681366, err_t_domain: 0.698895
# epoch: 6, [iter: 56 / all 190], err_s_label: 0.779875, err_s_domain: 1.740588, err_t_domain: 0.714563
# epoch: 6, [iter: 57 / all 190], err_s_label: 0.558637, err_s_domain: 1.688500, err_t_domain: 0.723071
# epoch: 6, [iter: 58 / all 190], err_s_label: 0.454652, err_s_domain: 1.844440, err_t_domain: 0.666818
# epoch: 6, [iter: 59 / all 190], err_s_label: 0.554502, err_s_domain: 1.735081, err_t_domain: 0.722448
# epoch: 6, [iter: 60 / all 190], err_s_label: 0.523549, err_s_domain: 1.713333, err_t_domain: 0.700416
# epoch: 6, [iter: 61 / all 190], err_s_label: 0.341583, err_s_domain: 1.768598, err_t_domain: 0.696609
# epoch: 6, [iter: 62 / all 190], err_s_label: 0.129800, err_s_domain: 1.626001, err_t_domain: 0.736389
# epoch: 6, [iter: 63 / all 190], err_s_label: 0.492738, err_s_domain: 1.707488, err_t_domain: 0.693370
# epoch: 6, [iter: 64 / all 190], err_s_label: 0.324527, err_s_domain: 1.696406, err_t_domain: 0.656396
# epoch: 6, [iter: 65 / all 190], err_s_label: 0.203777, err_s_domain: 1.627703, err_t_domain: 0.695910
# epoch: 6, [iter: 66 / all 190], err_s_label: 0.580966, err_s_domain: 1.742307, err_t_domain: 0.669887
# epoch: 6, [iter: 67 / all 190], err_s_label: 0.760708, err_s_domain: 1.934350, err_t_domain: 0.638013
# epoch: 6, [iter: 68 / all 190], err_s_label: 0.620687, err_s_domain: 1.840183, err_t_domain: 0.663896
# epoch: 6, [iter: 69 / all 190], err_s_label: 0.571898, err_s_domain: 1.712937, err_t_domain: 0.708525
# epoch: 6, [iter: 70 / all 190], err_s_label: 0.563075, err_s_domain: 1.793828, err_t_domain: 0.659879
# epoch: 6, [iter: 71 / all 190], err_s_label: 0.584609, err_s_domain: 1.757425, err_t_domain: 0.661681
# epoch: 6, [iter: 72 / all 190], err_s_label: 0.557591, err_s_domain: 1.806249, err_t_domain: 0.665488
# epoch: 6, [iter: 73 / all 190], err_s_label: 0.277877, err_s_domain: 1.771490, err_t_domain: 0.662434
# epoch: 6, [iter: 74 / all 190], err_s_label: 0.668619, err_s_domain: 1.869991, err_t_domain: 0.672965
# epoch: 6, [iter: 75 / all 190], err_s_label: 0.681194, err_s_domain: 1.794762, err_t_domain: 0.657911
# epoch: 6, [iter: 76 / all 190], err_s_label: 0.604425, err_s_domain: 1.791468, err_t_domain: 0.698096
# epoch: 6, [iter: 77 / all 190], err_s_label: 0.583538, err_s_domain: 1.704010, err_t_domain: 0.704802
# epoch: 6, [iter: 78 / all 190], err_s_label: 0.671720, err_s_domain: 1.750707, err_t_domain: 0.677963
# epoch: 6, [iter: 79 / all 190], err_s_label: 0.656995, err_s_domain: 1.730294, err_t_domain: 0.670145
# epoch: 6, [iter: 80 / all 190], err_s_label: 0.192323, err_s_domain: 1.744863, err_t_domain: 0.680649
# epoch: 6, [iter: 81 / all 190], err_s_label: 0.798705, err_s_domain: 1.734568, err_t_domain: 0.687499
# epoch: 6, [iter: 82 / all 190], err_s_label: 0.480165, err_s_domain: 1.639202, err_t_domain: 0.705807
# epoch: 6, [iter: 83 / all 190], err_s_label: 0.538566, err_s_domain: 1.862772, err_t_domain: 0.712466
# epoch: 6, [iter: 84 / all 190], err_s_label: 0.830766, err_s_domain: 1.796530, err_t_domain: 0.724742
# epoch: 6, [iter: 85 / all 190], err_s_label: 0.406898, err_s_domain: 1.731485, err_t_domain: 0.676988
# epoch: 6, [iter: 86 / all 190], err_s_label: 0.883707, err_s_domain: 1.757123, err_t_domain: 0.684668
# epoch: 6, [iter: 87 / all 190], err_s_label: 0.633077, err_s_domain: 1.715311, err_t_domain: 0.678207
# epoch: 6, [iter: 88 / all 190], err_s_label: 0.538206, err_s_domain: 1.805617, err_t_domain: 0.693319
# epoch: 6, [iter: 89 / all 190], err_s_label: 0.525547, err_s_domain: 1.773812, err_t_domain: 0.663916
# epoch: 6, [iter: 90 / all 190], err_s_label: 0.310927, err_s_domain: 1.748553, err_t_domain: 0.687104
# epoch: 6, [iter: 91 / all 190], err_s_label: 0.393666, err_s_domain: 1.696790, err_t_domain: 0.643581
# epoch: 6, [iter: 92 / all 190], err_s_label: 0.714960, err_s_domain: 1.681426, err_t_domain: 0.705868
# epoch: 6, [iter: 93 / all 190], err_s_label: 0.575415, err_s_domain: 1.748301, err_t_domain: 0.665400
# epoch: 6, [iter: 94 / all 190], err_s_label: 0.758006, err_s_domain: 1.705998, err_t_domain: 0.691234
# epoch: 6, [iter: 95 / all 190], err_s_label: 0.412622, err_s_domain: 1.694518, err_t_domain: 0.659465
# epoch: 6, [iter: 96 / all 190], err_s_label: 0.429317, err_s_domain: 1.895105, err_t_domain: 0.644521
# epoch: 6, [iter: 97 / all 190], err_s_label: 0.509318, err_s_domain: 1.723377, err_t_domain: 0.687901
# epoch: 6, [iter: 98 / all 190], err_s_label: 0.544058, err_s_domain: 1.700588, err_t_domain: 0.654846
# epoch: 6, [iter: 99 / all 190], err_s_label: 0.353627, err_s_domain: 1.774953, err_t_domain: 0.691384
# epoch: 6, [iter: 100 / all 190], err_s_label: 0.530397, err_s_domain: 1.773576, err_t_domain: 0.665193
# epoch: 6, [iter: 101 / all 190], err_s_label: 0.532562, err_s_domain: 1.719025, err_t_domain: 0.723757
# epoch: 6, [iter: 102 / all 190], err_s_label: 0.266763, err_s_domain: 1.834042, err_t_domain: 0.704438
# epoch: 6, [iter: 103 / all 190], err_s_label: 0.637073, err_s_domain: 1.742281, err_t_domain: 0.704934
# epoch: 6, [iter: 104 / all 190], err_s_label: 1.046662, err_s_domain: 1.792708, err_t_domain: 0.665267
# epoch: 6, [iter: 105 / all 190], err_s_label: 0.514794, err_s_domain: 1.814352, err_t_domain: 0.672921
# epoch: 6, [iter: 106 / all 190], err_s_label: 0.543944, err_s_domain: 1.791986, err_t_domain: 0.714803
# epoch: 6, [iter: 107 / all 190], err_s_label: 1.060649, err_s_domain: 1.751010, err_t_domain: 0.671734
# epoch: 6, [iter: 108 / all 190], err_s_label: 1.011285, err_s_domain: 1.775167, err_t_domain: 0.647417
# epoch: 6, [iter: 109 / all 190], err_s_label: 0.788803, err_s_domain: 1.728577, err_t_domain: 0.676434
# epoch: 6, [iter: 110 / all 190], err_s_label: 0.639912, err_s_domain: 1.753625, err_t_domain: 0.663824
# epoch: 6, [iter: 111 / all 190], err_s_label: 0.627551, err_s_domain: 1.817417, err_t_domain: 0.663346
# epoch: 6, [iter: 112 / all 190], err_s_label: 0.561413, err_s_domain: 1.773781, err_t_domain: 0.665955
# epoch: 6, [iter: 113 / all 190], err_s_label: 0.569157, err_s_domain: 1.726158, err_t_domain: 0.645815
# epoch: 6, [iter: 114 / all 190], err_s_label: 0.688749, err_s_domain: 1.715156, err_t_domain: 0.709656
# epoch: 6, [iter: 115 / all 190], err_s_label: 0.662995, err_s_domain: 1.854434, err_t_domain: 0.662433
# epoch: 6, [iter: 116 / all 190], err_s_label: 0.872782, err_s_domain: 1.698570, err_t_domain: 0.691687
# epoch: 6, [iter: 117 / all 190], err_s_label: 0.825288, err_s_domain: 1.768648, err_t_domain: 0.724144
# epoch: 6, [iter: 118 / all 190], err_s_label: 0.590594, err_s_domain: 1.663701, err_t_domain: 0.701068
# epoch: 6, [iter: 119 / all 190], err_s_label: 0.675499, err_s_domain: 1.796155, err_t_domain: 0.682932
# epoch: 6, [iter: 120 / all 190], err_s_label: 0.338756, err_s_domain: 1.703426, err_t_domain: 0.705018
# epoch: 6, [iter: 121 / all 190], err_s_label: 0.566484, err_s_domain: 1.741315, err_t_domain: 0.689642
# epoch: 6, [iter: 122 / all 190], err_s_label: 0.755311, err_s_domain: 1.711222, err_t_domain: 0.675355
# epoch: 6, [iter: 123 / all 190], err_s_label: 0.471226, err_s_domain: 1.704851, err_t_domain: 0.677937
# epoch: 6, [iter: 124 / all 190], err_s_label: 0.812273, err_s_domain: 1.792201, err_t_domain: 0.683076
# epoch: 6, [iter: 125 / all 190], err_s_label: 0.803427, err_s_domain: 1.851828, err_t_domain: 0.667942
# epoch: 6, [iter: 126 / all 190], err_s_label: 0.769148, err_s_domain: 1.720937, err_t_domain: 0.713145
# epoch: 6, [iter: 127 / all 190], err_s_label: 0.515533, err_s_domain: 1.840712, err_t_domain: 0.702936
# epoch: 6, [iter: 128 / all 190], err_s_label: 0.495685, err_s_domain: 1.841533, err_t_domain: 0.701927
# epoch: 6, [iter: 129 / all 190], err_s_label: 0.746435, err_s_domain: 1.812850, err_t_domain: 0.666207
# epoch: 6, [iter: 130 / all 190], err_s_label: 0.622485, err_s_domain: 1.787448, err_t_domain: 0.665375
# epoch: 6, [iter: 131 / all 190], err_s_label: 0.444405, err_s_domain: 1.781146, err_t_domain: 0.647986
# epoch: 6, [iter: 132 / all 190], err_s_label: 0.420180, err_s_domain: 1.688347, err_t_domain: 0.676863
# epoch: 6, [iter: 133 / all 190], err_s_label: 0.624875, err_s_domain: 1.859875, err_t_domain: 0.660797
# epoch: 6, [iter: 134 / all 190], err_s_label: 0.400067, err_s_domain: 1.721772, err_t_domain: 0.686188
# epoch: 6, [iter: 135 / all 190], err_s_label: 0.496679, err_s_domain: 1.822243, err_t_domain: 0.692496
# epoch: 6, [iter: 136 / all 190], err_s_label: 0.645660, err_s_domain: 1.704001, err_t_domain: 0.682682
# epoch: 6, [iter: 137 / all 190], err_s_label: 0.337139, err_s_domain: 1.866592, err_t_domain: 0.684887
# epoch: 6, [iter: 138 / all 190], err_s_label: 0.763193, err_s_domain: 1.755840, err_t_domain: 0.713471
# epoch: 6, [iter: 139 / all 190], err_s_label: 0.311037, err_s_domain: 1.749888, err_t_domain: 0.689906
# epoch: 6, [iter: 140 / all 190], err_s_label: 0.481029, err_s_domain: 1.785792, err_t_domain: 0.688837
# epoch: 6, [iter: 141 / all 190], err_s_label: 0.622653, err_s_domain: 1.796495, err_t_domain: 0.709542
# epoch: 6, [iter: 142 / all 190], err_s_label: 0.741924, err_s_domain: 1.720512, err_t_domain: 0.684170
# epoch: 6, [iter: 143 / all 190], err_s_label: 0.813861, err_s_domain: 1.851873, err_t_domain: 0.715853
# epoch: 6, [iter: 144 / all 190], err_s_label: 0.427839, err_s_domain: 1.797499, err_t_domain: 0.682424
# epoch: 6, [iter: 145 / all 190], err_s_label: 0.396279, err_s_domain: 1.761655, err_t_domain: 0.697230
# epoch: 6, [iter: 146 / all 190], err_s_label: 0.748278, err_s_domain: 1.733454, err_t_domain: 0.672004
# epoch: 6, [iter: 147 / all 190], err_s_label: 0.518930, err_s_domain: 1.752831, err_t_domain: 0.686471
# epoch: 6, [iter: 148 / all 190], err_s_label: 0.767647, err_s_domain: 1.814039, err_t_domain: 0.695357
# epoch: 6, [iter: 149 / all 190], err_s_label: 0.396441, err_s_domain: 1.721896, err_t_domain: 0.707633
# epoch: 6, [iter: 150 / all 190], err_s_label: 0.629672, err_s_domain: 1.775199, err_t_domain: 0.741687
# epoch: 6, [iter: 151 / all 190], err_s_label: 0.556112, err_s_domain: 1.736075, err_t_domain: 0.692014
# epoch: 6, [iter: 152 / all 190], err_s_label: 0.593600, err_s_domain: 1.688703, err_t_domain: 0.708635
# epoch: 6, [iter: 153 / all 190], err_s_label: 0.398786, err_s_domain: 1.760369, err_t_domain: 0.712892
# epoch: 6, [iter: 154 / all 190], err_s_label: 0.494693, err_s_domain: 1.738692, err_t_domain: 0.721557
# epoch: 6, [iter: 155 / all 190], err_s_label: 0.783228, err_s_domain: 1.808444, err_t_domain: 0.711603
# epoch: 6, [iter: 156 / all 190], err_s_label: 0.302203, err_s_domain: 1.773235, err_t_domain: 0.659971
# epoch: 6, [iter: 157 / all 190], err_s_label: 0.484949, err_s_domain: 1.816736, err_t_domain: 0.663623
# epoch: 6, [iter: 158 / all 190], err_s_label: 0.555412, err_s_domain: 1.758099, err_t_domain: 0.645704
# epoch: 6, [iter: 159 / all 190], err_s_label: 0.562467, err_s_domain: 1.655809, err_t_domain: 0.707192
# epoch: 6, [iter: 160 / all 190], err_s_label: 0.739249, err_s_domain: 1.753423, err_t_domain: 0.703392
# epoch: 6, [iter: 161 / all 190], err_s_label: 0.470707, err_s_domain: 1.749678, err_t_domain: 0.644846
# epoch: 6, [iter: 162 / all 190], err_s_label: 0.719392, err_s_domain: 1.773504, err_t_domain: 0.690634
# epoch: 6, [iter: 163 / all 190], err_s_label: 0.440740, err_s_domain: 1.722205, err_t_domain: 0.680311
# epoch: 6, [iter: 164 / all 190], err_s_label: 0.246948, err_s_domain: 1.788913, err_t_domain: 0.653241
# epoch: 6, [iter: 165 / all 190], err_s_label: 0.663091, err_s_domain: 1.780663, err_t_domain: 0.651039
# epoch: 6, [iter: 166 / all 190], err_s_label: 0.398578, err_s_domain: 1.786396, err_t_domain: 0.661054
# epoch: 6, [iter: 167 / all 190], err_s_label: 0.453752, err_s_domain: 1.773557, err_t_domain: 0.669762
# epoch: 6, [iter: 168 / all 190], err_s_label: 0.590406, err_s_domain: 1.818177, err_t_domain: 0.698470
# epoch: 6, [iter: 169 / all 190], err_s_label: 0.746043, err_s_domain: 1.712369, err_t_domain: 0.663248
# epoch: 6, [iter: 170 / all 190], err_s_label: 0.570501, err_s_domain: 1.768368, err_t_domain: 0.691754
# epoch: 6, [iter: 171 / all 190], err_s_label: 0.527883, err_s_domain: 1.838237, err_t_domain: 0.689907
# epoch: 6, [iter: 172 / all 190], err_s_label: 0.480114, err_s_domain: 1.827177, err_t_domain: 0.662462
# epoch: 6, [iter: 173 / all 190], err_s_label: 0.603927, err_s_domain: 1.708729, err_t_domain: 0.672903
# epoch: 6, [iter: 174 / all 190], err_s_label: 0.745345, err_s_domain: 1.760446, err_t_domain: 0.662417
# epoch: 6, [iter: 175 / all 190], err_s_label: 0.536425, err_s_domain: 1.752204, err_t_domain: 0.699216
# epoch: 6, [iter: 176 / all 190], err_s_label: 0.748830, err_s_domain: 1.770577, err_t_domain: 0.674108
# epoch: 6, [iter: 177 / all 190], err_s_label: 1.078084, err_s_domain: 1.774479, err_t_domain: 0.720476
# epoch: 6, [iter: 178 / all 190], err_s_label: 0.602870, err_s_domain: 1.796506, err_t_domain: 0.696478
# epoch: 6, [iter: 179 / all 190], err_s_label: 0.408664, err_s_domain: 1.821419, err_t_domain: 0.690809
# epoch: 6, [iter: 180 / all 190], err_s_label: 0.419103, err_s_domain: 1.768202, err_t_domain: 0.670109
# epoch: 6, [iter: 181 / all 190], err_s_label: 0.245491, err_s_domain: 1.709120, err_t_domain: 0.679033
# epoch: 6, [iter: 182 / all 190], err_s_label: 1.077870, err_s_domain: 1.805490, err_t_domain: 0.688045
# epoch: 6, [iter: 183 / all 190], err_s_label: 0.476303, err_s_domain: 1.759676, err_t_domain: 0.672700
# epoch: 6, [iter: 184 / all 190], err_s_label: 0.681925, err_s_domain: 1.761151, err_t_domain: 0.696180
# epoch: 6, [iter: 185 / all 190], err_s_label: 0.582054, err_s_domain: 1.786665, err_t_domain: 0.671817
# epoch: 6, [iter: 186 / all 190], err_s_label: 0.625086, err_s_domain: 1.741597, err_t_domain: 0.706747
# epoch: 6, [iter: 187 / all 190], err_s_label: 0.509323, err_s_domain: 1.704045, err_t_domain: 0.702015
# epoch: 6, [iter: 188 / all 190], err_s_label: 0.544456, err_s_domain: 1.685268, err_t_domain: 0.695025
# epoch: 6, [iter: 189 / all 190], err_s_label: 0.640090, err_s_domain: 1.721146, err_t_domain: 0.686353
# epoch: 6, [iter: 190 / all 190], err_s_label: 0.416945, err_s_domain: 1.694876, err_t_domain: 0.699376
# epoch: 6, accuracy of the train dataset: 0.552128
# epoch: 6, accuracy of the test dataset: 0.335709
# epoch: 7, [iter: 1 / all 190], err_s_label: 0.566943, err_s_domain: 1.914858, err_t_domain: 0.680265
# epoch: 7, [iter: 2 / all 190], err_s_label: 0.471938, err_s_domain: 1.775402, err_t_domain: 0.685557
# epoch: 7, [iter: 3 / all 190], err_s_label: 0.506232, err_s_domain: 1.686358, err_t_domain: 0.691158
# epoch: 7, [iter: 4 / all 190], err_s_label: 0.399654, err_s_domain: 1.748651, err_t_domain: 0.704077
# epoch: 7, [iter: 5 / all 190], err_s_label: 0.538993, err_s_domain: 1.753055, err_t_domain: 0.693464
# epoch: 7, [iter: 6 / all 190], err_s_label: 0.519907, err_s_domain: 1.773534, err_t_domain: 0.674370
# epoch: 7, [iter: 7 / all 190], err_s_label: 0.458463, err_s_domain: 1.784084, err_t_domain: 0.685736
# epoch: 7, [iter: 8 / all 190], err_s_label: 0.549633, err_s_domain: 1.830979, err_t_domain: 0.688432
# epoch: 7, [iter: 9 / all 190], err_s_label: 0.632866, err_s_domain: 1.811211, err_t_domain: 0.674049
# epoch: 7, [iter: 10 / all 190], err_s_label: 0.798379, err_s_domain: 1.907217, err_t_domain: 0.685218
# epoch: 7, [iter: 11 / all 190], err_s_label: 0.412328, err_s_domain: 1.770009, err_t_domain: 0.686095
# epoch: 7, [iter: 12 / all 190], err_s_label: 0.495344, err_s_domain: 1.788785, err_t_domain: 0.670928
# epoch: 7, [iter: 13 / all 190], err_s_label: 0.543012, err_s_domain: 1.739227, err_t_domain: 0.705688
# epoch: 7, [iter: 14 / all 190], err_s_label: 0.375339, err_s_domain: 1.699801, err_t_domain: 0.711567
# epoch: 7, [iter: 15 / all 190], err_s_label: 0.431012, err_s_domain: 1.756730, err_t_domain: 0.668100
# epoch: 7, [iter: 16 / all 190], err_s_label: 0.533867, err_s_domain: 1.862669, err_t_domain: 0.665554
# epoch: 7, [iter: 17 / all 190], err_s_label: 0.700356, err_s_domain: 1.833071, err_t_domain: 0.693209
# epoch: 7, [iter: 18 / all 190], err_s_label: 0.454029, err_s_domain: 1.826617, err_t_domain: 0.702344
# epoch: 7, [iter: 19 / all 190], err_s_label: 0.655517, err_s_domain: 1.749386, err_t_domain: 0.676984
# epoch: 7, [iter: 20 / all 190], err_s_label: 0.782110, err_s_domain: 1.745583, err_t_domain: 0.657951
# epoch: 7, [iter: 21 / all 190], err_s_label: 0.615602, err_s_domain: 1.776527, err_t_domain: 0.659979
# epoch: 7, [iter: 22 / all 190], err_s_label: 0.260013, err_s_domain: 1.785908, err_t_domain: 0.654566
# epoch: 7, [iter: 23 / all 190], err_s_label: 0.763483, err_s_domain: 1.636170, err_t_domain: 0.708167
# epoch: 7, [iter: 24 / all 190], err_s_label: 0.445904, err_s_domain: 1.723689, err_t_domain: 0.711211
# epoch: 7, [iter: 25 / all 190], err_s_label: 0.802959, err_s_domain: 1.777202, err_t_domain: 0.719969
# epoch: 7, [iter: 26 / all 190], err_s_label: 0.583325, err_s_domain: 1.706049, err_t_domain: 0.675346
# epoch: 7, [iter: 27 / all 190], err_s_label: 0.298552, err_s_domain: 1.726424, err_t_domain: 0.658649
# epoch: 7, [iter: 28 / all 190], err_s_label: 0.755043, err_s_domain: 1.678403, err_t_domain: 0.691035
# epoch: 7, [iter: 29 / all 190], err_s_label: 0.470239, err_s_domain: 1.774556, err_t_domain: 0.691244
# epoch: 7, [iter: 30 / all 190], err_s_label: 0.455658, err_s_domain: 1.702068, err_t_domain: 0.679136
# epoch: 7, [iter: 31 / all 190], err_s_label: 0.302639, err_s_domain: 1.677650, err_t_domain: 0.686127
# epoch: 7, [iter: 32 / all 190], err_s_label: 0.449590, err_s_domain: 1.719362, err_t_domain: 0.672211
# epoch: 7, [iter: 33 / all 190], err_s_label: 0.674896, err_s_domain: 1.691868, err_t_domain: 0.692480
# epoch: 7, [iter: 34 / all 190], err_s_label: 0.373869, err_s_domain: 1.692884, err_t_domain: 0.651050
# epoch: 7, [iter: 35 / all 190], err_s_label: 0.529150, err_s_domain: 1.704061, err_t_domain: 0.692734
# epoch: 7, [iter: 36 / all 190], err_s_label: 0.648470, err_s_domain: 1.813476, err_t_domain: 0.691874
# epoch: 7, [iter: 37 / all 190], err_s_label: 0.522178, err_s_domain: 1.638139, err_t_domain: 0.665185
# epoch: 7, [iter: 38 / all 190], err_s_label: 0.491920, err_s_domain: 1.784098, err_t_domain: 0.683289
# epoch: 7, [iter: 39 / all 190], err_s_label: 0.360097, err_s_domain: 1.818866, err_t_domain: 0.681332
# epoch: 7, [iter: 40 / all 190], err_s_label: 0.635527, err_s_domain: 1.777246, err_t_domain: 0.699738
# epoch: 7, [iter: 41 / all 190], err_s_label: 0.396065, err_s_domain: 1.687689, err_t_domain: 0.727972
# epoch: 7, [iter: 42 / all 190], err_s_label: 0.381933, err_s_domain: 1.747580, err_t_domain: 0.717372
# epoch: 7, [iter: 43 / all 190], err_s_label: 0.399056, err_s_domain: 1.815553, err_t_domain: 0.714581
# epoch: 7, [iter: 44 / all 190], err_s_label: 0.450089, err_s_domain: 1.835161, err_t_domain: 0.717579
# epoch: 7, [iter: 45 / all 190], err_s_label: 0.517043, err_s_domain: 1.740524, err_t_domain: 0.699180
# epoch: 7, [iter: 46 / all 190], err_s_label: 0.456007, err_s_domain: 1.664559, err_t_domain: 0.712378
# epoch: 7, [iter: 47 / all 190], err_s_label: 0.410805, err_s_domain: 1.810733, err_t_domain: 0.691155
# epoch: 7, [iter: 48 / all 190], err_s_label: 0.401206, err_s_domain: 1.856028, err_t_domain: 0.698903
# epoch: 7, [iter: 49 / all 190], err_s_label: 0.635400, err_s_domain: 1.815348, err_t_domain: 0.657334
# epoch: 7, [iter: 50 / all 190], err_s_label: 0.631019, err_s_domain: 1.763091, err_t_domain: 0.665703
# epoch: 7, [iter: 51 / all 190], err_s_label: 0.652169, err_s_domain: 1.893760, err_t_domain: 0.655866
# epoch: 7, [iter: 52 / all 190], err_s_label: 0.311780, err_s_domain: 1.879392, err_t_domain: 0.696240
# epoch: 7, [iter: 53 / all 190], err_s_label: 0.616795, err_s_domain: 1.677839, err_t_domain: 0.688377
# epoch: 7, [iter: 54 / all 190], err_s_label: 0.628147, err_s_domain: 1.818918, err_t_domain: 0.680927
# epoch: 7, [iter: 55 / all 190], err_s_label: 0.250232, err_s_domain: 1.768646, err_t_domain: 0.689343
# epoch: 7, [iter: 56 / all 190], err_s_label: 0.466773, err_s_domain: 1.782620, err_t_domain: 0.653645
# epoch: 7, [iter: 57 / all 190], err_s_label: 0.758691, err_s_domain: 1.791372, err_t_domain: 0.692832
# epoch: 7, [iter: 58 / all 190], err_s_label: 0.404602, err_s_domain: 1.792662, err_t_domain: 0.669506
# epoch: 7, [iter: 59 / all 190], err_s_label: 0.329873, err_s_domain: 1.774421, err_t_domain: 0.667346
# epoch: 7, [iter: 60 / all 190], err_s_label: 0.390796, err_s_domain: 1.800761, err_t_domain: 0.689410
# epoch: 7, [iter: 61 / all 190], err_s_label: 0.394637, err_s_domain: 1.862616, err_t_domain: 0.685340
# epoch: 7, [iter: 62 / all 190], err_s_label: 0.336731, err_s_domain: 1.778598, err_t_domain: 0.698938
# epoch: 7, [iter: 63 / all 190], err_s_label: 0.684948, err_s_domain: 1.813753, err_t_domain: 0.704150
# epoch: 7, [iter: 64 / all 190], err_s_label: 0.257996, err_s_domain: 1.789989, err_t_domain: 0.736040
# epoch: 7, [iter: 65 / all 190], err_s_label: 0.864384, err_s_domain: 1.757905, err_t_domain: 0.666977
# epoch: 7, [iter: 66 / all 190], err_s_label: 0.580166, err_s_domain: 1.784593, err_t_domain: 0.712478
# epoch: 7, [iter: 67 / all 190], err_s_label: 0.277148, err_s_domain: 1.796004, err_t_domain: 0.691747
# epoch: 7, [iter: 68 / all 190], err_s_label: 0.323941, err_s_domain: 1.730480, err_t_domain: 0.706905
# epoch: 7, [iter: 69 / all 190], err_s_label: 0.294636, err_s_domain: 1.779637, err_t_domain: 0.727969
# epoch: 7, [iter: 70 / all 190], err_s_label: 0.278818, err_s_domain: 1.753957, err_t_domain: 0.731467
# epoch: 7, [iter: 71 / all 190], err_s_label: 0.407711, err_s_domain: 1.783981, err_t_domain: 0.728443
# epoch: 7, [iter: 72 / all 190], err_s_label: 0.542161, err_s_domain: 1.724723, err_t_domain: 0.714371
# epoch: 7, [iter: 73 / all 190], err_s_label: 0.908231, err_s_domain: 1.818029, err_t_domain: 0.715006
# epoch: 7, [iter: 74 / all 190], err_s_label: 0.553270, err_s_domain: 1.763541, err_t_domain: 0.694347
# epoch: 7, [iter: 75 / all 190], err_s_label: 0.305887, err_s_domain: 1.771225, err_t_domain: 0.693227
# epoch: 7, [iter: 76 / all 190], err_s_label: 0.326827, err_s_domain: 1.765256, err_t_domain: 0.699836
# epoch: 7, [iter: 77 / all 190], err_s_label: 0.746418, err_s_domain: 1.774938, err_t_domain: 0.691209
# epoch: 7, [iter: 78 / all 190], err_s_label: 0.549010, err_s_domain: 1.791616, err_t_domain: 0.700483
# epoch: 7, [iter: 79 / all 190], err_s_label: 0.316059, err_s_domain: 1.829911, err_t_domain: 0.700757
# epoch: 7, [iter: 80 / all 190], err_s_label: 0.382863, err_s_domain: 1.826632, err_t_domain: 0.678978
# epoch: 7, [iter: 81 / all 190], err_s_label: 0.701427, err_s_domain: 1.789237, err_t_domain: 0.679908
# epoch: 7, [iter: 82 / all 190], err_s_label: 0.568040, err_s_domain: 1.755309, err_t_domain: 0.654538
# epoch: 7, [iter: 83 / all 190], err_s_label: 0.455459, err_s_domain: 1.849376, err_t_domain: 0.703376
# epoch: 7, [iter: 84 / all 190], err_s_label: 0.310422, err_s_domain: 1.815855, err_t_domain: 0.687374
# epoch: 7, [iter: 85 / all 190], err_s_label: 0.492858, err_s_domain: 1.740525, err_t_domain: 0.653425
# epoch: 7, [iter: 86 / all 190], err_s_label: 0.469714, err_s_domain: 1.748401, err_t_domain: 0.684782
# epoch: 7, [iter: 87 / all 190], err_s_label: 0.519475, err_s_domain: 1.814772, err_t_domain: 0.674087
# epoch: 7, [iter: 88 / all 190], err_s_label: 0.316659, err_s_domain: 1.749489, err_t_domain: 0.704176
# epoch: 7, [iter: 89 / all 190], err_s_label: 0.608662, err_s_domain: 1.800571, err_t_domain: 0.668637
# epoch: 7, [iter: 90 / all 190], err_s_label: 0.532063, err_s_domain: 1.694794, err_t_domain: 0.667479
# epoch: 7, [iter: 91 / all 190], err_s_label: 0.546112, err_s_domain: 1.807100, err_t_domain: 0.705960
# epoch: 7, [iter: 92 / all 190], err_s_label: 0.631196, err_s_domain: 1.755539, err_t_domain: 0.690820
# epoch: 7, [iter: 93 / all 190], err_s_label: 0.517510, err_s_domain: 1.666008, err_t_domain: 0.659604
# epoch: 7, [iter: 94 / all 190], err_s_label: 0.797695, err_s_domain: 1.767832, err_t_domain: 0.692908
# epoch: 7, [iter: 95 / all 190], err_s_label: 0.456465, err_s_domain: 1.764694, err_t_domain: 0.679405
# epoch: 7, [iter: 96 / all 190], err_s_label: 0.337296, err_s_domain: 1.682221, err_t_domain: 0.670318
# epoch: 7, [iter: 97 / all 190], err_s_label: 0.392157, err_s_domain: 1.766625, err_t_domain: 0.712352
# epoch: 7, [iter: 98 / all 190], err_s_label: 0.439821, err_s_domain: 1.749142, err_t_domain: 0.673029
# epoch: 7, [iter: 99 / all 190], err_s_label: 0.370689, err_s_domain: 1.809906, err_t_domain: 0.686892
# epoch: 7, [iter: 100 / all 190], err_s_label: 0.360736, err_s_domain: 1.638339, err_t_domain: 0.689719
# epoch: 7, [iter: 101 / all 190], err_s_label: 1.146884, err_s_domain: 1.684739, err_t_domain: 0.670733
# epoch: 7, [iter: 102 / all 190], err_s_label: 0.445616, err_s_domain: 1.757650, err_t_domain: 0.685848
# epoch: 7, [iter: 103 / all 190], err_s_label: 0.479847, err_s_domain: 1.855935, err_t_domain: 0.654947
# epoch: 7, [iter: 104 / all 190], err_s_label: 0.802871, err_s_domain: 1.795892, err_t_domain: 0.667804
# epoch: 7, [iter: 105 / all 190], err_s_label: 0.450312, err_s_domain: 1.817127, err_t_domain: 0.684686
# epoch: 7, [iter: 106 / all 190], err_s_label: 0.411178, err_s_domain: 1.824141, err_t_domain: 0.687540
# epoch: 7, [iter: 107 / all 190], err_s_label: 0.537136, err_s_domain: 1.826434, err_t_domain: 0.689770
# epoch: 7, [iter: 108 / all 190], err_s_label: 0.423516, err_s_domain: 1.666986, err_t_domain: 0.678859
# epoch: 7, [iter: 109 / all 190], err_s_label: 0.379911, err_s_domain: 1.693835, err_t_domain: 0.694277
# epoch: 7, [iter: 110 / all 190], err_s_label: 0.380338, err_s_domain: 1.912058, err_t_domain: 0.670333
# epoch: 7, [iter: 111 / all 190], err_s_label: 0.420989, err_s_domain: 1.665548, err_t_domain: 0.659214
# epoch: 7, [iter: 112 / all 190], err_s_label: 0.355823, err_s_domain: 1.716319, err_t_domain: 0.694163
# epoch: 7, [iter: 113 / all 190], err_s_label: 0.350195, err_s_domain: 1.819914, err_t_domain: 0.687036
# epoch: 7, [iter: 114 / all 190], err_s_label: 0.325495, err_s_domain: 1.723701, err_t_domain: 0.686303
# epoch: 7, [iter: 115 / all 190], err_s_label: 0.635616, err_s_domain: 1.707841, err_t_domain: 0.674519
# epoch: 7, [iter: 116 / all 190], err_s_label: 0.667063, err_s_domain: 1.781444, err_t_domain: 0.681789
# epoch: 7, [iter: 117 / all 190], err_s_label: 0.405824, err_s_domain: 1.681629, err_t_domain: 0.695248
# epoch: 7, [iter: 118 / all 190], err_s_label: 0.602485, err_s_domain: 1.704979, err_t_domain: 0.677016
# epoch: 7, [iter: 119 / all 190], err_s_label: 0.461765, err_s_domain: 1.858859, err_t_domain: 0.703753
# epoch: 7, [iter: 120 / all 190], err_s_label: 0.604924, err_s_domain: 1.798500, err_t_domain: 0.700986
# epoch: 7, [iter: 121 / all 190], err_s_label: 0.563892, err_s_domain: 1.790324, err_t_domain: 0.700109
# epoch: 7, [iter: 122 / all 190], err_s_label: 0.698828, err_s_domain: 1.718173, err_t_domain: 0.722735
# epoch: 7, [iter: 123 / all 190], err_s_label: 0.537588, err_s_domain: 1.802888, err_t_domain: 0.701803
# epoch: 7, [iter: 124 / all 190], err_s_label: 0.395789, err_s_domain: 1.775945, err_t_domain: 0.675988
# epoch: 7, [iter: 125 / all 190], err_s_label: 0.493080, err_s_domain: 1.699186, err_t_domain: 0.695014
# epoch: 7, [iter: 126 / all 190], err_s_label: 0.326387, err_s_domain: 1.801308, err_t_domain: 0.690090
# epoch: 7, [iter: 127 / all 190], err_s_label: 0.415253, err_s_domain: 1.709266, err_t_domain: 0.705521
# epoch: 7, [iter: 128 / all 190], err_s_label: 0.362598, err_s_domain: 1.764233, err_t_domain: 0.701551
# epoch: 7, [iter: 129 / all 190], err_s_label: 0.648620, err_s_domain: 1.648396, err_t_domain: 0.677632
# epoch: 7, [iter: 130 / all 190], err_s_label: 0.465957, err_s_domain: 1.722825, err_t_domain: 0.724880
# epoch: 7, [iter: 131 / all 190], err_s_label: 0.378565, err_s_domain: 1.837367, err_t_domain: 0.713485
# epoch: 7, [iter: 132 / all 190], err_s_label: 0.489680, err_s_domain: 1.712139, err_t_domain: 0.652865
# epoch: 7, [iter: 133 / all 190], err_s_label: 0.670087, err_s_domain: 1.717979, err_t_domain: 0.688207
# epoch: 7, [iter: 134 / all 190], err_s_label: 0.450268, err_s_domain: 1.716012, err_t_domain: 0.659633
# epoch: 7, [iter: 135 / all 190], err_s_label: 0.566756, err_s_domain: 1.689326, err_t_domain: 0.705665
# epoch: 7, [iter: 136 / all 190], err_s_label: 0.595745, err_s_domain: 1.835620, err_t_domain: 0.709639
# epoch: 7, [iter: 137 / all 190], err_s_label: 0.402209, err_s_domain: 1.782021, err_t_domain: 0.700931
# epoch: 7, [iter: 138 / all 190], err_s_label: 0.631138, err_s_domain: 1.796850, err_t_domain: 0.748042
# epoch: 7, [iter: 139 / all 190], err_s_label: 0.520656, err_s_domain: 1.848467, err_t_domain: 0.680336
# epoch: 7, [iter: 140 / all 190], err_s_label: 0.731709, err_s_domain: 1.666749, err_t_domain: 0.731276
# epoch: 7, [iter: 141 / all 190], err_s_label: 0.597990, err_s_domain: 1.717804, err_t_domain: 0.712856
# epoch: 7, [iter: 142 / all 190], err_s_label: 0.396574, err_s_domain: 1.750531, err_t_domain: 0.707263
# epoch: 7, [iter: 143 / all 190], err_s_label: 0.350754, err_s_domain: 1.860291, err_t_domain: 0.711308
# epoch: 7, [iter: 144 / all 190], err_s_label: 0.736739, err_s_domain: 1.815591, err_t_domain: 0.717431
# epoch: 7, [iter: 145 / all 190], err_s_label: 0.288054, err_s_domain: 1.752704, err_t_domain: 0.695506
# epoch: 7, [iter: 146 / all 190], err_s_label: 0.423532, err_s_domain: 1.694712, err_t_domain: 0.676245
# epoch: 7, [iter: 147 / all 190], err_s_label: 0.380551, err_s_domain: 1.774363, err_t_domain: 0.706332
# epoch: 7, [iter: 148 / all 190], err_s_label: 0.453618, err_s_domain: 1.762474, err_t_domain: 0.686264
# epoch: 7, [iter: 149 / all 190], err_s_label: 0.282944, err_s_domain: 1.755417, err_t_domain: 0.711361
# epoch: 7, [iter: 150 / all 190], err_s_label: 0.605737, err_s_domain: 1.836020, err_t_domain: 0.670109
# epoch: 7, [iter: 151 / all 190], err_s_label: 0.219070, err_s_domain: 1.829038, err_t_domain: 0.675260
# epoch: 7, [iter: 152 / all 190], err_s_label: 0.320581, err_s_domain: 1.857150, err_t_domain: 0.667771
# epoch: 7, [iter: 153 / all 190], err_s_label: 0.530350, err_s_domain: 1.917516, err_t_domain: 0.682746
# epoch: 7, [iter: 154 / all 190], err_s_label: 0.709987, err_s_domain: 1.810777, err_t_domain: 0.665308
# epoch: 7, [iter: 155 / all 190], err_s_label: 0.316663, err_s_domain: 1.727294, err_t_domain: 0.681927
# epoch: 7, [iter: 156 / all 190], err_s_label: 0.740299, err_s_domain: 1.806793, err_t_domain: 0.675420
# epoch: 7, [iter: 157 / all 190], err_s_label: 0.695015, err_s_domain: 1.798050, err_t_domain: 0.688735
# epoch: 7, [iter: 158 / all 190], err_s_label: 0.995682, err_s_domain: 1.902734, err_t_domain: 0.662408
# epoch: 7, [iter: 159 / all 190], err_s_label: 0.421205, err_s_domain: 1.845392, err_t_domain: 0.691177
# epoch: 7, [iter: 160 / all 190], err_s_label: 0.732110, err_s_domain: 1.776062, err_t_domain: 0.714475
# epoch: 7, [iter: 161 / all 190], err_s_label: 0.649616, err_s_domain: 1.700663, err_t_domain: 0.727851
# epoch: 7, [iter: 162 / all 190], err_s_label: 0.135188, err_s_domain: 1.688823, err_t_domain: 0.704202
# epoch: 7, [iter: 163 / all 190], err_s_label: 0.288630, err_s_domain: 1.792058, err_t_domain: 0.676645
# epoch: 7, [iter: 164 / all 190], err_s_label: 0.539393, err_s_domain: 1.818383, err_t_domain: 0.711509
# epoch: 7, [iter: 165 / all 190], err_s_label: 0.720698, err_s_domain: 1.678350, err_t_domain: 0.722902
# epoch: 7, [iter: 166 / all 190], err_s_label: 0.423651, err_s_domain: 1.737587, err_t_domain: 0.712346
# epoch: 7, [iter: 167 / all 190], err_s_label: 0.761395, err_s_domain: 1.748940, err_t_domain: 0.690804
# epoch: 7, [iter: 168 / all 190], err_s_label: 0.340117, err_s_domain: 1.701202, err_t_domain: 0.684002
# epoch: 7, [iter: 169 / all 190], err_s_label: 0.522390, err_s_domain: 1.703150, err_t_domain: 0.670011
# epoch: 7, [iter: 170 / all 190], err_s_label: 0.549621, err_s_domain: 1.735924, err_t_domain: 0.679727
# epoch: 7, [iter: 171 / all 190], err_s_label: 0.435850, err_s_domain: 1.799944, err_t_domain: 0.698754
# epoch: 7, [iter: 172 / all 190], err_s_label: 0.324222, err_s_domain: 1.746367, err_t_domain: 0.706074
# epoch: 7, [iter: 173 / all 190], err_s_label: 0.667125, err_s_domain: 1.742124, err_t_domain: 0.708298
# epoch: 7, [iter: 174 / all 190], err_s_label: 0.256426, err_s_domain: 1.705857, err_t_domain: 0.713380
# epoch: 7, [iter: 175 / all 190], err_s_label: 0.381289, err_s_domain: 1.715593, err_t_domain: 0.685891
# epoch: 7, [iter: 176 / all 190], err_s_label: 0.633024, err_s_domain: 1.717666, err_t_domain: 0.703933
# epoch: 7, [iter: 177 / all 190], err_s_label: 0.267447, err_s_domain: 1.700704, err_t_domain: 0.681238
# epoch: 7, [iter: 178 / all 190], err_s_label: 0.489690, err_s_domain: 1.712825, err_t_domain: 0.695219
# epoch: 7, [iter: 179 / all 190], err_s_label: 0.679626, err_s_domain: 1.744006, err_t_domain: 0.672541
# epoch: 7, [iter: 180 / all 190], err_s_label: 0.573095, err_s_domain: 1.805360, err_t_domain: 0.663764
# epoch: 7, [iter: 181 / all 190], err_s_label: 0.320551, err_s_domain: 1.740505, err_t_domain: 0.694319
# epoch: 7, [iter: 182 / all 190], err_s_label: 0.497774, err_s_domain: 1.735136, err_t_domain: 0.667333
# epoch: 7, [iter: 183 / all 190], err_s_label: 0.513765, err_s_domain: 1.640142, err_t_domain: 0.696588
# epoch: 7, [iter: 184 / all 190], err_s_label: 0.235515, err_s_domain: 1.732907, err_t_domain: 0.664738
# epoch: 7, [iter: 185 / all 190], err_s_label: 0.346587, err_s_domain: 1.727702, err_t_domain: 0.707520
# epoch: 7, [iter: 186 / all 190], err_s_label: 0.293928, err_s_domain: 1.687291, err_t_domain: 0.659517
# epoch: 7, [iter: 187 / all 190], err_s_label: 0.432631, err_s_domain: 1.705071, err_t_domain: 0.689731
# epoch: 7, [iter: 188 / all 190], err_s_label: 0.225009, err_s_domain: 1.731666, err_t_domain: 0.679935
# epoch: 7, [iter: 189 / all 190], err_s_label: 0.261662, err_s_domain: 1.691581, err_t_domain: 0.676355
# epoch: 7, [iter: 190 / all 190], err_s_label: 0.233318, err_s_domain: 1.700061, err_t_domain: 0.667431
# epoch: 7, accuracy of the train dataset: 0.348895
# epoch: 7, accuracy of the test dataset: 0.313311
# epoch: 8, [iter: 1 / all 190], err_s_label: 0.429952, err_s_domain: 1.785582, err_t_domain: 0.698179
# epoch: 8, [iter: 2 / all 190], err_s_label: 0.392165, err_s_domain: 1.727942, err_t_domain: 0.653678
# epoch: 8, [iter: 3 / all 190], err_s_label: 0.400593, err_s_domain: 1.820180, err_t_domain: 0.671556
# epoch: 8, [iter: 4 / all 190], err_s_label: 0.477751, err_s_domain: 1.773528, err_t_domain: 0.708124
# epoch: 8, [iter: 5 / all 190], err_s_label: 0.335673, err_s_domain: 1.827260, err_t_domain: 0.678830
# epoch: 8, [iter: 6 / all 190], err_s_label: 0.191454, err_s_domain: 1.753925, err_t_domain: 0.653629
# epoch: 8, [iter: 7 / all 190], err_s_label: 0.555972, err_s_domain: 1.835404, err_t_domain: 0.683263
# epoch: 8, [iter: 8 / all 190], err_s_label: 0.315358, err_s_domain: 1.695385, err_t_domain: 0.686454
# epoch: 8, [iter: 9 / all 190], err_s_label: 0.161590, err_s_domain: 1.727946, err_t_domain: 0.699164
# epoch: 8, [iter: 10 / all 190], err_s_label: 0.454178, err_s_domain: 1.764891, err_t_domain: 0.709093
# epoch: 8, [iter: 11 / all 190], err_s_label: 0.575341, err_s_domain: 1.692625, err_t_domain: 0.716432
# epoch: 8, [iter: 12 / all 190], err_s_label: 0.560977, err_s_domain: 1.881206, err_t_domain: 0.706525
# epoch: 8, [iter: 13 / all 190], err_s_label: 0.564521, err_s_domain: 1.941896, err_t_domain: 0.675686
# epoch: 8, [iter: 14 / all 190], err_s_label: 0.310738, err_s_domain: 1.758119, err_t_domain: 0.685157
# epoch: 8, [iter: 15 / all 190], err_s_label: 0.378699, err_s_domain: 1.809422, err_t_domain: 0.685282
# epoch: 8, [iter: 16 / all 190], err_s_label: 0.185939, err_s_domain: 1.732286, err_t_domain: 0.691018
# epoch: 8, [iter: 17 / all 190], err_s_label: 0.435434, err_s_domain: 1.762702, err_t_domain: 0.713736
# epoch: 8, [iter: 18 / all 190], err_s_label: 0.380894, err_s_domain: 1.797823, err_t_domain: 0.674834
# epoch: 8, [iter: 19 / all 190], err_s_label: 0.383252, err_s_domain: 1.719563, err_t_domain: 0.682588
# epoch: 8, [iter: 20 / all 190], err_s_label: 0.422799, err_s_domain: 1.754582, err_t_domain: 0.687519
# epoch: 8, [iter: 21 / all 190], err_s_label: 0.360227, err_s_domain: 1.757688, err_t_domain: 0.711791
# epoch: 8, [iter: 22 / all 190], err_s_label: 0.434371, err_s_domain: 1.845623, err_t_domain: 0.696266
# epoch: 8, [iter: 23 / all 190], err_s_label: 0.312929, err_s_domain: 1.741996, err_t_domain: 0.667010
# epoch: 8, [iter: 24 / all 190], err_s_label: 0.395226, err_s_domain: 1.749922, err_t_domain: 0.685809
# epoch: 8, [iter: 25 / all 190], err_s_label: 0.331534, err_s_domain: 1.806203, err_t_domain: 0.674930
# epoch: 8, [iter: 26 / all 190], err_s_label: 0.447311, err_s_domain: 1.760608, err_t_domain: 0.719826
# epoch: 8, [iter: 27 / all 190], err_s_label: 0.257934, err_s_domain: 1.794320, err_t_domain: 0.698535
# epoch: 8, [iter: 28 / all 190], err_s_label: 0.115069, err_s_domain: 1.809846, err_t_domain: 0.707836
# epoch: 8, [iter: 29 / all 190], err_s_label: 0.347835, err_s_domain: 1.807654, err_t_domain: 0.699597
# epoch: 8, [iter: 30 / all 190], err_s_label: 0.494394, err_s_domain: 1.731942, err_t_domain: 0.666558
# epoch: 8, [iter: 31 / all 190], err_s_label: 0.477110, err_s_domain: 1.744799, err_t_domain: 0.651438
# epoch: 8, [iter: 32 / all 190], err_s_label: 0.335805, err_s_domain: 1.803514, err_t_domain: 0.693288
# epoch: 8, [iter: 33 / all 190], err_s_label: 0.486017, err_s_domain: 1.743458, err_t_domain: 0.682675
# epoch: 8, [iter: 34 / all 190], err_s_label: 0.449821, err_s_domain: 1.701141, err_t_domain: 0.683996
# epoch: 8, [iter: 35 / all 190], err_s_label: 0.343423, err_s_domain: 1.830083, err_t_domain: 0.702703
# epoch: 8, [iter: 36 / all 190], err_s_label: 0.396825, err_s_domain: 1.758669, err_t_domain: 0.679245
# epoch: 8, [iter: 37 / all 190], err_s_label: 0.186499, err_s_domain: 1.784812, err_t_domain: 0.668958
# epoch: 8, [iter: 38 / all 190], err_s_label: 0.607674, err_s_domain: 1.823180, err_t_domain: 0.699107
# epoch: 8, [iter: 39 / all 190], err_s_label: 0.357524, err_s_domain: 1.803049, err_t_domain: 0.676380
# epoch: 8, [iter: 40 / all 190], err_s_label: 0.449702, err_s_domain: 1.735857, err_t_domain: 0.685612
# epoch: 8, [iter: 41 / all 190], err_s_label: 0.233096, err_s_domain: 1.848601, err_t_domain: 0.673506
# epoch: 8, [iter: 42 / all 190], err_s_label: 0.710166, err_s_domain: 1.830680, err_t_domain: 0.702248
# epoch: 8, [iter: 43 / all 190], err_s_label: 0.499848, err_s_domain: 1.753246, err_t_domain: 0.663174
# epoch: 8, [iter: 44 / all 190], err_s_label: 0.276811, err_s_domain: 1.806640, err_t_domain: 0.677099
# epoch: 8, [iter: 45 / all 190], err_s_label: 0.340299, err_s_domain: 1.760847, err_t_domain: 0.671724
# epoch: 8, [iter: 46 / all 190], err_s_label: 0.333295, err_s_domain: 1.711121, err_t_domain: 0.674294
# epoch: 8, [iter: 47 / all 190], err_s_label: 0.192698, err_s_domain: 1.806979, err_t_domain: 0.699229
# epoch: 8, [iter: 48 / all 190], err_s_label: 0.639804, err_s_domain: 1.808269, err_t_domain: 0.691386
# epoch: 8, [iter: 49 / all 190], err_s_label: 0.484858, err_s_domain: 1.827140, err_t_domain: 0.707786
# epoch: 8, [iter: 50 / all 190], err_s_label: 0.188879, err_s_domain: 1.814633, err_t_domain: 0.700190
# epoch: 8, [iter: 51 / all 190], err_s_label: 0.413528, err_s_domain: 1.765696, err_t_domain: 0.687520
# epoch: 8, [iter: 52 / all 190], err_s_label: 0.421378, err_s_domain: 1.766416, err_t_domain: 0.698112
# epoch: 8, [iter: 53 / all 190], err_s_label: 0.417074, err_s_domain: 1.801947, err_t_domain: 0.731017
# epoch: 8, [iter: 54 / all 190], err_s_label: 0.386165, err_s_domain: 1.783127, err_t_domain: 0.706294
# epoch: 8, [iter: 55 / all 190], err_s_label: 0.589436, err_s_domain: 1.803860, err_t_domain: 0.690257
# epoch: 8, [iter: 56 / all 190], err_s_label: 0.348921, err_s_domain: 1.750305, err_t_domain: 0.719069
# epoch: 8, [iter: 57 / all 190], err_s_label: 0.267847, err_s_domain: 1.758156, err_t_domain: 0.696030
# epoch: 8, [iter: 58 / all 190], err_s_label: 0.424558, err_s_domain: 1.923206, err_t_domain: 0.701395
# epoch: 8, [iter: 59 / all 190], err_s_label: 0.398457, err_s_domain: 1.769872, err_t_domain: 0.713984
# epoch: 8, [iter: 60 / all 190], err_s_label: 0.532640, err_s_domain: 1.770126, err_t_domain: 0.732199
# epoch: 8, [iter: 61 / all 190], err_s_label: 0.389866, err_s_domain: 1.751151, err_t_domain: 0.744251
# epoch: 8, [iter: 62 / all 190], err_s_label: 0.303590, err_s_domain: 1.826803, err_t_domain: 0.735976
# epoch: 8, [iter: 63 / all 190], err_s_label: 0.344472, err_s_domain: 1.826888, err_t_domain: 0.719059
# epoch: 8, [iter: 64 / all 190], err_s_label: 0.821961, err_s_domain: 1.891724, err_t_domain: 0.700352
# epoch: 8, [iter: 65 / all 190], err_s_label: 0.361093, err_s_domain: 1.822702, err_t_domain: 0.735654
# epoch: 8, [iter: 66 / all 190], err_s_label: 0.496078, err_s_domain: 1.793969, err_t_domain: 0.685100
# epoch: 8, [iter: 67 / all 190], err_s_label: 0.495647, err_s_domain: 1.759108, err_t_domain: 0.665198
# epoch: 8, [iter: 68 / all 190], err_s_label: 0.617997, err_s_domain: 1.763994, err_t_domain: 0.696629
# epoch: 8, [iter: 69 / all 190], err_s_label: 0.370566, err_s_domain: 1.827628, err_t_domain: 0.709542
# epoch: 8, [iter: 70 / all 190], err_s_label: 0.412775, err_s_domain: 1.759811, err_t_domain: 0.727269
# epoch: 8, [iter: 71 / all 190], err_s_label: 0.686144, err_s_domain: 1.756887, err_t_domain: 0.682072
# ...
# epoch: 31, [iter: 48 / all 190], err_s_label: 0.072077, err_s_domain: 1.801671, err_t_domain: 0.698710
# epoch: 31, [iter: 49 / all 190], err_s_label: 0.093378, err_s_domain: 1.734236, err_t_domain: 0.698675
# epoch: 31, [iter: 50 / all 190], err_s_label: 0.070655, err_s_domain: 1.780509, err_t_domain: 0.699417
# epoch: 31, [iter: 51 / all 190], err_s_label: 0.182418, err_s_domain: 1.746023, err_t_domain: 0.690679
# epoch: 31, [iter: 52 / all 190], err_s_label: 0.139757, err_s_domain: 1.786011, err_t_domain: 0.694509
# epoch: 31, [iter: 53 / all 190], err_s_label: 0.092941, err_s_domain: 1.728656, err_t_domain: 0.695601
# epoch: 31, [iter: 54 / all 190], err_s_label: 0.025560, err_s_domain: 1.744852, err_t_domain: 0.686755
# epoch: 31, [iter: 55 / all 190], err_s_label: 0.038830, err_s_domain: 1.812510, err_t_domain: 0.691638
# epoch: 31, [iter: 56 / all 190], err_s_label: 0.016122, err_s_domain: 1.794721, err_t_domain: 0.696645
# epoch: 31, [iter: 57 / all 190], err_s_label: 0.007673, err_s_domain: 1.781549, err_t_domain: 0.691609
# epoch: 31, [iter: 58 / all 190], err_s_label: 0.019385, err_s_domain: 1.767904, err_t_domain: 0.695883
# epoch: 31, [iter: 59 / all 190], err_s_label: 0.060326, err_s_domain: 1.751164, err_t_domain: 0.688222
# epoch: 31, [iter: 60 / all 190], err_s_label: 0.081618, err_s_domain: 1.750779, err_t_domain: 0.694993
# epoch: 31, [iter: 61 / all 190], err_s_label: 0.071191, err_s_domain: 1.714729, err_t_domain: 0.693373
# epoch: 31, [iter: 62 / all 190], err_s_label: 0.061122, err_s_domain: 1.750023, err_t_domain: 0.695161
# epoch: 31, [iter: 63 / all 190], err_s_label: 0.006373, err_s_domain: 1.768557, err_t_domain: 0.697429
# epoch: 31, [iter: 64 / all 190], err_s_label: 0.004127, err_s_domain: 1.705529, err_t_domain: 0.698929
# epoch: 31, [iter: 65 / all 190], err_s_label: 0.190370, err_s_domain: 1.743430, err_t_domain: 0.696976
# epoch: 31, [iter: 66 / all 190], err_s_label: 0.082055, err_s_domain: 1.751741, err_t_domain: 0.691201
# epoch: 31, [iter: 67 / all 190], err_s_label: 0.055723, err_s_domain: 1.732982, err_t_domain: 0.700845
# epoch: 31, [iter: 68 / all 190], err_s_label: 0.002610, err_s_domain: 1.734119, err_t_domain: 0.700172
# epoch: 31, [iter: 69 / all 190], err_s_label: 0.109140, err_s_domain: 1.742951, err_t_domain: 0.701074
# epoch: 31, [iter: 70 / all 190], err_s_label: 0.104447, err_s_domain: 1.740734, err_t_domain: 0.704536
# epoch: 31, [iter: 71 / all 190], err_s_label: 0.157929, err_s_domain: 1.773834, err_t_domain: 0.699084
# epoch: 31, [iter: 72 / all 190], err_s_label: 0.032387, err_s_domain: 1.787608, err_t_domain: 0.696550
# epoch: 31, [iter: 73 / all 190], err_s_label: 0.010475, err_s_domain: 1.798005, err_t_domain: 0.699961
# epoch: 31, [iter: 74 / all 190], err_s_label: 0.028278, err_s_domain: 1.815193, err_t_domain: 0.696647
# epoch: 31, [iter: 75 / all 190], err_s_label: 0.023453, err_s_domain: 1.810389, err_t_domain: 0.692064
# epoch: 31, [iter: 76 / all 190], err_s_label: 0.055089, err_s_domain: 1.784500, err_t_domain: 0.684237
# epoch: 31, [iter: 77 / all 190], err_s_label: 0.010644, err_s_domain: 1.819239, err_t_domain: 0.697422
# epoch: 31, [iter: 78 / all 190], err_s_label: 0.025627, err_s_domain: 1.753971, err_t_domain: 0.690244
# epoch: 31, [iter: 79 / all 190], err_s_label: 0.195400, err_s_domain: 1.846111, err_t_domain: 0.693595
# epoch: 31, [iter: 80 / all 190], err_s_label: 0.009709, err_s_domain: 1.794699, err_t_domain: 0.693811
# epoch: 31, [iter: 81 / all 190], err_s_label: 0.052872, err_s_domain: 1.796194, err_t_domain: 0.694026
# epoch: 31, [iter: 82 / all 190], err_s_label: 0.374307, err_s_domain: 1.813584, err_t_domain: 0.685171
# epoch: 31, [iter: 83 / all 190], err_s_label: 0.276039, err_s_domain: 1.780732, err_t_domain: 0.688803
# epoch: 31, [iter: 84 / all 190], err_s_label: 0.180805, err_s_domain: 1.833765, err_t_domain: 0.693220
# epoch: 31, [iter: 85 / all 190], err_s_label: 0.008283, err_s_domain: 1.824215, err_t_domain: 0.685235
# epoch: 31, [iter: 86 / all 190], err_s_label: 0.116009, err_s_domain: 1.791770, err_t_domain: 0.689258
# epoch: 31, [iter: 87 / all 190], err_s_label: 0.006309, err_s_domain: 1.730197, err_t_domain: 0.684748
# epoch: 31, [iter: 88 / all 190], err_s_label: 0.028404, err_s_domain: 1.777810, err_t_domain: 0.688367
# epoch: 31, [iter: 89 / all 190], err_s_label: 0.685482, err_s_domain: 1.703860, err_t_domain: 0.691251
# epoch: 31, [iter: 90 / all 190], err_s_label: 0.110315, err_s_domain: 1.795280, err_t_domain: 0.690802
# epoch: 31, [iter: 91 / all 190], err_s_label: 0.058513, err_s_domain: 1.709047, err_t_domain: 0.696374
# epoch: 31, [iter: 92 / all 190], err_s_label: 0.092504, err_s_domain: 1.809955, err_t_domain: 0.688216
# epoch: 31, [iter: 93 / all 190], err_s_label: 0.344941, err_s_domain: 1.808825, err_t_domain: 0.693036
# epoch: 31, [iter: 94 / all 190], err_s_label: 0.091045, err_s_domain: 1.793624, err_t_domain: 0.692963
# epoch: 31, [iter: 95 / all 190], err_s_label: 0.150920, err_s_domain: 1.821505, err_t_domain: 0.696783
# epoch: 31, [iter: 96 / all 190], err_s_label: 0.047872, err_s_domain: 1.812478, err_t_domain: 0.698878
# epoch: 31, [iter: 97 / all 190], err_s_label: 0.036141, err_s_domain: 1.824316, err_t_domain: 0.702620
# epoch: 31, [iter: 98 / all 190], err_s_label: 0.085562, err_s_domain: 1.739621, err_t_domain: 0.688431
# epoch: 31, [iter: 99 / all 190], err_s_label: 0.111356, err_s_domain: 1.754654, err_t_domain: 0.694712
# epoch: 31, [iter: 100 / all 190], err_s_label: 0.246005, err_s_domain: 1.766115, err_t_domain: 0.702083
# epoch: 31, [iter: 101 / all 190], err_s_label: 0.238855, err_s_domain: 1.796732, err_t_domain: 0.701760
# epoch: 31, [iter: 102 / all 190], err_s_label: 0.012627, err_s_domain: 1.735107, err_t_domain: 0.708047
# epoch: 31, [iter: 103 / all 190], err_s_label: 0.024566, err_s_domain: 1.792427, err_t_domain: 0.700549
# epoch: 31, [iter: 104 / all 190], err_s_label: 0.056112, err_s_domain: 1.828622, err_t_domain: 0.703007
# epoch: 31, [iter: 105 / all 190], err_s_label: 0.283872, err_s_domain: 1.708157, err_t_domain: 0.699953
# epoch: 31, [iter: 106 / all 190], err_s_label: 0.098318, err_s_domain: 1.771994, err_t_domain: 0.708471
# epoch: 31, [iter: 107 / all 190], err_s_label: 0.091773, err_s_domain: 1.830592, err_t_domain: 0.700116
# epoch: 31, [iter: 108 / all 190], err_s_label: 0.047660, err_s_domain: 1.775465, err_t_domain: 0.699728
# epoch: 31, [iter: 109 / all 190], err_s_label: 0.027502, err_s_domain: 1.836940, err_t_domain: 0.702363
# epoch: 31, [iter: 110 / all 190], err_s_label: 0.338676, err_s_domain: 1.751952, err_t_domain: 0.696301
# epoch: 31, [iter: 111 / all 190], err_s_label: 0.063340, err_s_domain: 1.831481, err_t_domain: 0.700213
# epoch: 31, [iter: 112 / all 190], err_s_label: 0.192147, err_s_domain: 1.760042, err_t_domain: 0.692796
# epoch: 31, [iter: 113 / all 190], err_s_label: 0.089101, err_s_domain: 1.767963, err_t_domain: 0.693106
# epoch: 31, [iter: 114 / all 190], err_s_label: 0.274114, err_s_domain: 1.768603, err_t_domain: 0.695189
# epoch: 31, [iter: 115 / all 190], err_s_label: 0.328873, err_s_domain: 1.726911, err_t_domain: 0.693218
# epoch: 31, [iter: 116 / all 190], err_s_label: 0.008196, err_s_domain: 1.804695, err_t_domain: 0.682563
# epoch: 31, [iter: 117 / all 190], err_s_label: 0.043283, err_s_domain: 1.729646, err_t_domain: 0.692036
# epoch: 31, [iter: 118 / all 190], err_s_label: 0.298308, err_s_domain: 1.732937, err_t_domain: 0.688851
# epoch: 31, [iter: 119 / all 190], err_s_label: 0.020009, err_s_domain: 1.754683, err_t_domain: 0.683138
# epoch: 31, [iter: 120 / all 190], err_s_label: 0.125568, err_s_domain: 1.763513, err_t_domain: 0.692477
# epoch: 31, [iter: 121 / all 190], err_s_label: 0.117919, err_s_domain: 1.770930, err_t_domain: 0.678725
# epoch: 31, [iter: 122 / all 190], err_s_label: 0.077603, err_s_domain: 1.754667, err_t_domain: 0.688978
# epoch: 31, [iter: 123 / all 190], err_s_label: 0.289036, err_s_domain: 1.746301, err_t_domain: 0.695949
# epoch: 31, [iter: 124 / all 190], err_s_label: 0.013643, err_s_domain: 1.816484, err_t_domain: 0.685661
# epoch: 31, [iter: 125 / all 190], err_s_label: 0.244375, err_s_domain: 1.736463, err_t_domain: 0.687737
# epoch: 31, [iter: 126 / all 190], err_s_label: 0.061689, err_s_domain: 1.672261, err_t_domain: 0.697190
# epoch: 31, [iter: 127 / all 190], err_s_label: 0.004674, err_s_domain: 1.796442, err_t_domain: 0.692484
# epoch: 31, [iter: 128 / all 190], err_s_label: 0.014050, err_s_domain: 1.863624, err_t_domain: 0.686626
# epoch: 31, [iter: 129 / all 190], err_s_label: 0.030465, err_s_domain: 1.760823, err_t_domain: 0.695295
# epoch: 31, [iter: 130 / all 190], err_s_label: 0.104231, err_s_domain: 1.807387, err_t_domain: 0.684679
# epoch: 31, [iter: 131 / all 190], err_s_label: 0.009927, err_s_domain: 1.787678, err_t_domain: 0.687274
# epoch: 31, [iter: 132 / all 190], err_s_label: 0.042795, err_s_domain: 1.730311, err_t_domain: 0.691987
# epoch: 31, [iter: 133 / all 190], err_s_label: 0.232029, err_s_domain: 1.831381, err_t_domain: 0.694599
# epoch: 31, [iter: 134 / all 190], err_s_label: 0.194114, err_s_domain: 1.751138, err_t_domain: 0.686935
# epoch: 31, [iter: 135 / all 190], err_s_label: 0.109980, err_s_domain: 1.717189, err_t_domain: 0.690292
# epoch: 31, [iter: 136 / all 190], err_s_label: 0.072303, err_s_domain: 1.777282, err_t_domain: 0.703495
# epoch: 31, [iter: 137 / all 190], err_s_label: 0.009633, err_s_domain: 1.806947, err_t_domain: 0.696988
# epoch: 31, [iter: 138 / all 190], err_s_label: 0.139734, err_s_domain: 1.750197, err_t_domain: 0.690868
# epoch: 31, [iter: 139 / all 190], err_s_label: 0.087127, err_s_domain: 1.818452, err_t_domain: 0.690589
# epoch: 31, [iter: 140 / all 190], err_s_label: 0.142664, err_s_domain: 1.750699, err_t_domain: 0.694083
# epoch: 31, [iter: 141 / all 190], err_s_label: 0.288057, err_s_domain: 1.789551, err_t_domain: 0.694038
# epoch: 31, [iter: 142 / all 190], err_s_label: 0.081848, err_s_domain: 1.752591, err_t_domain: 0.696407
# epoch: 31, [iter: 143 / all 190], err_s_label: 0.069332, err_s_domain: 1.790653, err_t_domain: 0.696362
# epoch: 31, [iter: 144 / all 190], err_s_label: 0.019214, err_s_domain: 1.799494, err_t_domain: 0.693863
# epoch: 31, [iter: 145 / all 190], err_s_label: 0.185381, err_s_domain: 1.764098, err_t_domain: 0.708670
# epoch: 31, [iter: 146 / all 190], err_s_label: 0.038473, err_s_domain: 1.683382, err_t_domain: 0.698281
# epoch: 31, [iter: 147 / all 190], err_s_label: 0.329905, err_s_domain: 1.814697, err_t_domain: 0.698782
# epoch: 31, [iter: 148 / all 190], err_s_label: 0.100060, err_s_domain: 1.816365, err_t_domain: 0.694307
# epoch: 31, [iter: 149 / all 190], err_s_label: 0.066822, err_s_domain: 1.766898, err_t_domain: 0.698485
# epoch: 31, [iter: 150 / all 190], err_s_label: 0.117339, err_s_domain: 1.701088, err_t_domain: 0.701899
# epoch: 31, [iter: 151 / all 190], err_s_label: 0.180225, err_s_domain: 1.852432, err_t_domain: 0.694697
# epoch: 31, [iter: 152 / all 190], err_s_label: 0.041607, err_s_domain: 1.823359, err_t_domain: 0.683480
# epoch: 31, [iter: 153 / all 190], err_s_label: 0.055733, err_s_domain: 1.767764, err_t_domain: 0.692355
# epoch: 31, [iter: 154 / all 190], err_s_label: 0.048990, err_s_domain: 1.796959, err_t_domain: 0.700243
# epoch: 31, [iter: 155 / all 190], err_s_label: 0.106963, err_s_domain: 1.767469, err_t_domain: 0.692788
# epoch: 31, [iter: 156 / all 190], err_s_label: 0.092519, err_s_domain: 1.803653, err_t_domain: 0.695446
# epoch: 31, [iter: 157 / all 190], err_s_label: 0.020582, err_s_domain: 1.802640, err_t_domain: 0.684348
# epoch: 31, [iter: 158 / all 190], err_s_label: 0.042732, err_s_domain: 1.745595, err_t_domain: 0.692891
# epoch: 31, [iter: 159 / all 190], err_s_label: 0.076958, err_s_domain: 1.771745, err_t_domain: 0.692551
# epoch: 31, [iter: 160 / all 190], err_s_label: 0.109884, err_s_domain: 1.768062, err_t_domain: 0.694686
# epoch: 31, [iter: 161 / all 190], err_s_label: 0.081980, err_s_domain: 1.769044, err_t_domain: 0.691619
# epoch: 31, [iter: 162 / all 190], err_s_label: 0.131256, err_s_domain: 1.734209, err_t_domain: 0.698637
# epoch: 31, [iter: 163 / all 190], err_s_label: 0.093999, err_s_domain: 1.739075, err_t_domain: 0.703522
# epoch: 31, [iter: 164 / all 190], err_s_label: 0.026215, err_s_domain: 1.763509, err_t_domain: 0.698584
# epoch: 31, [iter: 165 / all 190], err_s_label: 0.140652, err_s_domain: 1.779748, err_t_domain: 0.697782
# epoch: 31, [iter: 166 / all 190], err_s_label: 0.198456, err_s_domain: 1.746134, err_t_domain: 0.700574
# epoch: 31, [iter: 167 / all 190], err_s_label: 0.012857, err_s_domain: 1.735985, err_t_domain: 0.700674
# epoch: 31, [iter: 168 / all 190], err_s_label: 0.013458, err_s_domain: 1.809399, err_t_domain: 0.697866
# epoch: 31, [iter: 169 / all 190], err_s_label: 0.128788, err_s_domain: 1.744661, err_t_domain: 0.699245
# epoch: 31, [iter: 170 / all 190], err_s_label: 0.013687, err_s_domain: 1.812390, err_t_domain: 0.696546
# epoch: 31, [iter: 171 / all 190], err_s_label: 0.008514, err_s_domain: 1.828730, err_t_domain: 0.699115
# epoch: 31, [iter: 172 / all 190], err_s_label: 0.063445, err_s_domain: 1.787020, err_t_domain: 0.691343
# epoch: 31, [iter: 173 / all 190], err_s_label: 0.054086, err_s_domain: 1.928908, err_t_domain: 0.695687
# epoch: 31, [iter: 174 / all 190], err_s_label: 0.014385, err_s_domain: 1.841780, err_t_domain: 0.689743
# epoch: 31, [iter: 175 / all 190], err_s_label: 0.223237, err_s_domain: 1.816020, err_t_domain: 0.691936
# epoch: 31, [iter: 176 / all 190], err_s_label: 0.274648, err_s_domain: 1.859765, err_t_domain: 0.690378
# epoch: 31, [iter: 177 / all 190], err_s_label: 0.210493, err_s_domain: 1.834723, err_t_domain: 0.692829
# epoch: 31, [iter: 178 / all 190], err_s_label: 0.098183, err_s_domain: 1.785561, err_t_domain: 0.695658
# epoch: 31, [iter: 179 / all 190], err_s_label: 0.014519, err_s_domain: 1.777567, err_t_domain: 0.686966
# epoch: 31, [iter: 180 / all 190], err_s_label: 0.051127, err_s_domain: 1.789222, err_t_domain: 0.697789
# epoch: 31, [iter: 181 / all 190], err_s_label: 0.137281, err_s_domain: 1.802770, err_t_domain: 0.697471
# epoch: 31, [iter: 182 / all 190], err_s_label: 0.016468, err_s_domain: 1.769749, err_t_domain: 0.699233
# epoch: 31, [iter: 183 / all 190], err_s_label: 0.121979, err_s_domain: 1.750410, err_t_domain: 0.699963
# epoch: 31, [iter: 184 / all 190], err_s_label: 0.061799, err_s_domain: 1.748478, err_t_domain: 0.699577
# epoch: 31, [iter: 185 / all 190], err_s_label: 0.323869, err_s_domain: 1.756290, err_t_domain: 0.697804
# epoch: 31, [iter: 186 / all 190], err_s_label: 0.030896, err_s_domain: 1.792162, err_t_domain: 0.699682
# epoch: 31, [iter: 187 / all 190], err_s_label: 0.238310, err_s_domain: 1.759512, err_t_domain: 0.701075
# epoch: 31, [iter: 188 / all 190], err_s_label: 0.227255, err_s_domain: 1.757325, err_t_domain: 0.696232
# epoch: 31, [iter: 189 / all 190], err_s_label: 0.072341, err_s_domain: 1.816397, err_t_domain: 0.701041
# epoch: 31, [iter: 190 / all 190], err_s_label: 0.088230, err_s_domain: 1.824372, err_t_domain: 0.699061
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d245c2930c68> in <module>()
#     114
#     115     # torch.save(my_net, 'output/model_epoch_{}.pth'.format(epoch))
# --> 116     test(my_net, epoch)
#     117     my_net.train()
#     118
#
# <ipython-input-15-1367ceecb862> in test(net, epoch)
#      38     train_results.to_csv(train_results_pth, index=False)
#      39
# ---> 40     test_pths, test_preds = inference(net, dataloader_target, cuda=cuda, alpha=alpha)
#      41     test_results = pd.DataFrame({'id': test_pths, 'label': test_preds})
#      42     test_results_pth = os.path.join(output_root, '%s_test_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
#
# <ipython-input-15-1367ceecb862> in inference(net, dataloader, cuda, alpha)
#      60         pred = class_output.data.max(1, keepdim=True)[1]
#      61         pths = pths + list(img_paths)
# ---> 62         preds = preds + list(pred.squeeze(1).cpu().numpy())
#      63     return pths, preds
#      64
#
# KeyboardInterrupt:
