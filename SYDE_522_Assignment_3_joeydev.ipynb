# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffreyfeng99/SYDE_522_A3/blob/master/SYDE_522_Assignment_3_joeydev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Submission Notes
# Group members:
#
# Jeffrey Feng, 20704800
#
# Joey Kuang, 20726074

# %% [markdown]
# # Import statements

# %%
import os
import pandas as pd
import numpy as np
import random
from PIL import Image
from tqdm import tqdm
from datetime import datetime

import torch
import torch.nn as nn
import torch.utils.data as data
from torch.autograd import Function
import torch.backends.cudnn as cudnn
from torchvision import transforms
from torchvision import datasets
from torchvision import models
import torch.optim as optim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Config

# %%
cuda = True
cudnn.benchmark = True

model_name = "resnet50"

LR = 1e-3
BATCH_SIZE = 32
IMAGE_SIZE = 224 #227
# FT_OUT_SIZE = 512
N_EPOCH = 50

# %% [markdown]
# # Data loader

# %%
dataset_root = '/content/drive/MyDrive/4B/SYDE-522/data'
output_root = '/content/drive/MyDrive/4B/SYDE-522/submission/03302022_resnet50_norm'
source_dataset_name = 'train_set'
target_dataset_name = 'test_set'

source_image_root = os.path.join(dataset_root, source_dataset_name)
target_image_root = os.path.join(dataset_root, target_dataset_name)

train_label_list = os.path.join(dataset_root, 'train_labels.csv')

os.makedirs(output_root, exist_ok=True)

# %%
class GetLoader(data.Dataset):
    def __init__(self, data_root, data_list=None, transform=None):
        self.root = data_root
        self.transform = transform

        # we only pass data_list if it's training set
        if data_list is not None:
            df = pd.read_csv(data_list)
            self.img_paths = df['dir'].to_list()

            if 'label2' in df.columns:
                self.img_labels = df['label2'].to_list()
            else: 
                self.img_labels = ['0' for i in range(len(self.img_paths))]

            if 'label1' in df.columns:
                self.domain_labels = df['label1'].to_list()
            else: 
                self.domain_labels = ['0' for i in range(len(self.img_paths))]
        else:
            # Walk through test folder - we don't need labels
            self.img_paths = [f for root,dirs,files in os.walk(data_root) for f in files if f.endswith('.png')]
            self.img_labels = ['0' for i in range(len(self.img_paths))]
            self.domain_labels = ['0' for i in range(len(self.img_paths))]

        self.n_data = len(self.img_paths)

    def __getitem__(self, item):
        img_paths, labels, domain_labels = self.img_paths[item%self.n_data], self.img_labels[item%self.n_data], self.domain_labels[item%self.n_data]
        imgs = Image.open(os.path.join(self.root, img_paths)).convert('RGB')

        if self.transform is not None:

            if isinstance(self.transform, list):
                tform = self.transform[int(domain_labels)]
            else:
                tform = self.transform

            imgs = tform(imgs)
            labels = int(labels)
            domain_labels = int(domain_labels)

        return imgs, labels, domain_labels, img_paths

    def __len__(self):
        return self.n_data

# %%
# Preprocess data
def preprocess_multiple_fn(mus, stds):
    tforms = []

    for i in range(len(mus)):
        tforms.append(preprocess_fn(mu=mus[i], std=stds[i]))
    
    return tforms

def preprocess_fn(mu=(0.6399, 0.6076, 0.5603), std=(0.3065, 0.3082, 0.3353)):
  img_transform = transforms.Compose([
      transforms.Resize(IMAGE_SIZE),
      transforms.ToTensor(),
      transforms.Normalize(mean=mu, std=std) 
  ])

  return img_transform

def prep_dataloader(image_root, label_list=None, img_transform=None, 
                    drop_last=False, shuffle=True):
    dataset = GetLoader(
        data_root=image_root,
        data_list=label_list,
        transform=img_transform
    )

    dataloader = data.DataLoader(
        dataset=dataset,
        batch_size=BATCH_SIZE,
        shuffle=shuffle,
        num_workers=4,
        drop_last=drop_last)
    
    return dataset, dataloader

# %% [markdown]
# # Model definition

# %%
# if False, then we are feature extracting
def set_parameter_requires_grad(model, finetune):
    for param in model.parameters():
        param.requires_grad = finetune

# %%
class ReverseLayerF(Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None


class CNNModel(nn.Module):

    def __init__(self, model_name="resnet18"):
        super(CNNModel, self).__init__()
        self.ft_out_size = 0

        if model_name == "resnet18":
            self.feature = models.resnet18(pretrained=True) 
            self.feature.fc = nn.Identity()
            self.ft_out_size = 512
        if model_name == "resnet50":
            self.feature = models.resnet50(pretrained=True) 
            self.feature.fc = nn.Identity()
            self.ft_out_size = 2048
        elif model_name == "vgg16":
            self.feature = models.vgg16_bn(pretrained=True) 
            self.feature.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1)) # original is (7,7)
            self.feature.classifier = nn.Identity()
            self.ft_out_size = 512
        else:
            # Need some default model?
            self.feature = nn.Sequential()
            self.feature.add_module('f_conv1', nn.Conv2d(3, 64, kernel_size=5))
            self.feature.add_module('f_bn1', nn.BatchNorm2d(64))
            self.feature.add_module('f_pool1', nn.MaxPool2d(2))
            self.feature.add_module('f_relu1', nn.ReLU(True))
            self.feature.add_module('f_conv2', nn.Conv2d(64, 128, kernel_size=3))
            self.feature.add_module('f_bn2', nn.BatchNorm2d(128))
            self.feature.add_module('f_drop1', nn.Dropout2d())
            self.feature.add_module('f_pool2', nn.MaxPool2d(2))
            self.feature.add_module('f_relu2', nn.ReLU(True))
            self.feature.add_module('f_conv3', nn.Conv2d(128, 256, kernel_size=3))
            self.feature.add_module('f_bn3', nn.BatchNorm2d(256))
            self.feature.add_module('f_drop3', nn.Dropout2d())
            self.feature.add_module('f_pool3', nn.MaxPool2d(2))
            self.feature.add_module('f_relu4', nn.ReLU(True))
            self.feature.add_module('f_conv4', nn.Conv2d(256, 256, kernel_size=3))
            self.feature.add_module('f_bn4', nn.BatchNorm2d(256))
            self.feature.add_module('f_drop4', nn.Dropout2d())
            self.feature.add_module('f_pool4', nn.MaxPool2d(2))
            self.feature.add_module('f_relu4', nn.ReLU(True))
            self.feature.add_module('f_conv5', nn.Conv2d(256, 512, kernel_size=3))
            self.feature.add_module('f_bn5', nn.BatchNorm2d(512))
            self.feature.add_module('f_drop5', nn.Dropout2d())
            self.feature.add_module('f_pool5', nn.MaxPool2d(2))
            self.feature.add_module('f_relu5', nn.ReLU(True))

        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(self.ft_out_size, 100))
        self.class_classifier.add_module('c_bn1', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_drop1', nn.Dropout2d())
        self.class_classifier.add_module('c_fc2', nn.Linear(100, 100))
        self.class_classifier.add_module('c_bn2', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(100, 7))
        self.class_classifier.add_module('c_softmax', nn.LogSoftmax(dim=1))

        self.domain_classifier = nn.Sequential()
        self.domain_classifier.add_module('d_fc1', nn.Linear(self.ft_out_size, 100))
        self.domain_classifier.add_module('d_bn1', nn.BatchNorm1d(100))
        self.domain_classifier.add_module('d_relu1', nn.ReLU(True))
        self.domain_classifier.add_module('d_fc2', nn.Linear(100, 4))
        self.domain_classifier.add_module('d_softmax', nn.LogSoftmax(dim=1))
        


    def forward(self, input_data, alpha):
        input_data = input_data.expand(input_data.data.shape[0], 3, IMAGE_SIZE, IMAGE_SIZE)
        feature = self.feature(input_data)
        feature = feature.view(-1, self.ft_out_size)
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)

        return class_output, domain_output

# %% [markdown]
# # Test pipeline

# %%
def test(net, epoch):

    # load data
    # img_transform_source = preprocess_multiple_fn(mus=[(0.5085, 0.4832, 0.4396),
    #                                                     (0.5550, 0.5085, 0.4579),
    #                                                    (0.8077, 0.7829, 0.7358)], 
    #                                               stds=[(0.1780, 0.1779, 0.1907),
    #                                                     (0.1880, 0.1917, 0.2060),
    #                                                     (0.2239, 0.2283, 0.2437)])
    
    # img_transform_target = preprocess_fn(mu=(0.9566, 0.9566, 0.9566), std=(0.1752, 0.1752, 0.1752))

    img_transform_source = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
    img_transform_target = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))


    dataset_source, dataloader_source = prep_dataloader(
        image_root=os.path.join(source_image_root, 'train_set'),
        label_list=train_label_list,
        img_transform=img_transform_source,
        shuffle=False
    )

    dataset_target, dataloader_target = prep_dataloader(
        image_root=os.path.join(target_image_root, 'test_set'),
        img_transform=img_transform_target,
        shuffle=False
    )

    net.eval()

    if cuda:
        net = net.cuda()

    train_pths, train_preds = inference(net, dataloader_source, cuda=cuda, alpha=alpha)
    train_results = pd.DataFrame({'id': train_pths, 'label': train_preds})
    train_results_pth = os.path.join(output_root, '%s_train_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
    train_results.to_csv(train_results_pth, index=False)

    test_pths, test_preds = inference(net, dataloader_target, cuda=cuda, alpha=alpha)
    test_results = pd.DataFrame({'id': test_pths, 'label': test_preds})
    test_results_pth = os.path.join(output_root, '%s_test_epoch%s.csv' % (datetime.now().strftime("%m%d%Y"), epoch))
    test_results.to_csv(test_results_pth, index=False)

    print('epoch: %d, accuracy of the train dataset: %f' % (epoch, compare(train_label_list, train_results_pth)))

    # Secret
    test_label_list = os.path.join(dataset_root, 'dummy_test_labels.csv')
    print('epoch: %d, accuracy of the test dataset: %f' % (epoch, compare(test_label_list, test_results_pth)))

def inference(net, dataloader, cuda=True, alpha=0.0):
    preds = []
    pths = []
    for input_img, _,_, img_paths in dataloader: 

        if cuda:
            input_img = input_img.cuda()

        class_output, _ = net(input_data=input_img, alpha=alpha)
        pred = class_output.data.max(1, keepdim=True)[1]
        pths = pths + list(img_paths)
        preds = preds + list(pred.squeeze(1).cpu().numpy())
    return pths, preds

def compare(true_labels, predicted_labels):
    combined_df = pd.read_csv(true_labels)
    predicted_df = pd.read_csv(predicted_labels)

    combined_df['label'] = combined_df['dir'].map(predicted_df.set_index('id')['label'])

    true_labels = np.array(combined_df['label2'].to_list())
    pred_labels = np.array(combined_df['label'].to_list())

    return np.sum(true_labels == pred_labels) / len(true_labels)

# %% [markdown]
# # Training pipeline

# %%
manual_seed = random.randint(1, 10000)
random.seed(manual_seed)
torch.manual_seed(manual_seed)

# load data
# img_transform_source = preprocess_multiple_fn(mus=[(0.5085, 0.4832, 0.4396),
#                                                     (0.5550, 0.5085, 0.4579),
#                                                     (0.8077, 0.7829, 0.7358)], 
#                                                 stds=[(0.1780, 0.1779, 0.1907),
#                                                     (0.1880, 0.1917, 0.2060),
#                                                     (0.2239, 0.2283, 0.2437)])
# img_transform_target = preprocess_fn(mu=(0.9566, 0.9566, 0.9566), std=(0.1752, 0.1752, 0.1752))

img_transform_source = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
img_transform_target = preprocess_fn(mu=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))


dataset_source, dataloader_source = prep_dataloader(
    image_root=os.path.join(source_image_root, 'train_set'), # TODO should we unnest
    label_list=train_label_list,
    img_transform=img_transform_source
)

dataset_target, dataloader_target = prep_dataloader(
    image_root=os.path.join(target_image_root, 'test_set'),
    img_transform=img_transform_target
)

# load model
my_net = CNNModel(model_name=model_name)

# setup optimizer
optimizer = optim.Adam(my_net.parameters(), lr=LR)

loss_class = torch.nn.NLLLoss()
loss_domain = torch.nn.NLLLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()
    loss_domain = loss_domain.cuda()

set_parameter_requires_grad(my_net, True)

# training
for epoch in range(N_EPOCH):

    len_dataloader = max(len(dataloader_source), len(dataloader_target))
    data_source_iter = iter(dataloader_source)
    data_target_iter = iter(dataloader_target)

    i = 0
    while i < len_dataloader:

        p = float(i + epoch * len_dataloader) / N_EPOCH / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # training model using source data
        data_source = data_source_iter.next()
        s_img, s_label, s_domain_label, _ = data_source

        my_net.zero_grad()
        batch_size = len(s_label)

        input_img = torch.FloatTensor(batch_size, 3, IMAGE_SIZE, IMAGE_SIZE)
        class_label = torch.LongTensor(batch_size)
        domain_label = torch.LongTensor(batch_size)

        if cuda:
            s_img = s_img.cuda()
            s_label = s_label.cuda()
            s_domain_label = s_domain_label.cuda()
            input_img = input_img.cuda()
            class_label = class_label.cuda()
            domain_label = domain_label.cuda()

        input_img.resize_as_(s_img).copy_(s_img)
        class_label.resize_as_(s_label).copy_(s_label)
        domain_label.resize_as_(s_domain_label).copy_(s_domain_label)

        class_output, domain_output = my_net(input_data=input_img, alpha=alpha)
        err_s_label = loss_class(class_output, class_label)
        err_s_domain = loss_domain(domain_output, domain_label)

        # training model using target data
        if i == len(dataloader_target):
            data_target_iter = iter(dataloader_target)
        data_target = data_target_iter.next()
        t_img, _, _, _ = data_target

        batch_size = len(t_img) # TODO: why?

        input_img = torch.FloatTensor(batch_size, 3, IMAGE_SIZE, IMAGE_SIZE)
        domain_label = torch.ones(batch_size) * 3.0
        domain_label = domain_label.long()

        if cuda:
            t_img = t_img.cuda()
            input_img = input_img.cuda()
            domain_label = domain_label.cuda()

        input_img.resize_as_(t_img).copy_(t_img)

        _, domain_output = my_net(input_data=input_img, alpha=alpha)
        err_t_domain = loss_domain(domain_output, domain_label)
        err = err_t_domain + err_s_domain + err_s_label
        err.backward()
        optimizer.step()

        i += 1

        print('epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
            % (epoch, i, len_dataloader, err_s_label.cpu().data.numpy(),
                err_s_domain.cpu().data.numpy(), err_t_domain.cpu().data.numpy()))

    # torch.save(my_net, 'output/model_epoch_{}.pth'.format(epoch))
    test(my_net, epoch)
    my_net.train()

print('done')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Streaming output truncated to the last 5000 lines.
# epoch: 13, [iter: 90 / all 190], err_s_label: 0.222090, err_s_domain: 1.687956, err_t_domain: 0.688674
# epoch: 13, [iter: 91 / all 190], err_s_label: 0.183054, err_s_domain: 1.801024, err_t_domain: 0.692868
# epoch: 13, [iter: 92 / all 190], err_s_label: 0.184935, err_s_domain: 1.736314, err_t_domain: 0.708281
# epoch: 13, [iter: 93 / all 190], err_s_label: 0.353350, err_s_domain: 1.880902, err_t_domain: 0.696476
# epoch: 13, [iter: 94 / all 190], err_s_label: 0.222928, err_s_domain: 1.731478, err_t_domain: 0.694679
# epoch: 13, [iter: 95 / all 190], err_s_label: 0.278316, err_s_domain: 1.758981, err_t_domain: 0.694082
# epoch: 13, [iter: 96 / all 190], err_s_label: 0.288084, err_s_domain: 1.821062, err_t_domain: 0.720254
# epoch: 13, [iter: 97 / all 190], err_s_label: 0.483329, err_s_domain: 1.752183, err_t_domain: 0.683366
# epoch: 13, [iter: 98 / all 190], err_s_label: 0.175482, err_s_domain: 1.789683, err_t_domain: 0.691676
# epoch: 13, [iter: 99 / all 190], err_s_label: 0.493149, err_s_domain: 1.783053, err_t_domain: 0.678816
# epoch: 13, [iter: 100 / all 190], err_s_label: 0.188850, err_s_domain: 1.791288, err_t_domain: 0.673200
# epoch: 13, [iter: 101 / all 190], err_s_label: 0.111772, err_s_domain: 1.767734, err_t_domain: 0.700764
# epoch: 13, [iter: 102 / all 190], err_s_label: 0.134684, err_s_domain: 1.789058, err_t_domain: 0.701599
# epoch: 13, [iter: 103 / all 190], err_s_label: 0.209162, err_s_domain: 1.712917, err_t_domain: 0.703642
# epoch: 13, [iter: 104 / all 190], err_s_label: 0.127786, err_s_domain: 1.711999, err_t_domain: 0.713751
# epoch: 13, [iter: 105 / all 190], err_s_label: 0.326795, err_s_domain: 1.751583, err_t_domain: 0.701321
# epoch: 13, [iter: 106 / all 190], err_s_label: 0.090477, err_s_domain: 1.847612, err_t_domain: 0.687431
# epoch: 13, [iter: 107 / all 190], err_s_label: 0.146205, err_s_domain: 1.800872, err_t_domain: 0.712317
# epoch: 13, [iter: 108 / all 190], err_s_label: 0.243261, err_s_domain: 1.775209, err_t_domain: 0.714926
# epoch: 13, [iter: 109 / all 190], err_s_label: 0.373387, err_s_domain: 1.738816, err_t_domain: 0.729549
# epoch: 13, [iter: 110 / all 190], err_s_label: 0.272299, err_s_domain: 1.730631, err_t_domain: 0.696922
# epoch: 13, [iter: 111 / all 190], err_s_label: 0.104596, err_s_domain: 1.715382, err_t_domain: 0.723453
# epoch: 13, [iter: 112 / all 190], err_s_label: 0.214427, err_s_domain: 1.732833, err_t_domain: 0.723219
# epoch: 13, [iter: 113 / all 190], err_s_label: 0.089397, err_s_domain: 1.654321, err_t_domain: 0.747433
# epoch: 13, [iter: 114 / all 190], err_s_label: 0.059116, err_s_domain: 1.724375, err_t_domain: 0.702381
# epoch: 13, [iter: 115 / all 190], err_s_label: 0.448793, err_s_domain: 1.790485, err_t_domain: 0.718392
# epoch: 13, [iter: 116 / all 190], err_s_label: 0.119674, err_s_domain: 1.778220, err_t_domain: 0.677525
# epoch: 13, [iter: 117 / all 190], err_s_label: 0.043906, err_s_domain: 1.749721, err_t_domain: 0.697546
# epoch: 13, [iter: 118 / all 190], err_s_label: 0.365236, err_s_domain: 1.841466, err_t_domain: 0.682095
# epoch: 13, [iter: 119 / all 190], err_s_label: 0.267049, err_s_domain: 1.830504, err_t_domain: 0.696488
# epoch: 13, [iter: 120 / all 190], err_s_label: 0.110756, err_s_domain: 1.778834, err_t_domain: 0.692514
# epoch: 13, [iter: 121 / all 190], err_s_label: 0.380098, err_s_domain: 1.863896, err_t_domain: 0.695809
# epoch: 13, [iter: 122 / all 190], err_s_label: 0.151499, err_s_domain: 1.792084, err_t_domain: 0.703283
# epoch: 13, [iter: 123 / all 190], err_s_label: 0.190291, err_s_domain: 1.803968, err_t_domain: 0.700414
# epoch: 13, [iter: 124 / all 190], err_s_label: 0.197752, err_s_domain: 1.821826, err_t_domain: 0.699975
# epoch: 13, [iter: 125 / all 190], err_s_label: 0.184942, err_s_domain: 1.719764, err_t_domain: 0.672120
# epoch: 13, [iter: 126 / all 190], err_s_label: 0.298559, err_s_domain: 1.810787, err_t_domain: 0.689639
# epoch: 13, [iter: 127 / all 190], err_s_label: 0.441770, err_s_domain: 1.734198, err_t_domain: 0.675496
# epoch: 13, [iter: 128 / all 190], err_s_label: 0.368170, err_s_domain: 1.852112, err_t_domain: 0.701154
# epoch: 13, [iter: 129 / all 190], err_s_label: 0.533203, err_s_domain: 1.863924, err_t_domain: 0.708028
# epoch: 13, [iter: 130 / all 190], err_s_label: 0.071717, err_s_domain: 1.758117, err_t_domain: 0.690246
# epoch: 13, [iter: 131 / all 190], err_s_label: 0.234514, err_s_domain: 1.853449, err_t_domain: 0.657018
# epoch: 13, [iter: 132 / all 190], err_s_label: 0.375761, err_s_domain: 1.828789, err_t_domain: 0.661476
# epoch: 13, [iter: 133 / all 190], err_s_label: 0.194886, err_s_domain: 1.802750, err_t_domain: 0.677063
# epoch: 13, [iter: 134 / all 190], err_s_label: 0.237894, err_s_domain: 1.722036, err_t_domain: 0.669189
# epoch: 13, [iter: 135 / all 190], err_s_label: 0.171071, err_s_domain: 1.788312, err_t_domain: 0.671613
# epoch: 13, [iter: 136 / all 190], err_s_label: 0.321419, err_s_domain: 1.739166, err_t_domain: 0.712275
# epoch: 13, [iter: 137 / all 190], err_s_label: 0.103386, err_s_domain: 1.809585, err_t_domain: 0.699987
# epoch: 13, [iter: 138 / all 190], err_s_label: 0.156311, err_s_domain: 1.814347, err_t_domain: 0.709796
# epoch: 13, [iter: 139 / all 190], err_s_label: 0.150355, err_s_domain: 1.796580, err_t_domain: 0.706337
# epoch: 13, [iter: 140 / all 190], err_s_label: 0.392626, err_s_domain: 1.893310, err_t_domain: 0.715814
# epoch: 13, [iter: 141 / all 190], err_s_label: 0.354208, err_s_domain: 1.780306, err_t_domain: 0.716800
# epoch: 13, [iter: 142 / all 190], err_s_label: 0.229393, err_s_domain: 1.759274, err_t_domain: 0.708066
# epoch: 13, [iter: 143 / all 190], err_s_label: 0.094467, err_s_domain: 1.730300, err_t_domain: 0.703932
# epoch: 13, [iter: 144 / all 190], err_s_label: 0.288581, err_s_domain: 1.881884, err_t_domain: 0.716415
# epoch: 13, [iter: 145 / all 190], err_s_label: 0.196969, err_s_domain: 1.806530, err_t_domain: 0.712111
# epoch: 13, [iter: 146 / all 190], err_s_label: 0.183451, err_s_domain: 1.881270, err_t_domain: 0.666524
# epoch: 13, [iter: 147 / all 190], err_s_label: 0.202716, err_s_domain: 1.808466, err_t_domain: 0.675263
# epoch: 13, [iter: 148 / all 190], err_s_label: 0.322987, err_s_domain: 1.852654, err_t_domain: 0.715615
# epoch: 13, [iter: 149 / all 190], err_s_label: 0.186601, err_s_domain: 1.767279, err_t_domain: 0.686423
# epoch: 13, [iter: 150 / all 190], err_s_label: 0.139327, err_s_domain: 1.802158, err_t_domain: 0.679912
# epoch: 13, [iter: 151 / all 190], err_s_label: 0.344034, err_s_domain: 1.739568, err_t_domain: 0.688742
# epoch: 13, [iter: 152 / all 190], err_s_label: 0.129488, err_s_domain: 1.739287, err_t_domain: 0.715305
# epoch: 13, [iter: 153 / all 190], err_s_label: 0.169925, err_s_domain: 1.831288, err_t_domain: 0.666597
# epoch: 13, [iter: 154 / all 190], err_s_label: 0.469755, err_s_domain: 1.763003, err_t_domain: 0.697822
# epoch: 13, [iter: 155 / all 190], err_s_label: 0.237680, err_s_domain: 1.835011, err_t_domain: 0.698864
# epoch: 13, [iter: 156 / all 190], err_s_label: 0.187803, err_s_domain: 1.774514, err_t_domain: 0.683559
# epoch: 13, [iter: 157 / all 190], err_s_label: 0.242932, err_s_domain: 1.853590, err_t_domain: 0.700929
# epoch: 13, [iter: 158 / all 190], err_s_label: 0.237274, err_s_domain: 1.768650, err_t_domain: 0.718841
# epoch: 13, [iter: 159 / all 190], err_s_label: 0.443569, err_s_domain: 1.885361, err_t_domain: 0.696634
# epoch: 13, [iter: 160 / all 190], err_s_label: 0.868043, err_s_domain: 1.760559, err_t_domain: 0.719991
# epoch: 13, [iter: 161 / all 190], err_s_label: 0.251553, err_s_domain: 1.748372, err_t_domain: 0.709588
# epoch: 13, [iter: 162 / all 190], err_s_label: 0.187663, err_s_domain: 1.673327, err_t_domain: 0.736703
# epoch: 13, [iter: 163 / all 190], err_s_label: 0.287576, err_s_domain: 1.806002, err_t_domain: 0.710812
# epoch: 13, [iter: 164 / all 190], err_s_label: 0.202711, err_s_domain: 1.809224, err_t_domain: 0.699131
# epoch: 13, [iter: 165 / all 190], err_s_label: 0.170856, err_s_domain: 1.769997, err_t_domain: 0.732810
# epoch: 13, [iter: 166 / all 190], err_s_label: 0.323369, err_s_domain: 1.730005, err_t_domain: 0.723149
# epoch: 13, [iter: 167 / all 190], err_s_label: 0.323593, err_s_domain: 1.775378, err_t_domain: 0.714613
# epoch: 13, [iter: 168 / all 190], err_s_label: 0.256624, err_s_domain: 1.735453, err_t_domain: 0.704301
# epoch: 13, [iter: 169 / all 190], err_s_label: 0.191066, err_s_domain: 1.775540, err_t_domain: 0.697821
# epoch: 13, [iter: 170 / all 190], err_s_label: 0.087754, err_s_domain: 1.704887, err_t_domain: 0.710003
# epoch: 13, [iter: 171 / all 190], err_s_label: 0.239927, err_s_domain: 1.770388, err_t_domain: 0.707897
# epoch: 13, [iter: 172 / all 190], err_s_label: 0.107723, err_s_domain: 1.657980, err_t_domain: 0.715788
# epoch: 13, [iter: 173 / all 190], err_s_label: 0.443846, err_s_domain: 1.744399, err_t_domain: 0.714372
# epoch: 13, [iter: 174 / all 190], err_s_label: 0.146119, err_s_domain: 1.711497, err_t_domain: 0.721097
# epoch: 13, [iter: 175 / all 190], err_s_label: 0.433848, err_s_domain: 1.680195, err_t_domain: 0.693731
# epoch: 13, [iter: 176 / all 190], err_s_label: 0.313322, err_s_domain: 1.746010, err_t_domain: 0.707246
# epoch: 13, [iter: 177 / all 190], err_s_label: 0.243683, err_s_domain: 1.725732, err_t_domain: 0.706407
# epoch: 13, [iter: 178 / all 190], err_s_label: 0.230426, err_s_domain: 1.766821, err_t_domain: 0.687721
# epoch: 13, [iter: 179 / all 190], err_s_label: 0.507250, err_s_domain: 1.828713, err_t_domain: 0.711981
# epoch: 13, [iter: 180 / all 190], err_s_label: 0.185111, err_s_domain: 1.861604, err_t_domain: 0.704283
# epoch: 13, [iter: 181 / all 190], err_s_label: 0.141313, err_s_domain: 1.718251, err_t_domain: 0.700121
# epoch: 13, [iter: 182 / all 190], err_s_label: 0.287956, err_s_domain: 1.811365, err_t_domain: 0.696525
# epoch: 13, [iter: 183 / all 190], err_s_label: 0.079148, err_s_domain: 1.896494, err_t_domain: 0.674540
# epoch: 13, [iter: 184 / all 190], err_s_label: 0.088250, err_s_domain: 1.857944, err_t_domain: 0.690069
# epoch: 13, [iter: 185 / all 190], err_s_label: 0.174496, err_s_domain: 1.733117, err_t_domain: 0.692680
# epoch: 13, [iter: 186 / all 190], err_s_label: 0.398136, err_s_domain: 1.862618, err_t_domain: 0.678582
# epoch: 13, [iter: 187 / all 190], err_s_label: 0.296139, err_s_domain: 1.891646, err_t_domain: 0.709844
# epoch: 13, [iter: 188 / all 190], err_s_label: 0.251822, err_s_domain: 1.813141, err_t_domain: 0.702960
# epoch: 13, [iter: 189 / all 190], err_s_label: 0.346108, err_s_domain: 1.750555, err_t_domain: 0.704102
# epoch: 13, [iter: 190 / all 190], err_s_label: 0.199603, err_s_domain: 1.732368, err_t_domain: 0.700324
# epoch: 13, accuracy of the train dataset: 0.842461
# epoch: 13, accuracy of the test dataset: 0.570883
# epoch: 14, [iter: 1 / all 190], err_s_label: 0.191531, err_s_domain: 1.745937, err_t_domain: 0.716787
# epoch: 14, [iter: 2 / all 190], err_s_label: 0.061327, err_s_domain: 1.851896, err_t_domain: 0.722584
# epoch: 14, [iter: 3 / all 190], err_s_label: 0.174226, err_s_domain: 1.805533, err_t_domain: 0.718922
# epoch: 14, [iter: 4 / all 190], err_s_label: 0.099376, err_s_domain: 1.801164, err_t_domain: 0.716644
# epoch: 14, [iter: 5 / all 190], err_s_label: 0.157816, err_s_domain: 1.783484, err_t_domain: 0.695836
# epoch: 14, [iter: 6 / all 190], err_s_label: 0.070541, err_s_domain: 1.728629, err_t_domain: 0.705658
# epoch: 14, [iter: 7 / all 190], err_s_label: 0.098536, err_s_domain: 1.780498, err_t_domain: 0.695254
# epoch: 14, [iter: 8 / all 190], err_s_label: 0.129074, err_s_domain: 1.765648, err_t_domain: 0.687995
# epoch: 14, [iter: 9 / all 190], err_s_label: 0.113228, err_s_domain: 1.790172, err_t_domain: 0.710295
# epoch: 14, [iter: 10 / all 190], err_s_label: 0.092428, err_s_domain: 1.811582, err_t_domain: 0.688225
# epoch: 14, [iter: 11 / all 190], err_s_label: 0.079052, err_s_domain: 1.729993, err_t_domain: 0.714998
# epoch: 14, [iter: 12 / all 190], err_s_label: 0.244776, err_s_domain: 1.721571, err_t_domain: 0.700294
# epoch: 14, [iter: 13 / all 190], err_s_label: 0.238501, err_s_domain: 1.840908, err_t_domain: 0.703827
# epoch: 14, [iter: 14 / all 190], err_s_label: 0.229585, err_s_domain: 1.759732, err_t_domain: 0.697399
# epoch: 14, [iter: 15 / all 190], err_s_label: 0.266928, err_s_domain: 1.872547, err_t_domain: 0.719412
# epoch: 14, [iter: 16 / all 190], err_s_label: 0.273338, err_s_domain: 1.791324, err_t_domain: 0.711606
# epoch: 14, [iter: 17 / all 190], err_s_label: 0.442317, err_s_domain: 1.755251, err_t_domain: 0.675752
# epoch: 14, [iter: 18 / all 190], err_s_label: 0.121389, err_s_domain: 1.811446, err_t_domain: 0.705524
# epoch: 14, [iter: 19 / all 190], err_s_label: 0.323993, err_s_domain: 1.704479, err_t_domain: 0.705496
# epoch: 14, [iter: 20 / all 190], err_s_label: 0.082060, err_s_domain: 1.716376, err_t_domain: 0.691243
# epoch: 14, [iter: 21 / all 190], err_s_label: 0.427671, err_s_domain: 1.799387, err_t_domain: 0.694941
# epoch: 14, [iter: 22 / all 190], err_s_label: 0.099019, err_s_domain: 1.740540, err_t_domain: 0.722510
# epoch: 14, [iter: 23 / all 190], err_s_label: 0.189270, err_s_domain: 1.743717, err_t_domain: 0.700076
# epoch: 14, [iter: 24 / all 190], err_s_label: 0.044734, err_s_domain: 1.751963, err_t_domain: 0.702398
# epoch: 14, [iter: 25 / all 190], err_s_label: 0.152009, err_s_domain: 1.732602, err_t_domain: 0.692454
# epoch: 14, [iter: 26 / all 190], err_s_label: 0.160021, err_s_domain: 1.748240, err_t_domain: 0.720065
# epoch: 14, [iter: 27 / all 190], err_s_label: 0.173999, err_s_domain: 1.806139, err_t_domain: 0.707228
# epoch: 14, [iter: 28 / all 190], err_s_label: 0.422267, err_s_domain: 1.743880, err_t_domain: 0.709548
# epoch: 14, [iter: 29 / all 190], err_s_label: 0.081764, err_s_domain: 1.677449, err_t_domain: 0.697587
# epoch: 14, [iter: 30 / all 190], err_s_label: 0.126956, err_s_domain: 1.733848, err_t_domain: 0.692748
# epoch: 14, [iter: 31 / all 190], err_s_label: 0.103612, err_s_domain: 1.750003, err_t_domain: 0.682527
# epoch: 14, [iter: 32 / all 190], err_s_label: 0.133206, err_s_domain: 1.772483, err_t_domain: 0.714031
# epoch: 14, [iter: 33 / all 190], err_s_label: 0.025718, err_s_domain: 1.725383, err_t_domain: 0.688179
# epoch: 14, [iter: 34 / all 190], err_s_label: 0.116811, err_s_domain: 1.771608, err_t_domain: 0.692429
# epoch: 14, [iter: 35 / all 190], err_s_label: 0.179688, err_s_domain: 1.730356, err_t_domain: 0.705296
# epoch: 14, [iter: 36 / all 190], err_s_label: 0.352134, err_s_domain: 1.807225, err_t_domain: 0.700622
# epoch: 14, [iter: 37 / all 190], err_s_label: 0.411222, err_s_domain: 1.706584, err_t_domain: 0.707492
# epoch: 14, [iter: 38 / all 190], err_s_label: 0.083844, err_s_domain: 1.731632, err_t_domain: 0.704237
# epoch: 14, [iter: 39 / all 190], err_s_label: 0.181039, err_s_domain: 1.738318, err_t_domain: 0.717993
# epoch: 14, [iter: 40 / all 190], err_s_label: 0.140855, err_s_domain: 1.722389, err_t_domain: 0.714706
# epoch: 14, [iter: 41 / all 190], err_s_label: 0.190395, err_s_domain: 1.804065, err_t_domain: 0.711187
# epoch: 14, [iter: 42 / all 190], err_s_label: 0.184200, err_s_domain: 1.719611, err_t_domain: 0.686677
# epoch: 14, [iter: 43 / all 190], err_s_label: 0.092513, err_s_domain: 1.772123, err_t_domain: 0.700806
# epoch: 14, [iter: 44 / all 190], err_s_label: 0.240613, err_s_domain: 1.784909, err_t_domain: 0.693354
# epoch: 14, [iter: 45 / all 190], err_s_label: 0.102392, err_s_domain: 1.615222, err_t_domain: 0.691191
# epoch: 14, [iter: 46 / all 190], err_s_label: 0.247202, err_s_domain: 1.753084, err_t_domain: 0.687067
# epoch: 14, [iter: 47 / all 190], err_s_label: 0.201439, err_s_domain: 1.726401, err_t_domain: 0.690368
# epoch: 14, [iter: 48 / all 190], err_s_label: 0.158437, err_s_domain: 1.749198, err_t_domain: 0.688183
# epoch: 14, [iter: 49 / all 190], err_s_label: 0.269573, err_s_domain: 1.811498, err_t_domain: 0.687307
# epoch: 14, [iter: 50 / all 190], err_s_label: 0.096825, err_s_domain: 1.835001, err_t_domain: 0.696787
# epoch: 14, [iter: 51 / all 190], err_s_label: 0.122479, err_s_domain: 1.809922, err_t_domain: 0.666311
# epoch: 14, [iter: 52 / all 190], err_s_label: 0.282502, err_s_domain: 1.729398, err_t_domain: 0.681852
# epoch: 14, [iter: 53 / all 190], err_s_label: 0.031090, err_s_domain: 1.733092, err_t_domain: 0.683486
# epoch: 14, [iter: 54 / all 190], err_s_label: 0.317708, err_s_domain: 1.805456, err_t_domain: 0.683258
# epoch: 14, [iter: 55 / all 190], err_s_label: 0.125957, err_s_domain: 1.798723, err_t_domain: 0.656295
# epoch: 14, [iter: 56 / all 190], err_s_label: 0.394611, err_s_domain: 1.815171, err_t_domain: 0.678509
# epoch: 14, [iter: 57 / all 190], err_s_label: 0.366638, err_s_domain: 1.770607, err_t_domain: 0.674836
# epoch: 14, [iter: 58 / all 190], err_s_label: 0.148446, err_s_domain: 1.850418, err_t_domain: 0.669468
# epoch: 14, [iter: 59 / all 190], err_s_label: 0.133021, err_s_domain: 1.796609, err_t_domain: 0.686317
# epoch: 14, [iter: 60 / all 190], err_s_label: 0.090828, err_s_domain: 1.744172, err_t_domain: 0.693816
# epoch: 14, [iter: 61 / all 190], err_s_label: 0.274729, err_s_domain: 1.888102, err_t_domain: 0.683317
# epoch: 14, [iter: 62 / all 190], err_s_label: 0.103815, err_s_domain: 1.776620, err_t_domain: 0.691659
# epoch: 14, [iter: 63 / all 190], err_s_label: 0.167983, err_s_domain: 1.807492, err_t_domain: 0.687858
# epoch: 14, [iter: 64 / all 190], err_s_label: 0.416719, err_s_domain: 1.743917, err_t_domain: 0.667952
# epoch: 14, [iter: 65 / all 190], err_s_label: 0.263138, err_s_domain: 1.842998, err_t_domain: 0.679849
# epoch: 14, [iter: 66 / all 190], err_s_label: 0.074815, err_s_domain: 1.778729, err_t_domain: 0.689156
# epoch: 14, [iter: 67 / all 190], err_s_label: 0.195629, err_s_domain: 1.816622, err_t_domain: 0.681374
# epoch: 14, [iter: 68 / all 190], err_s_label: 0.081108, err_s_domain: 1.892275, err_t_domain: 0.676072
# epoch: 14, [iter: 69 / all 190], err_s_label: 0.065970, err_s_domain: 1.864379, err_t_domain: 0.680974
# epoch: 14, [iter: 70 / all 190], err_s_label: 0.216285, err_s_domain: 1.802015, err_t_domain: 0.683063
# epoch: 14, [iter: 71 / all 190], err_s_label: 0.116549, err_s_domain: 1.802341, err_t_domain: 0.675053
# epoch: 14, [iter: 72 / all 190], err_s_label: 0.109135, err_s_domain: 1.874241, err_t_domain: 0.680791
# epoch: 14, [iter: 73 / all 190], err_s_label: 0.172490, err_s_domain: 1.785487, err_t_domain: 0.667658
# epoch: 14, [iter: 74 / all 190], err_s_label: 0.383248, err_s_domain: 1.808038, err_t_domain: 0.670075
# epoch: 14, [iter: 75 / all 190], err_s_label: 0.102106, err_s_domain: 1.771195, err_t_domain: 0.661537
# epoch: 14, [iter: 76 / all 190], err_s_label: 0.277908, err_s_domain: 1.743477, err_t_domain: 0.670499
# epoch: 14, [iter: 77 / all 190], err_s_label: 0.522096, err_s_domain: 1.789268, err_t_domain: 0.677767
# epoch: 14, [iter: 78 / all 190], err_s_label: 0.172652, err_s_domain: 1.799933, err_t_domain: 0.674818
# epoch: 14, [iter: 79 / all 190], err_s_label: 0.448795, err_s_domain: 1.783047, err_t_domain: 0.689766
# epoch: 14, [iter: 80 / all 190], err_s_label: 0.165230, err_s_domain: 1.865839, err_t_domain: 0.654995
# epoch: 14, [iter: 81 / all 190], err_s_label: 0.073834, err_s_domain: 1.745777, err_t_domain: 0.683149
# epoch: 14, [iter: 82 / all 190], err_s_label: 0.146455, err_s_domain: 1.774780, err_t_domain: 0.679495
# epoch: 14, [iter: 83 / all 190], err_s_label: 0.197575, err_s_domain: 1.795109, err_t_domain: 0.664290
# epoch: 14, [iter: 84 / all 190], err_s_label: 0.047872, err_s_domain: 1.791255, err_t_domain: 0.669754
# epoch: 14, [iter: 85 / all 190], err_s_label: 0.163069, err_s_domain: 1.793983, err_t_domain: 0.662923
# epoch: 14, [iter: 86 / all 190], err_s_label: 0.136473, err_s_domain: 1.776753, err_t_domain: 0.685193
# epoch: 14, [iter: 87 / all 190], err_s_label: 0.030857, err_s_domain: 1.715941, err_t_domain: 0.673405
# epoch: 14, [iter: 88 / all 190], err_s_label: 0.281333, err_s_domain: 1.747995, err_t_domain: 0.681039
# epoch: 14, [iter: 89 / all 190], err_s_label: 0.159040, err_s_domain: 1.754850, err_t_domain: 0.683055
# epoch: 14, [iter: 90 / all 190], err_s_label: 0.227217, err_s_domain: 1.710245, err_t_domain: 0.683203
# epoch: 14, [iter: 91 / all 190], err_s_label: 0.103693, err_s_domain: 1.747651, err_t_domain: 0.671421
# epoch: 14, [iter: 92 / all 190], err_s_label: 0.184120, err_s_domain: 1.710871, err_t_domain: 0.680539
# epoch: 14, [iter: 93 / all 190], err_s_label: 0.335011, err_s_domain: 1.739464, err_t_domain: 0.673566
# epoch: 14, [iter: 94 / all 190], err_s_label: 0.247678, err_s_domain: 1.664738, err_t_domain: 0.667197
# epoch: 14, [iter: 95 / all 190], err_s_label: 0.198913, err_s_domain: 1.697738, err_t_domain: 0.676225
# epoch: 14, [iter: 96 / all 190], err_s_label: 0.375284, err_s_domain: 1.762422, err_t_domain: 0.694468
# epoch: 14, [iter: 97 / all 190], err_s_label: 0.058689, err_s_domain: 1.635403, err_t_domain: 0.716264
# epoch: 14, [iter: 98 / all 190], err_s_label: 0.201709, err_s_domain: 1.697163, err_t_domain: 0.688068
# epoch: 14, [iter: 99 / all 190], err_s_label: 0.057431, err_s_domain: 1.695805, err_t_domain: 0.695510
# epoch: 14, [iter: 100 / all 190], err_s_label: 0.127568, err_s_domain: 1.811095, err_t_domain: 0.694681
# epoch: 14, [iter: 101 / all 190], err_s_label: 0.206667, err_s_domain: 1.811008, err_t_domain: 0.706474
# epoch: 14, [iter: 102 / all 190], err_s_label: 0.143490, err_s_domain: 1.818987, err_t_domain: 0.679959
# epoch: 14, [iter: 103 / all 190], err_s_label: 0.075200, err_s_domain: 1.866533, err_t_domain: 0.702739
# epoch: 14, [iter: 104 / all 190], err_s_label: 0.065670, err_s_domain: 1.748406, err_t_domain: 0.714932
# epoch: 14, [iter: 105 / all 190], err_s_label: 0.118338, err_s_domain: 1.823779, err_t_domain: 0.682109
# epoch: 14, [iter: 106 / all 190], err_s_label: 0.166145, err_s_domain: 1.784186, err_t_domain: 0.687111
# epoch: 14, [iter: 107 / all 190], err_s_label: 0.165604, err_s_domain: 1.868834, err_t_domain: 0.679591
# epoch: 14, [iter: 108 / all 190], err_s_label: 0.510580, err_s_domain: 1.789262, err_t_domain: 0.687206
# epoch: 14, [iter: 109 / all 190], err_s_label: 0.109058, err_s_domain: 1.828882, err_t_domain: 0.687003
# epoch: 14, [iter: 110 / all 190], err_s_label: 0.098319, err_s_domain: 1.783457, err_t_domain: 0.671266
# epoch: 14, [iter: 111 / all 190], err_s_label: 0.160164, err_s_domain: 1.731433, err_t_domain: 0.679937
# epoch: 14, [iter: 112 / all 190], err_s_label: 0.211043, err_s_domain: 1.739565, err_t_domain: 0.712214
# epoch: 14, [iter: 113 / all 190], err_s_label: 0.137056, err_s_domain: 1.827622, err_t_domain: 0.698948
# epoch: 14, [iter: 114 / all 190], err_s_label: 0.170133, err_s_domain: 1.793114, err_t_domain: 0.707866
# epoch: 14, [iter: 115 / all 190], err_s_label: 0.189919, err_s_domain: 1.844850, err_t_domain: 0.693200
# epoch: 14, [iter: 116 / all 190], err_s_label: 0.161162, err_s_domain: 1.847811, err_t_domain: 0.703301
# epoch: 14, [iter: 117 / all 190], err_s_label: 0.157392, err_s_domain: 1.826141, err_t_domain: 0.681251
# epoch: 14, [iter: 118 / all 190], err_s_label: 0.103871, err_s_domain: 1.842067, err_t_domain: 0.667161
# epoch: 14, [iter: 119 / all 190], err_s_label: 0.097977, err_s_domain: 1.773296, err_t_domain: 0.694786
# epoch: 14, [iter: 120 / all 190], err_s_label: 0.092924, err_s_domain: 1.830714, err_t_domain: 0.683711
# epoch: 14, [iter: 121 / all 190], err_s_label: 0.083753, err_s_domain: 1.840206, err_t_domain: 0.696180
# epoch: 14, [iter: 122 / all 190], err_s_label: 0.266783, err_s_domain: 1.739728, err_t_domain: 0.687777
# epoch: 14, [iter: 123 / all 190], err_s_label: 0.187130, err_s_domain: 1.805162, err_t_domain: 0.683017
# epoch: 14, [iter: 124 / all 190], err_s_label: 0.304891, err_s_domain: 1.765443, err_t_domain: 0.696367
# epoch: 14, [iter: 125 / all 190], err_s_label: 0.125341, err_s_domain: 1.826956, err_t_domain: 0.736409
# epoch: 14, [iter: 126 / all 190], err_s_label: 0.166516, err_s_domain: 1.828488, err_t_domain: 0.713238
# epoch: 14, [iter: 127 / all 190], err_s_label: 0.293030, err_s_domain: 1.795273, err_t_domain: 0.719737
# epoch: 14, [iter: 128 / all 190], err_s_label: 0.313919, err_s_domain: 1.782094, err_t_domain: 0.713309
# epoch: 14, [iter: 129 / all 190], err_s_label: 0.305977, err_s_domain: 1.825891, err_t_domain: 0.714852
# epoch: 14, [iter: 130 / all 190], err_s_label: 0.233572, err_s_domain: 1.765711, err_t_domain: 0.706865
# epoch: 14, [iter: 131 / all 190], err_s_label: 0.048750, err_s_domain: 1.816303, err_t_domain: 0.717210
# epoch: 14, [iter: 132 / all 190], err_s_label: 0.227521, err_s_domain: 1.793600, err_t_domain: 0.709048
# epoch: 14, [iter: 133 / all 190], err_s_label: 0.117046, err_s_domain: 1.806123, err_t_domain: 0.703167
# epoch: 14, [iter: 134 / all 190], err_s_label: 0.230979, err_s_domain: 1.825945, err_t_domain: 0.697380
# epoch: 14, [iter: 135 / all 190], err_s_label: 0.125016, err_s_domain: 1.849962, err_t_domain: 0.671314
# epoch: 14, [iter: 136 / all 190], err_s_label: 0.270005, err_s_domain: 1.780161, err_t_domain: 0.680730
# epoch: 14, [iter: 137 / all 190], err_s_label: 0.046990, err_s_domain: 1.793964, err_t_domain: 0.688168
# epoch: 14, [iter: 138 / all 190], err_s_label: 0.164984, err_s_domain: 1.805102, err_t_domain: 0.665942
# epoch: 14, [iter: 139 / all 190], err_s_label: 0.121605, err_s_domain: 1.818552, err_t_domain: 0.683703
# epoch: 14, [iter: 140 / all 190], err_s_label: 0.167210, err_s_domain: 1.853237, err_t_domain: 0.679826
# epoch: 14, [iter: 141 / all 190], err_s_label: 0.415938, err_s_domain: 1.810203, err_t_domain: 0.701070
# epoch: 14, [iter: 142 / all 190], err_s_label: 0.089182, err_s_domain: 1.745788, err_t_domain: 0.674319
# epoch: 14, [iter: 143 / all 190], err_s_label: 0.235629, err_s_domain: 1.767166, err_t_domain: 0.691035
# epoch: 14, [iter: 144 / all 190], err_s_label: 0.578340, err_s_domain: 1.833677, err_t_domain: 0.697577
# epoch: 14, [iter: 145 / all 190], err_s_label: 0.178199, err_s_domain: 1.709849, err_t_domain: 0.667848
# epoch: 14, [iter: 146 / all 190], err_s_label: 0.033546, err_s_domain: 1.758578, err_t_domain: 0.667705
# epoch: 14, [iter: 147 / all 190], err_s_label: 0.056983, err_s_domain: 1.759745, err_t_domain: 0.685092
# epoch: 14, [iter: 148 / all 190], err_s_label: 0.067175, err_s_domain: 1.778807, err_t_domain: 0.687289
# epoch: 14, [iter: 149 / all 190], err_s_label: 0.406965, err_s_domain: 1.755965, err_t_domain: 0.696980
# epoch: 14, [iter: 150 / all 190], err_s_label: 0.071291, err_s_domain: 1.838698, err_t_domain: 0.706940
# epoch: 14, [iter: 151 / all 190], err_s_label: 0.144814, err_s_domain: 1.811363, err_t_domain: 0.706824
# epoch: 14, [iter: 152 / all 190], err_s_label: 0.281000, err_s_domain: 1.823406, err_t_domain: 0.712792
# epoch: 14, [iter: 153 / all 190], err_s_label: 0.247233, err_s_domain: 1.791485, err_t_domain: 0.677786
# epoch: 14, [iter: 154 / all 190], err_s_label: 0.093639, err_s_domain: 1.717009, err_t_domain: 0.706493
# epoch: 14, [iter: 155 / all 190], err_s_label: 0.233534, err_s_domain: 1.767435, err_t_domain: 0.694887
# epoch: 14, [iter: 156 / all 190], err_s_label: 0.344578, err_s_domain: 1.824944, err_t_domain: 0.702695
# epoch: 14, [iter: 157 / all 190], err_s_label: 0.240931, err_s_domain: 1.775864, err_t_domain: 0.712129
# epoch: 14, [iter: 158 / all 190], err_s_label: 0.185317, err_s_domain: 1.775366, err_t_domain: 0.696725
# epoch: 14, [iter: 159 / all 190], err_s_label: 0.162698, err_s_domain: 1.771791, err_t_domain: 0.702286
# epoch: 14, [iter: 160 / all 190], err_s_label: 0.172039, err_s_domain: 1.758845, err_t_domain: 0.707345
# epoch: 14, [iter: 161 / all 190], err_s_label: 0.095998, err_s_domain: 1.744260, err_t_domain: 0.701910
# epoch: 14, [iter: 162 / all 190], err_s_label: 0.060556, err_s_domain: 1.711260, err_t_domain: 0.703979
# epoch: 14, [iter: 163 / all 190], err_s_label: 0.020377, err_s_domain: 1.728521, err_t_domain: 0.685854
# epoch: 14, [iter: 164 / all 190], err_s_label: 0.030887, err_s_domain: 1.810142, err_t_domain: 0.688244
# epoch: 14, [iter: 165 / all 190], err_s_label: 0.293403, err_s_domain: 1.742487, err_t_domain: 0.711603
# epoch: 14, [iter: 166 / all 190], err_s_label: 0.042364, err_s_domain: 1.840455, err_t_domain: 0.693133
# epoch: 14, [iter: 167 / all 190], err_s_label: 0.293724, err_s_domain: 1.750916, err_t_domain: 0.686652
# epoch: 14, [iter: 168 / all 190], err_s_label: 0.180461, err_s_domain: 1.753873, err_t_domain: 0.707823
# epoch: 14, [iter: 169 / all 190], err_s_label: 0.149531, err_s_domain: 1.814091, err_t_domain: 0.690010
# epoch: 14, [iter: 170 / all 190], err_s_label: 0.042166, err_s_domain: 1.744503, err_t_domain: 0.704448
# epoch: 14, [iter: 171 / all 190], err_s_label: 0.090429, err_s_domain: 1.759784, err_t_domain: 0.707850
# epoch: 14, [iter: 172 / all 190], err_s_label: 0.173807, err_s_domain: 1.849488, err_t_domain: 0.689295
# epoch: 14, [iter: 173 / all 190], err_s_label: 0.036847, err_s_domain: 1.848754, err_t_domain: 0.694492
# epoch: 14, [iter: 174 / all 190], err_s_label: 0.170187, err_s_domain: 1.784685, err_t_domain: 0.694104
# epoch: 14, [iter: 175 / all 190], err_s_label: 0.186031, err_s_domain: 1.858279, err_t_domain: 0.683869
# epoch: 14, [iter: 176 / all 190], err_s_label: 0.167689, err_s_domain: 1.764989, err_t_domain: 0.680696
# epoch: 14, [iter: 177 / all 190], err_s_label: 0.181785, err_s_domain: 1.793638, err_t_domain: 0.685633
# epoch: 14, [iter: 178 / all 190], err_s_label: 0.271479, err_s_domain: 1.747568, err_t_domain: 0.680057
# epoch: 14, [iter: 179 / all 190], err_s_label: 0.223354, err_s_domain: 1.842386, err_t_domain: 0.684325
# epoch: 14, [iter: 180 / all 190], err_s_label: 0.143030, err_s_domain: 1.712877, err_t_domain: 0.697000
# epoch: 14, [iter: 181 / all 190], err_s_label: 0.108155, err_s_domain: 1.732393, err_t_domain: 0.697184
# epoch: 14, [iter: 182 / all 190], err_s_label: 0.065771, err_s_domain: 1.811926, err_t_domain: 0.690557
# epoch: 14, [iter: 183 / all 190], err_s_label: 0.147508, err_s_domain: 1.754427, err_t_domain: 0.697319
# epoch: 14, [iter: 184 / all 190], err_s_label: 0.180138, err_s_domain: 1.731129, err_t_domain: 0.695287
# epoch: 14, [iter: 185 / all 190], err_s_label: 0.123484, err_s_domain: 1.825579, err_t_domain: 0.687273
# epoch: 14, [iter: 186 / all 190], err_s_label: 0.217985, err_s_domain: 1.784273, err_t_domain: 0.693556
# epoch: 14, [iter: 187 / all 190], err_s_label: 0.045333, err_s_domain: 1.774019, err_t_domain: 0.710511
# epoch: 14, [iter: 188 / all 190], err_s_label: 0.158715, err_s_domain: 1.767669, err_t_domain: 0.686275
# epoch: 14, [iter: 189 / all 190], err_s_label: 0.215501, err_s_domain: 1.885222, err_t_domain: 0.678065
# epoch: 14, [iter: 190 / all 190], err_s_label: 0.026570, err_s_domain: 1.823134, err_t_domain: 0.690454
# epoch: 14, accuracy of the train dataset: 0.726163
# epoch: 14, accuracy of the test dataset: 0.557139
# epoch: 15, [iter: 1 / all 190], err_s_label: 0.047037, err_s_domain: 1.774456, err_t_domain: 0.678670
# epoch: 15, [iter: 2 / all 190], err_s_label: 0.041610, err_s_domain: 1.732782, err_t_domain: 0.684392
# epoch: 15, [iter: 3 / all 190], err_s_label: 0.092139, err_s_domain: 1.764845, err_t_domain: 0.703398
# epoch: 15, [iter: 4 / all 190], err_s_label: 0.022630, err_s_domain: 1.751431, err_t_domain: 0.685850
# epoch: 15, [iter: 5 / all 190], err_s_label: 0.079865, err_s_domain: 1.814168, err_t_domain: 0.690825
# epoch: 15, [iter: 6 / all 190], err_s_label: 0.049669, err_s_domain: 1.773654, err_t_domain: 0.697920
# epoch: 15, [iter: 7 / all 190], err_s_label: 0.094501, err_s_domain: 1.814349, err_t_domain: 0.696453
# epoch: 15, [iter: 8 / all 190], err_s_label: 0.282948, err_s_domain: 1.815631, err_t_domain: 0.705042
# epoch: 15, [iter: 9 / all 190], err_s_label: 0.120711, err_s_domain: 1.843246, err_t_domain: 0.703324
# epoch: 15, [iter: 10 / all 190], err_s_label: 0.056099, err_s_domain: 1.824534, err_t_domain: 0.695280
# epoch: 15, [iter: 11 / all 190], err_s_label: 0.112868, err_s_domain: 1.745385, err_t_domain: 0.690613
# epoch: 15, [iter: 12 / all 190], err_s_label: 0.057625, err_s_domain: 1.855367, err_t_domain: 0.698554
# epoch: 15, [iter: 13 / all 190], err_s_label: 0.216129, err_s_domain: 1.753320, err_t_domain: 0.696782
# epoch: 15, [iter: 14 / all 190], err_s_label: 0.077302, err_s_domain: 1.801659, err_t_domain: 0.700475
# epoch: 15, [iter: 15 / all 190], err_s_label: 0.314215, err_s_domain: 1.850026, err_t_domain: 0.703430
# epoch: 15, [iter: 16 / all 190], err_s_label: 0.213906, err_s_domain: 1.802319, err_t_domain: 0.705076
# epoch: 15, [iter: 17 / all 190], err_s_label: 0.141974, err_s_domain: 1.821834, err_t_domain: 0.708023
# epoch: 15, [iter: 18 / all 190], err_s_label: 0.130601, err_s_domain: 1.806759, err_t_domain: 0.696476
# epoch: 15, [iter: 19 / all 190], err_s_label: 0.113572, err_s_domain: 1.766764, err_t_domain: 0.694457
# epoch: 15, [iter: 20 / all 190], err_s_label: 0.149662, err_s_domain: 1.819305, err_t_domain: 0.711934
# epoch: 15, [iter: 21 / all 190], err_s_label: 0.028435, err_s_domain: 1.791139, err_t_domain: 0.713058
# epoch: 15, [iter: 22 / all 190], err_s_label: 0.042261, err_s_domain: 1.748919, err_t_domain: 0.711904
# epoch: 15, [iter: 23 / all 190], err_s_label: 0.050304, err_s_domain: 1.765701, err_t_domain: 0.695290
# epoch: 15, [iter: 24 / all 190], err_s_label: 0.103090, err_s_domain: 1.762239, err_t_domain: 0.688599
# epoch: 15, [iter: 25 / all 190], err_s_label: 0.237497, err_s_domain: 1.807009, err_t_domain: 0.705935
# epoch: 15, [iter: 26 / all 190], err_s_label: 0.161056, err_s_domain: 1.849122, err_t_domain: 0.694724
# epoch: 15, [iter: 27 / all 190], err_s_label: 0.107852, err_s_domain: 1.799455, err_t_domain: 0.705188
# epoch: 15, [iter: 28 / all 190], err_s_label: 0.086249, err_s_domain: 1.801036, err_t_domain: 0.697701
# epoch: 15, [iter: 29 / all 190], err_s_label: 0.140460, err_s_domain: 1.892319, err_t_domain: 0.697681
# epoch: 15, [iter: 30 / all 190], err_s_label: 0.272294, err_s_domain: 1.760210, err_t_domain: 0.689166
# epoch: 15, [iter: 31 / all 190], err_s_label: 0.564474, err_s_domain: 1.869265, err_t_domain: 0.694278
# epoch: 15, [iter: 32 / all 190], err_s_label: 0.059347, err_s_domain: 1.760617, err_t_domain: 0.671828
# epoch: 15, [iter: 33 / all 190], err_s_label: 0.129141, err_s_domain: 1.812039, err_t_domain: 0.692570
# epoch: 15, [iter: 34 / all 190], err_s_label: 0.063485, err_s_domain: 1.782120, err_t_domain: 0.692184
# epoch: 15, [iter: 35 / all 190], err_s_label: 0.069435, err_s_domain: 1.772642, err_t_domain: 0.699114
# epoch: 15, [iter: 36 / all 190], err_s_label: 0.217814, err_s_domain: 1.771962, err_t_domain: 0.689866
# epoch: 15, [iter: 37 / all 190], err_s_label: 0.083556, err_s_domain: 1.730734, err_t_domain: 0.687195
# epoch: 15, [iter: 38 / all 190], err_s_label: 0.056418, err_s_domain: 1.678194, err_t_domain: 0.689610
# epoch: 15, [iter: 39 / all 190], err_s_label: 0.215995, err_s_domain: 1.704783, err_t_domain: 0.701298
# epoch: 15, [iter: 40 / all 190], err_s_label: 0.036754, err_s_domain: 1.800166, err_t_domain: 0.712537
# epoch: 15, [iter: 41 / all 190], err_s_label: 0.199170, err_s_domain: 1.730241, err_t_domain: 0.705574
# epoch: 15, [iter: 42 / all 190], err_s_label: 0.232298, err_s_domain: 1.743076, err_t_domain: 0.738913
# epoch: 15, [iter: 43 / all 190], err_s_label: 0.229273, err_s_domain: 1.753975, err_t_domain: 0.699925
# epoch: 15, [iter: 44 / all 190], err_s_label: 0.135280, err_s_domain: 1.777187, err_t_domain: 0.700039
# epoch: 15, [iter: 45 / all 190], err_s_label: 0.103206, err_s_domain: 1.752005, err_t_domain: 0.714066
# epoch: 15, [iter: 46 / all 190], err_s_label: 0.117268, err_s_domain: 1.759790, err_t_domain: 0.707048
# epoch: 15, [iter: 47 / all 190], err_s_label: 0.232643, err_s_domain: 1.779481, err_t_domain: 0.713523
# epoch: 15, [iter: 48 / all 190], err_s_label: 0.019594, err_s_domain: 1.759412, err_t_domain: 0.711124
# epoch: 15, [iter: 49 / all 190], err_s_label: 0.278209, err_s_domain: 1.760104, err_t_domain: 0.694031
# epoch: 15, [iter: 50 / all 190], err_s_label: 0.052912, err_s_domain: 1.736125, err_t_domain: 0.711245
# epoch: 15, [iter: 51 / all 190], err_s_label: 0.384774, err_s_domain: 1.807761, err_t_domain: 0.702783
# epoch: 15, [iter: 52 / all 190], err_s_label: 0.206027, err_s_domain: 1.785126, err_t_domain: 0.708812
# epoch: 15, [iter: 53 / all 190], err_s_label: 0.224638, err_s_domain: 1.728028, err_t_domain: 0.685560
# epoch: 15, [iter: 54 / all 190], err_s_label: 0.251032, err_s_domain: 1.845965, err_t_domain: 0.695406
# epoch: 15, [iter: 55 / all 190], err_s_label: 0.166637, err_s_domain: 1.824948, err_t_domain: 0.716167
# epoch: 15, [iter: 56 / all 190], err_s_label: 0.146344, err_s_domain: 1.775024, err_t_domain: 0.705648
# epoch: 15, [iter: 57 / all 190], err_s_label: 0.097454, err_s_domain: 1.836041, err_t_domain: 0.694657
# epoch: 15, [iter: 58 / all 190], err_s_label: 0.074572, err_s_domain: 1.796749, err_t_domain: 0.706420
# epoch: 15, [iter: 59 / all 190], err_s_label: 0.215276, err_s_domain: 1.792213, err_t_domain: 0.695530
# epoch: 15, [iter: 60 / all 190], err_s_label: 0.324252, err_s_domain: 1.871404, err_t_domain: 0.713894
# epoch: 15, [iter: 61 / all 190], err_s_label: 0.213774, err_s_domain: 1.858468, err_t_domain: 0.709344
# epoch: 15, [iter: 62 / all 190], err_s_label: 0.078266, err_s_domain: 1.806866, err_t_domain: 0.718887
# epoch: 15, [iter: 63 / all 190], err_s_label: 0.106584, err_s_domain: 1.857450, err_t_domain: 0.699747
# epoch: 15, [iter: 64 / all 190], err_s_label: 0.097375, err_s_domain: 1.752565, err_t_domain: 0.730797
# epoch: 15, [iter: 65 / all 190], err_s_label: 0.040683, err_s_domain: 1.794917, err_t_domain: 0.694962
# epoch: 15, [iter: 66 / all 190], err_s_label: 0.122924, err_s_domain: 1.819445, err_t_domain: 0.696085
# epoch: 15, [iter: 67 / all 190], err_s_label: 0.318923, err_s_domain: 1.746359, err_t_domain: 0.700976
# epoch: 15, [iter: 68 / all 190], err_s_label: 0.137630, err_s_domain: 1.802418, err_t_domain: 0.710187
# epoch: 15, [iter: 69 / all 190], err_s_label: 0.076828, err_s_domain: 1.801746, err_t_domain: 0.687598
# epoch: 15, [iter: 70 / all 190], err_s_label: 0.132944, err_s_domain: 1.751963, err_t_domain: 0.694515
# epoch: 15, [iter: 71 / all 190], err_s_label: 0.072740, err_s_domain: 1.846476, err_t_domain: 0.702442
# epoch: 15, [iter: 72 / all 190], err_s_label: 0.091506, err_s_domain: 1.816891, err_t_domain: 0.706720
# epoch: 15, [iter: 73 / all 190], err_s_label: 0.112275, err_s_domain: 1.762088, err_t_domain: 0.701862
# epoch: 15, [iter: 74 / all 190], err_s_label: 0.030453, err_s_domain: 1.717259, err_t_domain: 0.714125
# epoch: 15, [iter: 75 / all 190], err_s_label: 0.031013, err_s_domain: 1.754508, err_t_domain: 0.695837
# epoch: 15, [iter: 76 / all 190], err_s_label: 0.059467, err_s_domain: 1.733614, err_t_domain: 0.678815
# epoch: 15, [iter: 77 / all 190], err_s_label: 0.229063, err_s_domain: 1.710264, err_t_domain: 0.698204
# epoch: 15, [iter: 78 / all 190], err_s_label: 0.266807, err_s_domain: 1.746185, err_t_domain: 0.696857
# epoch: 15, [iter: 79 / all 190], err_s_label: 0.153145, err_s_domain: 1.781125, err_t_domain: 0.698542
# epoch: 15, [iter: 80 / all 190], err_s_label: 0.140756, err_s_domain: 1.792820, err_t_domain: 0.690337
# epoch: 15, [iter: 81 / all 190], err_s_label: 0.410829, err_s_domain: 1.661333, err_t_domain: 0.699437
# epoch: 15, [iter: 82 / all 190], err_s_label: 0.120476, err_s_domain: 1.749262, err_t_domain: 0.690307
# epoch: 15, [iter: 83 / all 190], err_s_label: 0.285190, err_s_domain: 1.746681, err_t_domain: 0.690009
# epoch: 15, [iter: 84 / all 190], err_s_label: 0.289777, err_s_domain: 1.742723, err_t_domain: 0.717183
# epoch: 15, [iter: 85 / all 190], err_s_label: 0.234591, err_s_domain: 1.790708, err_t_domain: 0.689190
# epoch: 15, [iter: 86 / all 190], err_s_label: 0.055706, err_s_domain: 1.681501, err_t_domain: 0.695102
# epoch: 15, [iter: 87 / all 190], err_s_label: 0.156277, err_s_domain: 1.819601, err_t_domain: 0.702609
# epoch: 15, [iter: 88 / all 190], err_s_label: 0.221768, err_s_domain: 1.837747, err_t_domain: 0.693712
# epoch: 15, [iter: 89 / all 190], err_s_label: 0.153098, err_s_domain: 1.734175, err_t_domain: 0.694716
# epoch: 15, [iter: 90 / all 190], err_s_label: 0.230281, err_s_domain: 1.749969, err_t_domain: 0.688116
# epoch: 15, [iter: 91 / all 190], err_s_label: 0.118290, err_s_domain: 1.761296, err_t_domain: 0.703133
# epoch: 15, [iter: 92 / all 190], err_s_label: 0.016285, err_s_domain: 1.763542, err_t_domain: 0.694958
# epoch: 15, [iter: 93 / all 190], err_s_label: 0.143431, err_s_domain: 1.734125, err_t_domain: 0.674277
# epoch: 15, [iter: 94 / all 190], err_s_label: 0.089344, err_s_domain: 1.815419, err_t_domain: 0.679881
# epoch: 15, [iter: 95 / all 190], err_s_label: 0.034456, err_s_domain: 1.748835, err_t_domain: 0.684664
# epoch: 15, [iter: 96 / all 190], err_s_label: 0.375971, err_s_domain: 1.706068, err_t_domain: 0.698246
# epoch: 15, [iter: 97 / all 190], err_s_label: 0.053797, err_s_domain: 1.745342, err_t_domain: 0.691277
# epoch: 15, [iter: 98 / all 190], err_s_label: 0.060021, err_s_domain: 1.718855, err_t_domain: 0.695512
# epoch: 15, [iter: 99 / all 190], err_s_label: 0.632772, err_s_domain: 1.755771, err_t_domain: 0.699272
# epoch: 15, [iter: 100 / all 190], err_s_label: 0.137209, err_s_domain: 1.715396, err_t_domain: 0.709449
# epoch: 15, [iter: 101 / all 190], err_s_label: 0.187876, err_s_domain: 1.811304, err_t_domain: 0.683541
# epoch: 15, [iter: 102 / all 190], err_s_label: 0.188989, err_s_domain: 1.802857, err_t_domain: 0.698616
# epoch: 15, [iter: 103 / all 190], err_s_label: 0.047312, err_s_domain: 1.855424, err_t_domain: 0.714141
# epoch: 15, [iter: 104 / all 190], err_s_label: 0.099017, err_s_domain: 1.850925, err_t_domain: 0.707390
# epoch: 15, [iter: 105 / all 190], err_s_label: 0.270526, err_s_domain: 1.840918, err_t_domain: 0.695521
# epoch: 15, [iter: 106 / all 190], err_s_label: 0.339002, err_s_domain: 1.876929, err_t_domain: 0.704573
# epoch: 15, [iter: 107 / all 190], err_s_label: 0.044314, err_s_domain: 1.776088, err_t_domain: 0.701677
# epoch: 15, [iter: 108 / all 190], err_s_label: 0.451378, err_s_domain: 1.822542, err_t_domain: 0.692361
# epoch: 15, [iter: 109 / all 190], err_s_label: 0.117606, err_s_domain: 1.852372, err_t_domain: 0.705005
# epoch: 15, [iter: 110 / all 190], err_s_label: 0.168767, err_s_domain: 1.804852, err_t_domain: 0.702641
# epoch: 15, [iter: 111 / all 190], err_s_label: 0.045983, err_s_domain: 1.731666, err_t_domain: 0.725430
# epoch: 15, [iter: 112 / all 190], err_s_label: 0.077878, err_s_domain: 1.888928, err_t_domain: 0.706287
# epoch: 15, [iter: 113 / all 190], err_s_label: 0.052039, err_s_domain: 1.780420, err_t_domain: 0.699661
# epoch: 15, [iter: 114 / all 190], err_s_label: 0.271156, err_s_domain: 1.855346, err_t_domain: 0.716234
# epoch: 15, [iter: 115 / all 190], err_s_label: 0.236275, err_s_domain: 1.794992, err_t_domain: 0.691623
# epoch: 15, [iter: 116 / all 190], err_s_label: 0.158217, err_s_domain: 1.799012, err_t_domain: 0.706555
# epoch: 15, [iter: 117 / all 190], err_s_label: 0.053309, err_s_domain: 1.780270, err_t_domain: 0.699279
# epoch: 15, [iter: 118 / all 190], err_s_label: 0.340153, err_s_domain: 1.761684, err_t_domain: 0.688945
# epoch: 15, [iter: 119 / all 190], err_s_label: 0.103017, err_s_domain: 1.773527, err_t_domain: 0.685034
# epoch: 15, [iter: 120 / all 190], err_s_label: 0.437544, err_s_domain: 1.787640, err_t_domain: 0.685970
# epoch: 15, [iter: 121 / all 190], err_s_label: 0.234366, err_s_domain: 1.830416, err_t_domain: 0.694265
# epoch: 15, [iter: 122 / all 190], err_s_label: 0.098227, err_s_domain: 1.868200, err_t_domain: 0.673292
# epoch: 15, [iter: 123 / all 190], err_s_label: 0.155307, err_s_domain: 1.855512, err_t_domain: 0.680115
# epoch: 15, [iter: 124 / all 190], err_s_label: 0.243154, err_s_domain: 1.773803, err_t_domain: 0.689026
# epoch: 15, [iter: 125 / all 190], err_s_label: 0.264258, err_s_domain: 1.814582, err_t_domain: 0.696089
# epoch: 15, [iter: 126 / all 190], err_s_label: 0.063560, err_s_domain: 1.805762, err_t_domain: 0.684235
# epoch: 15, [iter: 127 / all 190], err_s_label: 0.180614, err_s_domain: 1.837608, err_t_domain: 0.701680
# epoch: 15, [iter: 128 / all 190], err_s_label: 0.505418, err_s_domain: 1.790139, err_t_domain: 0.697037
# epoch: 15, [iter: 129 / all 190], err_s_label: 0.343145, err_s_domain: 1.793093, err_t_domain: 0.711868
# epoch: 15, [iter: 130 / all 190], err_s_label: 0.353613, err_s_domain: 1.779898, err_t_domain: 0.691553
# epoch: 15, [iter: 131 / all 190], err_s_label: 0.068497, err_s_domain: 1.786905, err_t_domain: 0.691917
# epoch: 15, [iter: 132 / all 190], err_s_label: 0.433687, err_s_domain: 1.795195, err_t_domain: 0.687819
# epoch: 15, [iter: 133 / all 190], err_s_label: 0.252479, err_s_domain: 1.862866, err_t_domain: 0.710741
# epoch: 15, [iter: 134 / all 190], err_s_label: 0.524813, err_s_domain: 1.826067, err_t_domain: 0.683515
# epoch: 15, [iter: 135 / all 190], err_s_label: 0.119036, err_s_domain: 1.784770, err_t_domain: 0.694052
# epoch: 15, [iter: 136 / all 190], err_s_label: 0.301061, err_s_domain: 1.799052, err_t_domain: 0.698769
# epoch: 15, [iter: 137 / all 190], err_s_label: 0.405203, err_s_domain: 1.762954, err_t_domain: 0.677517
# epoch: 15, [iter: 138 / all 190], err_s_label: 0.121898, err_s_domain: 1.698357, err_t_domain: 0.696131
# epoch: 15, [iter: 139 / all 190], err_s_label: 0.287703, err_s_domain: 1.776301, err_t_domain: 0.686878
# epoch: 15, [iter: 140 / all 190], err_s_label: 0.320374, err_s_domain: 1.794702, err_t_domain: 0.673289
# epoch: 15, [iter: 141 / all 190], err_s_label: 0.424368, err_s_domain: 1.745072, err_t_domain: 0.683710
# epoch: 15, [iter: 142 / all 190], err_s_label: 0.237895, err_s_domain: 1.841399, err_t_domain: 0.683172
# epoch: 15, [iter: 143 / all 190], err_s_label: 0.253614, err_s_domain: 1.804501, err_t_domain: 0.667103
# epoch: 15, [iter: 144 / all 190], err_s_label: 0.125858, err_s_domain: 1.803238, err_t_domain: 0.673679
# epoch: 15, [iter: 145 / all 190], err_s_label: 0.134409, err_s_domain: 1.791573, err_t_domain: 0.674472
# epoch: 15, [iter: 146 / all 190], err_s_label: 0.205422, err_s_domain: 1.752519, err_t_domain: 0.679354
# epoch: 15, [iter: 147 / all 190], err_s_label: 0.048755, err_s_domain: 1.782088, err_t_domain: 0.675389
# epoch: 15, [iter: 148 / all 190], err_s_label: 0.186073, err_s_domain: 1.800502, err_t_domain: 0.675676
# epoch: 15, [iter: 149 / all 190], err_s_label: 0.035599, err_s_domain: 1.773979, err_t_domain: 0.666480
# epoch: 15, [iter: 150 / all 190], err_s_label: 0.720803, err_s_domain: 1.794849, err_t_domain: 0.666747
# epoch: 15, [iter: 151 / all 190], err_s_label: 0.168273, err_s_domain: 1.833967, err_t_domain: 0.677193
# epoch: 15, [iter: 152 / all 190], err_s_label: 0.096212, err_s_domain: 1.750213, err_t_domain: 0.685831
# epoch: 15, [iter: 153 / all 190], err_s_label: 0.220911, err_s_domain: 1.799376, err_t_domain: 0.672878
# epoch: 15, [iter: 154 / all 190], err_s_label: 0.516625, err_s_domain: 1.781154, err_t_domain: 0.656108
# epoch: 15, [iter: 155 / all 190], err_s_label: 0.088203, err_s_domain: 1.699539, err_t_domain: 0.678006
# epoch: 15, [iter: 156 / all 190], err_s_label: 0.037670, err_s_domain: 1.703811, err_t_domain: 0.670638
# epoch: 15, [iter: 157 / all 190], err_s_label: 0.472016, err_s_domain: 1.756628, err_t_domain: 0.676923
# epoch: 15, [iter: 158 / all 190], err_s_label: 0.052931, err_s_domain: 1.744005, err_t_domain: 0.675773
# epoch: 15, [iter: 159 / all 190], err_s_label: 0.341900, err_s_domain: 1.763300, err_t_domain: 0.661507
# epoch: 15, [iter: 160 / all 190], err_s_label: 0.120761, err_s_domain: 1.716281, err_t_domain: 0.687446
# epoch: 15, [iter: 161 / all 190], err_s_label: 0.268182, err_s_domain: 1.766594, err_t_domain: 0.668336
# epoch: 15, [iter: 162 / all 190], err_s_label: 0.245073, err_s_domain: 1.711735, err_t_domain: 0.687375
# epoch: 15, [iter: 163 / all 190], err_s_label: 0.617179, err_s_domain: 1.698086, err_t_domain: 0.669470
# epoch: 15, [iter: 164 / all 190], err_s_label: 0.108172, err_s_domain: 1.722750, err_t_domain: 0.693695
# epoch: 15, [iter: 165 / all 190], err_s_label: 0.222572, err_s_domain: 1.687705, err_t_domain: 0.702289
# ...
# epoch: 38, [iter: 138 / all 190], err_s_label: 0.051765, err_s_domain: 1.767605, err_t_domain: 0.692467
# epoch: 38, [iter: 139 / all 190], err_s_label: 0.093712, err_s_domain: 1.690204, err_t_domain: 0.696633
# epoch: 38, [iter: 140 / all 190], err_s_label: 0.038638, err_s_domain: 1.771453, err_t_domain: 0.688236
# epoch: 38, [iter: 141 / all 190], err_s_label: 0.119101, err_s_domain: 1.751799, err_t_domain: 0.698765
# epoch: 38, [iter: 142 / all 190], err_s_label: 0.011961, err_s_domain: 1.749367, err_t_domain: 0.691871
# epoch: 38, [iter: 143 / all 190], err_s_label: 0.004723, err_s_domain: 1.789423, err_t_domain: 0.693090
# epoch: 38, [iter: 144 / all 190], err_s_label: 0.012417, err_s_domain: 1.811074, err_t_domain: 0.700049
# epoch: 38, [iter: 145 / all 190], err_s_label: 0.007242, err_s_domain: 1.779182, err_t_domain: 0.697630
# epoch: 38, [iter: 146 / all 190], err_s_label: 0.021437, err_s_domain: 1.704094, err_t_domain: 0.705447
# epoch: 38, [iter: 147 / all 190], err_s_label: 0.041538, err_s_domain: 1.810002, err_t_domain: 0.700154
# epoch: 38, [iter: 148 / all 190], err_s_label: 0.004176, err_s_domain: 1.775519, err_t_domain: 0.702184
# epoch: 38, [iter: 149 / all 190], err_s_label: 0.041430, err_s_domain: 1.767484, err_t_domain: 0.703758
# epoch: 38, [iter: 150 / all 190], err_s_label: 0.062323, err_s_domain: 1.758864, err_t_domain: 0.697261
# epoch: 38, [iter: 151 / all 190], err_s_label: 0.002176, err_s_domain: 1.774132, err_t_domain: 0.705934
# epoch: 38, [iter: 152 / all 190], err_s_label: 0.121853, err_s_domain: 1.827931, err_t_domain: 0.700036
# epoch: 38, [iter: 153 / all 190], err_s_label: 0.048668, err_s_domain: 1.717566, err_t_domain: 0.693892
# epoch: 38, [iter: 154 / all 190], err_s_label: 0.185404, err_s_domain: 1.775665, err_t_domain: 0.692669
# epoch: 38, [iter: 155 / all 190], err_s_label: 0.071708, err_s_domain: 1.802301, err_t_domain: 0.698046
# epoch: 38, [iter: 156 / all 190], err_s_label: 0.110539, err_s_domain: 1.854865, err_t_domain: 0.695272
# epoch: 38, [iter: 157 / all 190], err_s_label: 0.079903, err_s_domain: 1.752731, err_t_domain: 0.693500
# epoch: 38, [iter: 158 / all 190], err_s_label: 0.003321, err_s_domain: 1.782127, err_t_domain: 0.690663
# epoch: 38, [iter: 159 / all 190], err_s_label: 0.118832, err_s_domain: 1.712927, err_t_domain: 0.697612
# epoch: 38, [iter: 160 / all 190], err_s_label: 0.054050, err_s_domain: 1.844883, err_t_domain: 0.693408
# epoch: 38, [iter: 161 / all 190], err_s_label: 0.032029, err_s_domain: 1.765978, err_t_domain: 0.690312
# epoch: 38, [iter: 162 / all 190], err_s_label: 0.082070, err_s_domain: 1.774047, err_t_domain: 0.694144
# epoch: 38, [iter: 163 / all 190], err_s_label: 0.015566, err_s_domain: 1.789931, err_t_domain: 0.691050
# epoch: 38, [iter: 164 / all 190], err_s_label: 0.005442, err_s_domain: 1.789338, err_t_domain: 0.693383
# epoch: 38, [iter: 165 / all 190], err_s_label: 0.042062, err_s_domain: 1.748296, err_t_domain: 0.694253
# epoch: 38, [iter: 166 / all 190], err_s_label: 0.004796, err_s_domain: 1.764369, err_t_domain: 0.699691
# epoch: 38, [iter: 167 / all 190], err_s_label: 0.187417, err_s_domain: 1.778994, err_t_domain: 0.691535
# epoch: 38, [iter: 168 / all 190], err_s_label: 0.072498, err_s_domain: 1.820912, err_t_domain: 0.695953
# epoch: 38, [iter: 169 / all 190], err_s_label: 0.011717, err_s_domain: 1.725318, err_t_domain: 0.692056
# epoch: 38, [iter: 170 / all 190], err_s_label: 0.042871, err_s_domain: 1.765123, err_t_domain: 0.698142
# epoch: 38, [iter: 171 / all 190], err_s_label: 0.015974, err_s_domain: 1.824085, err_t_domain: 0.692992
# epoch: 38, [iter: 172 / all 190], err_s_label: 0.008675, err_s_domain: 1.814388, err_t_domain: 0.701068
# epoch: 38, [iter: 173 / all 190], err_s_label: 0.037342, err_s_domain: 1.767088, err_t_domain: 0.699890
# epoch: 38, [iter: 174 / all 190], err_s_label: 0.153607, err_s_domain: 1.785610, err_t_domain: 0.698930
# epoch: 38, [iter: 175 / all 190], err_s_label: 0.047076, err_s_domain: 1.844839, err_t_domain: 0.698854
# epoch: 38, [iter: 176 / all 190], err_s_label: 0.058198, err_s_domain: 1.786915, err_t_domain: 0.698100
# epoch: 38, [iter: 177 / all 190], err_s_label: 0.011404, err_s_domain: 1.833821, err_t_domain: 0.696979
# epoch: 38, [iter: 178 / all 190], err_s_label: 0.210176, err_s_domain: 1.772563, err_t_domain: 0.694501
# epoch: 38, [iter: 179 / all 190], err_s_label: 0.033420, err_s_domain: 1.799854, err_t_domain: 0.693697
# epoch: 38, [iter: 180 / all 190], err_s_label: 0.005871, err_s_domain: 1.751036, err_t_domain: 0.700594
# epoch: 38, [iter: 181 / all 190], err_s_label: 0.040101, err_s_domain: 1.731628, err_t_domain: 0.700616
# epoch: 38, [iter: 182 / all 190], err_s_label: 0.033394, err_s_domain: 1.851150, err_t_domain: 0.697018
# epoch: 38, [iter: 183 / all 190], err_s_label: 0.128312, err_s_domain: 1.791493, err_t_domain: 0.696019
# epoch: 38, [iter: 184 / all 190], err_s_label: 0.084969, err_s_domain: 1.750899, err_t_domain: 0.690440
# epoch: 38, [iter: 185 / all 190], err_s_label: 0.011370, err_s_domain: 1.816672, err_t_domain: 0.693465
# epoch: 38, [iter: 186 / all 190], err_s_label: 0.017783, err_s_domain: 1.739214, err_t_domain: 0.689816
# epoch: 38, [iter: 187 / all 190], err_s_label: 0.065359, err_s_domain: 1.736821, err_t_domain: 0.687042
# epoch: 38, [iter: 188 / all 190], err_s_label: 0.009760, err_s_domain: 1.788213, err_t_domain: 0.688912
# epoch: 38, [iter: 189 / all 190], err_s_label: 0.015615, err_s_domain: 1.776000, err_t_domain: 0.699137
# epoch: 38, [iter: 190 / all 190], err_s_label: 0.296658, err_s_domain: 1.799865, err_t_domain: 0.686469
# epoch: 38, accuracy of the train dataset: 0.916034
# epoch: 38, accuracy of the test dataset: 0.528379
# epoch: 39, [iter: 1 / all 190], err_s_label: 0.016980, err_s_domain: 1.729313, err_t_domain: 0.692921
# epoch: 39, [iter: 2 / all 190], err_s_label: 0.033293, err_s_domain: 1.786804, err_t_domain: 0.693383
# epoch: 39, [iter: 3 / all 190], err_s_label: 0.015600, err_s_domain: 1.823600, err_t_domain: 0.700635
# epoch: 39, [iter: 4 / all 190], err_s_label: 0.054036, err_s_domain: 1.801926, err_t_domain: 0.691880
# epoch: 39, [iter: 5 / all 190], err_s_label: 0.028712, err_s_domain: 1.764157, err_t_domain: 0.704209
# epoch: 39, [iter: 6 / all 190], err_s_label: 0.007240, err_s_domain: 1.761607, err_t_domain: 0.689287
# epoch: 39, [iter: 7 / all 190], err_s_label: 0.074898, err_s_domain: 1.778532, err_t_domain: 0.691271
# epoch: 39, [iter: 8 / all 190], err_s_label: 0.127364, err_s_domain: 1.810161, err_t_domain: 0.692881
# epoch: 39, [iter: 9 / all 190], err_s_label: 0.041778, err_s_domain: 1.760133, err_t_domain: 0.695558
# epoch: 39, [iter: 10 / all 190], err_s_label: 0.012307, err_s_domain: 1.801283, err_t_domain: 0.699219
# epoch: 39, [iter: 11 / all 190], err_s_label: 0.019994, err_s_domain: 1.768741, err_t_domain: 0.696857
# epoch: 39, [iter: 12 / all 190], err_s_label: 0.005473, err_s_domain: 1.758306, err_t_domain: 0.696737
# epoch: 39, [iter: 13 / all 190], err_s_label: 0.130293, err_s_domain: 1.806838, err_t_domain: 0.693790
# epoch: 39, [iter: 14 / all 190], err_s_label: 0.019123, err_s_domain: 1.758433, err_t_domain: 0.693116
# epoch: 39, [iter: 15 / all 190], err_s_label: 0.072352, err_s_domain: 1.783609, err_t_domain: 0.700021
# epoch: 39, [iter: 16 / all 190], err_s_label: 0.020372, err_s_domain: 1.781024, err_t_domain: 0.691792
# epoch: 39, [iter: 17 / all 190], err_s_label: 0.108387, err_s_domain: 1.701848, err_t_domain: 0.697101
# epoch: 39, [iter: 18 / all 190], err_s_label: 0.062100, err_s_domain: 1.686109, err_t_domain: 0.702488
# epoch: 39, [iter: 19 / all 190], err_s_label: 0.111512, err_s_domain: 1.751769, err_t_domain: 0.695355
# epoch: 39, [iter: 20 / all 190], err_s_label: 0.021058, err_s_domain: 1.741047, err_t_domain: 0.695711
# epoch: 39, [iter: 21 / all 190], err_s_label: 0.020771, err_s_domain: 1.805434, err_t_domain: 0.695991
# epoch: 39, [iter: 22 / all 190], err_s_label: 0.026512, err_s_domain: 1.780995, err_t_domain: 0.698970
# epoch: 39, [iter: 23 / all 190], err_s_label: 0.042445, err_s_domain: 1.766934, err_t_domain: 0.700381
# epoch: 39, [iter: 24 / all 190], err_s_label: 0.003247, err_s_domain: 1.739410, err_t_domain: 0.701375
# epoch: 39, [iter: 25 / all 190], err_s_label: 0.094961, err_s_domain: 1.706949, err_t_domain: 0.696586
# epoch: 39, [iter: 26 / all 190], err_s_label: 0.095859, err_s_domain: 1.789469, err_t_domain: 0.694006
# epoch: 39, [iter: 27 / all 190], err_s_label: 0.041626, err_s_domain: 1.727322, err_t_domain: 0.706409
# epoch: 39, [iter: 28 / all 190], err_s_label: 0.540044, err_s_domain: 1.778634, err_t_domain: 0.699096
# epoch: 39, [iter: 29 / all 190], err_s_label: 0.025017, err_s_domain: 1.718944, err_t_domain: 0.691484
# epoch: 39, [iter: 30 / all 190], err_s_label: 0.043315, err_s_domain: 1.732400, err_t_domain: 0.700557
# epoch: 39, [iter: 31 / all 190], err_s_label: 0.033820, err_s_domain: 1.726864, err_t_domain: 0.692232
# epoch: 39, [iter: 32 / all 190], err_s_label: 0.036366, err_s_domain: 1.777844, err_t_domain: 0.696945
# epoch: 39, [iter: 33 / all 190], err_s_label: 0.013854, err_s_domain: 1.753643, err_t_domain: 0.686986
# epoch: 39, [iter: 34 / all 190], err_s_label: 0.018434, err_s_domain: 1.786675, err_t_domain: 0.697337
# epoch: 39, [iter: 35 / all 190], err_s_label: 0.018327, err_s_domain: 1.709796, err_t_domain: 0.692331
# epoch: 39, [iter: 36 / all 190], err_s_label: 0.123033, err_s_domain: 1.768567, err_t_domain: 0.692551
# epoch: 39, [iter: 37 / all 190], err_s_label: 0.002702, err_s_domain: 1.780009, err_t_domain: 0.694684
# epoch: 39, [iter: 38 / all 190], err_s_label: 0.230148, err_s_domain: 1.671024, err_t_domain: 0.691761
# epoch: 39, [iter: 39 / all 190], err_s_label: 0.009055, err_s_domain: 1.705950, err_t_domain: 0.695935
# epoch: 39, [iter: 40 / all 190], err_s_label: 0.024619, err_s_domain: 1.772668, err_t_domain: 0.688307
# epoch: 39, [iter: 41 / all 190], err_s_label: 0.079804, err_s_domain: 1.804928, err_t_domain: 0.690403
# epoch: 39, [iter: 42 / all 190], err_s_label: 0.009016, err_s_domain: 1.733607, err_t_domain: 0.691800
# epoch: 39, [iter: 43 / all 190], err_s_label: 0.069233, err_s_domain: 1.705292, err_t_domain: 0.687753
# epoch: 39, [iter: 44 / all 190], err_s_label: 0.053340, err_s_domain: 1.819177, err_t_domain: 0.691262
# epoch: 39, [iter: 45 / all 190], err_s_label: 0.083316, err_s_domain: 1.842695, err_t_domain: 0.687371
# epoch: 39, [iter: 46 / all 190], err_s_label: 0.037285, err_s_domain: 1.716273, err_t_domain: 0.693585
# epoch: 39, [iter: 47 / all 190], err_s_label: 0.173004, err_s_domain: 1.732462, err_t_domain: 0.692162
# epoch: 39, [iter: 48 / all 190], err_s_label: 0.099461, err_s_domain: 1.808676, err_t_domain: 0.675654
# epoch: 39, [iter: 49 / all 190], err_s_label: 0.086341, err_s_domain: 1.811997, err_t_domain: 0.686463
# epoch: 39, [iter: 50 / all 190], err_s_label: 0.004904, err_s_domain: 1.692221, err_t_domain: 0.687746
# epoch: 39, [iter: 51 / all 190], err_s_label: 0.046940, err_s_domain: 1.736633, err_t_domain: 0.693696
# epoch: 39, [iter: 52 / all 190], err_s_label: 0.005421, err_s_domain: 1.815688, err_t_domain: 0.686331
# epoch: 39, [iter: 53 / all 190], err_s_label: 0.010906, err_s_domain: 1.848032, err_t_domain: 0.690889
# epoch: 39, [iter: 54 / all 190], err_s_label: 0.031376, err_s_domain: 1.817567, err_t_domain: 0.694324
# epoch: 39, [iter: 55 / all 190], err_s_label: 0.018510, err_s_domain: 1.793489, err_t_domain: 0.688918
# epoch: 39, [iter: 56 / all 190], err_s_label: 0.065247, err_s_domain: 1.756715, err_t_domain: 0.691402
# epoch: 39, [iter: 57 / all 190], err_s_label: 0.007678, err_s_domain: 1.793197, err_t_domain: 0.690517
# epoch: 39, [iter: 58 / all 190], err_s_label: 0.065716, err_s_domain: 1.853213, err_t_domain: 0.692907
# epoch: 39, [iter: 59 / all 190], err_s_label: 0.300559, err_s_domain: 1.841218, err_t_domain: 0.688278
# epoch: 39, [iter: 60 / all 190], err_s_label: 0.042172, err_s_domain: 1.854044, err_t_domain: 0.687023
# epoch: 39, [iter: 61 / all 190], err_s_label: 0.024371, err_s_domain: 1.745226, err_t_domain: 0.681848
# epoch: 39, [iter: 62 / all 190], err_s_label: 0.021147, err_s_domain: 1.773349, err_t_domain: 0.682917
# epoch: 39, [iter: 63 / all 190], err_s_label: 0.017122, err_s_domain: 1.738159, err_t_domain: 0.684953
# epoch: 39, [iter: 64 / all 190], err_s_label: 0.008744, err_s_domain: 1.856499, err_t_domain: 0.691187
# epoch: 39, [iter: 65 / all 190], err_s_label: 0.064150, err_s_domain: 1.811541, err_t_domain: 0.674316
# epoch: 39, [iter: 66 / all 190], err_s_label: 0.028103, err_s_domain: 1.761011, err_t_domain: 0.683262
# epoch: 39, [iter: 67 / all 190], err_s_label: 0.063347, err_s_domain: 1.831817, err_t_domain: 0.689213
# epoch: 39, [iter: 68 / all 190], err_s_label: 0.012218, err_s_domain: 1.783620, err_t_domain: 0.680889
# epoch: 39, [iter: 69 / all 190], err_s_label: 0.169243, err_s_domain: 1.786344, err_t_domain: 0.690572
# epoch: 39, [iter: 70 / all 190], err_s_label: 0.037036, err_s_domain: 1.795961, err_t_domain: 0.689345
# epoch: 39, [iter: 71 / all 190], err_s_label: 0.145789, err_s_domain: 1.791140, err_t_domain: 0.694925
# epoch: 39, [iter: 72 / all 190], err_s_label: 0.009980, err_s_domain: 1.780310, err_t_domain: 0.686170
# epoch: 39, [iter: 73 / all 190], err_s_label: 0.072494, err_s_domain: 1.789217, err_t_domain: 0.683318
# epoch: 39, [iter: 74 / all 190], err_s_label: 0.005702, err_s_domain: 1.838605, err_t_domain: 0.684928
# epoch: 39, [iter: 75 / all 190], err_s_label: 0.081907, err_s_domain: 1.860107, err_t_domain: 0.690706
# epoch: 39, [iter: 76 / all 190], err_s_label: 0.032399, err_s_domain: 1.824405, err_t_domain: 0.683851
# epoch: 39, [iter: 77 / all 190], err_s_label: 0.002730, err_s_domain: 1.754843, err_t_domain: 0.682016
# epoch: 39, [iter: 78 / all 190], err_s_label: 0.282348, err_s_domain: 1.842982, err_t_domain: 0.691983
# epoch: 39, [iter: 79 / all 190], err_s_label: 0.001492, err_s_domain: 1.790967, err_t_domain: 0.689263
# epoch: 39, [iter: 80 / all 190], err_s_label: 0.037031, err_s_domain: 1.841422, err_t_domain: 0.686057
# epoch: 39, [iter: 81 / all 190], err_s_label: 0.079364, err_s_domain: 1.791668, err_t_domain: 0.692494
# epoch: 39, [iter: 82 / all 190], err_s_label: 0.283732, err_s_domain: 1.806994, err_t_domain: 0.691492
# epoch: 39, [iter: 83 / all 190], err_s_label: 0.003447, err_s_domain: 1.801452, err_t_domain: 0.686955
# epoch: 39, [iter: 84 / all 190], err_s_label: 0.133487, err_s_domain: 1.817054, err_t_domain: 0.690595
# epoch: 39, [iter: 85 / all 190], err_s_label: 0.099635, err_s_domain: 1.796762, err_t_domain: 0.698251
# epoch: 39, [iter: 86 / all 190], err_s_label: 0.039802, err_s_domain: 1.775511, err_t_domain: 0.695392
# epoch: 39, [iter: 87 / all 190], err_s_label: 0.317166, err_s_domain: 1.798679, err_t_domain: 0.693425
# epoch: 39, [iter: 88 / all 190], err_s_label: 0.013765, err_s_domain: 1.800230, err_t_domain: 0.691636
# epoch: 39, [iter: 89 / all 190], err_s_label: 0.176178, err_s_domain: 1.791534, err_t_domain: 0.690806
# epoch: 39, [iter: 90 / all 190], err_s_label: 0.283310, err_s_domain: 1.794633, err_t_domain: 0.692112
# epoch: 39, [iter: 91 / all 190], err_s_label: 0.040229, err_s_domain: 1.794794, err_t_domain: 0.697437
# epoch: 39, [iter: 92 / all 190], err_s_label: 0.036119, err_s_domain: 1.819621, err_t_domain: 0.694047
# epoch: 39, [iter: 93 / all 190], err_s_label: 0.023849, err_s_domain: 1.807137, err_t_domain: 0.695470
# epoch: 39, [iter: 94 / all 190], err_s_label: 0.064107, err_s_domain: 1.758023, err_t_domain: 0.695498
# epoch: 39, [iter: 95 / all 190], err_s_label: 0.124218, err_s_domain: 1.769067, err_t_domain: 0.695992
# epoch: 39, [iter: 96 / all 190], err_s_label: 0.014400, err_s_domain: 1.803669, err_t_domain: 0.693531
# epoch: 39, [iter: 97 / all 190], err_s_label: 0.012678, err_s_domain: 1.776112, err_t_domain: 0.700478
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d245c2930c68> in <module>()
#      96
#      97         if cuda:
# ---> 98             t_img = t_img.cuda()
#      99             input_img = input_img.cuda()
#     100             domain_label = domain_label.cuda()
#
# KeyboardInterrupt:
